# %% [markdown]
# # Soil Erosion LEAFs Conservation Tillage
# The RUSLE model can incorporate the effects of reduced tillage, and other land management practices, through simply modification in the C factor. Panagos et al. (2015) shows that for arable crops, the C factor can be disaggregated into. Note that there's currently no differentiation between irrigation practices soil erosion rates, despite having each their own set of values, as some rasters have small differences in where this can be implemented.
#
# $C_{arable} = C_{crop} \cdot C_{mgmt}$
#
# Where $C_{mgmt}$ represents the C factor of land management options including tillage, residues, and cover crops. This is also expressed by a simple multiplication:
#
# $C_{mgmt} = C_{tillage} \cdot C_{residues} \cdot C_{cover}$
#
# For **tillage**, a value of 1, 0.35, or 0.25 is assigned respectively to conventional tillage, reduced/conservation tillage, and No-Till practices.
#
# For **residue management**, it can be calculated as:
#
# $C_{residues} = 1 - 0.12 \cdot F_{residues}$
#
# Where $F_{residues}$ is the fraction of land that leaves residues on the field.
#
# Finally, for **cover crops**, $C_{cover}$ can be calculated as:
#
# $C_{cover} = 1 - 0.2 \cdot F_{cover}$
#
# Where $F_{cover}$ is the fraction of land that uses cover crops during winter or spring.
#
# ## Conservation Tillage Scenarios
# Soil Erosion LEAFs have been calculated for the following crops and scenarios, and can be used to assess the local benefits of reduced tillage when compared to the already calculated traditional tillage scenarios.
#
# | Crop      |  Residue Management |
# |:----------|:-----------------:|
# | Barley    |  Removed from field |
# | Barley    |  Left on the field |
# | Cotton    |  Not Applicable |
# | Maize    |  Removed from field |
# | Maize    |  Left on the field |
# | Rapeseed    |  Removed from field |
# | Rapeseed    |  Left on the field |
# | Sorghum    |  Removed from field |
# | Sorghum    |  Left on the field |
# | Soybean    |  Not Applicable |
# | Sunflower    |  Not Applicable |
# | Wheat    |  Removed from field |
# | Wheat    |  Left on the field |
# | Wheat    | Removed from field |
#
# The file [`lu_c_factor_reducedtillage.xlsx`](../data/crops/lu_c_factor_reducedtillage.xlsx) summarizes all the $C$ factors used

# %% [markdown]
# ## Creating C-Factor rasters
# Just as done in [SoilErosion_Baseline_LEAFs](../documentation/SoilErosion_Baseline_LEAFs.ipynb), C factor rasters are created for each $Crop \times Management$ scenario, which is done using the information in `lu_c_factor_reducedtillage.xlsx`

# %%
# Modules
import sbtn_leaf.map_plotting as mp
import sbtn_leaf.map_calculations as mc

import polars as pl
import geopandas as gpd
import matplotlib.pyplot as plt
import numpy as np
import os

# %%
# Data
scenarios = pl.read_excel("../data/crops/lu_c_factor_reducedtillage.xlsx")
scenarios.head()
# Out:
# shape: (5, 15)
# ┌──────────────┬──────────────┬─────────────┬───────────┬───┬────────┬───────┬───────────┬─────────┐
# │ file_name    ┆ land_use     ┆ path        ┆ crop_name ┆ … ┆ c_crop ┆ c_res ┆ c_tillage ┆ c_final │
# │ ---          ┆ ---          ┆ ---         ┆ ---       ┆   ┆ ---    ┆ ---   ┆ ---       ┆ ---     │
# │ str          ┆ str          ┆ str         ┆ str       ┆   ┆ f64    ┆ f64   ┆ f64       ┆ f64     │
# ╞══════════════╪══════════════╪═════════════╪═══════════╪═══╪════════╪═══════╪═══════════╪═════════╡
# │ lu_Irrigated ┆ Barley_irr_r ┆ C:\Users\lo ┆ Barley    ┆ … ┆ 0.2    ┆ 0.88  ┆ 0.35      ┆ 0.0616  │
# │ _Barley_resi ┆ on_rt        ┆ yola\OneDri ┆           ┆   ┆        ┆       ┆           ┆         │
# │ dues_l…      ┆              ┆ ve - Wor…   ┆           ┆   ┆        ┆       ┆           ┆         │
# │ lu_Irrigated ┆ Barley_irr_r ┆ C:\Users\lo ┆ Barley    ┆ … ┆ 0.2    ┆ 1.0   ┆ 0.35      ┆ 0.07    │
# │ _Barley_resi ┆ off_rt       ┆ yola\OneDri ┆           ┆   ┆        ┆       ┆           ┆         │
# │ dues_r…      ┆              ┆ ve - Wor…   ┆           ┆   ┆        ┆       ┆           ┆         │
# │ lu_Rainfed_B ┆ Barley_rf_ro ┆ C:\Users\lo ┆ Barley    ┆ … ┆ 0.2    ┆ 0.88  ┆ 0.35      ┆ 0.0616  │
# │ arley_residu ┆ n_rt         ┆ yola\OneDri ┆           ┆   ┆        ┆       ┆           ┆         │
# │ es_lef…      ┆              ┆ ve - Wor…   ┆           ┆   ┆        ┆       ┆           ┆         │
# │ lu_Rainfed_B ┆ Barley_rf_ro ┆ C:\Users\lo ┆ Barley    ┆ … ┆ 0.2    ┆ 1.0   ┆ 0.35      ┆ 0.07    │
# │ arley_residu ┆ ff_rt        ┆ yola\OneDri ┆           ┆   ┆        ┆       ┆           ┆         │
# │ es_rem…      ┆              ┆ ve - Wor…   ┆           ┆   ┆        ┆       ┆           ┆         │
# │ lu_Irrigated ┆ Maize_irr_ro ┆ C:\Users\lo ┆ Maize     ┆ … ┆ 0.38   ┆ 0.88  ┆ 0.35      ┆ 0.11704 │
# │ _Maize_resid ┆ n_rt         ┆ yola\OneDri ┆           ┆   ┆        ┆       ┆           ┆         │
# │ ues_le…      ┆              ┆ ve - Wor…   ┆           ┆   ┆        ┆       ┆           ┆         │
# └──────────────┴──────────────┴─────────────┴───────────┴───┴────────┴───────┴───────────┴─────────┘

# %% [markdown]
# Next step is to generate the C-Factor value in the original land use raster resolution (~10km) and then downsampling to 25km from the RLSK layer. The 10km files have not been preserved, but can be generated as follow:

# %%
output_folder = "../data/soil_erosion/C_Factors/10km/"

# %%
for row in scenarios.iter_rows(named=True):
    input_path = row["path"]
    c_factor = row["c_final"]
    land_use_type = row["land_use"]
    output_path = output_folder + "cfactor_10km_" + land_use_type + ".tif"

    print(f"Rasterizing {land_use_type} land use with a c factor of {c_factor}")

    mc.create_binary_mask(input_path, output_path, binary_value=c_factor, dst_nodata=np.nan)
    print(f"{land_use_type} rasterized successfully!\n")
# Out:
# Rasterizing Barley_irr_ron_rt land use with a c factor of 0.0616
# Input No Data defined as 0.0. Value 0.0616 if is not 0.0 and nan if it is.
# 0.0616
# Barley_irr_ron_rt rasterized successfully!
#
# Rasterizing Barley_irr_roff_rt land use with a c factor of 0.06999999999999999
# Input No Data defined as 0.0. Value 0.06999999999999999 if is not 0.0 and nan if it is.
# 0.06999999999999999
# Barley_irr_roff_rt rasterized successfully!
#
# Rasterizing Barley_rf_ron_rt land use with a c factor of 0.0616
# Input No Data defined as 0.0. Value 0.0616 if is not 0.0 and nan if it is.
# 0.0616
# Barley_rf_ron_rt rasterized successfully!
#
# Rasterizing Barley_rf_roff_rt land use with a c factor of 0.06999999999999999
# Input No Data defined as 0.0. Value 0.06999999999999999 if is not 0.0 and nan if it is.
# 0.06999999999999999
# Barley_rf_roff_rt rasterized successfully!
#
# Rasterizing Maize_irr_ron_rt land use with a c factor of 0.11704
# Input No Data defined as 0.0. Value 0.11704 if is not 0.0 and nan if it is.
# 0.11704
# Maize_irr_ron_rt rasterized successfully!
#
# Rasterizing Maize_irr_roff_rt land use with a c factor of 0.13299999999999998
# Input No Data defined as 0.0. Value 0.13299999999999998 if is not 0.0 and nan if it is.
# 0.13299999999999998
# Maize_irr_roff_rt rasterized successfully!
#
# Rasterizing Maize_rf_ron_rt land use with a c factor of 0.11704
# Input No Data defined as 0.0. Value 0.11704 if is not 0.0 and nan if it is.
# 0.11704
# Maize_rf_ron_rt rasterized successfully!
#
# Rasterizing Maize_rf_roff_rt land use with a c factor of 0.13299999999999998
# Input No Data defined as 0.0. Value 0.13299999999999998 if is not 0.0 and nan if it is.
# 0.13299999999999998
# Maize_rf_roff_rt rasterized successfully!
#
# Rasterizing Rapeseed_irr_ron_rt land use with a c factor of 0.077
# Input No Data defined as 0.0. Value 0.077 if is not 0.0 and nan if it is.
# 0.077
# Rapeseed_irr_ron_rt rasterized successfully!
#
# Rasterizing Rapeseed_irr_roff_rt land use with a c factor of 0.0875
# Input No Data defined as 0.0. Value 0.0875 if is not 0.0 and nan if it is.
# 0.0875
# Rapeseed_irr_roff_rt rasterized successfully!
#
# Rasterizing Rapeseed_rf_ron_rt land use with a c factor of 0.077
# Input No Data defined as 0.0. Value 0.077 if is not 0.0 and nan if it is.
# 0.077
# Rapeseed_rf_ron_rt rasterized successfully!
#
# Rasterizing Rapeseed_rf_roff_rt land use with a c factor of 0.0875
# Input No Data defined as 0.0. Value 0.0875 if is not 0.0 and nan if it is.
# 0.0875
# Rapeseed_rf_roff_rt rasterized successfully!
#
# Rasterizing Sorghum_irr_ron_rt land use with a c factor of 0.0308
# Input No Data defined as 0.0. Value 0.0308 if is not 0.0 and nan if it is.
# 0.0308
# Sorghum_irr_ron_rt rasterized successfully!
#
# Rasterizing Sorghum_irr_roff_rt land use with a c factor of 0.034999999999999996
# Input No Data defined as 0.0. Value 0.034999999999999996 if is not 0.0 and nan if it is.
# 0.034999999999999996
# Sorghum_irr_roff_rt rasterized successfully!
#
# Rasterizing Sorghum_rf_ron_rt land use with a c factor of 0.0308
# Input No Data defined as 0.0. Value 0.0308 if is not 0.0 and nan if it is.
# 0.0308
# Sorghum_rf_ron_rt rasterized successfully!
#
# Rasterizing Sorghum_rf_roff_rt land use with a c factor of 0.034999999999999996
# Input No Data defined as 0.0. Value 0.034999999999999996 if is not 0.0 and nan if it is.
# 0.034999999999999996
# Sorghum_rf_roff_rt rasterized successfully!
#
# Rasterizing Wheat_irr_ron_rt land use with a c factor of 0.0616
# Input No Data defined as 0.0. Value 0.0616 if is not 0.0 and nan if it is.
# 0.0616
# Wheat_irr_ron_rt rasterized successfully!
#
# Rasterizing Wheat_irr_roff_rt land use with a c factor of 0.06999999999999999
# Input No Data defined as 0.0. Value 0.06999999999999999 if is not 0.0 and nan if it is.
# 0.06999999999999999
# Wheat_irr_roff_rt rasterized successfully!
#
# Rasterizing Cotton_irr_rt land use with a c factor of 0.13999999999999999
# Input No Data defined as 0.0. Value 0.13999999999999999 if is not 0.0 and nan if it is.
# 0.13999999999999999
# Cotton_irr_rt rasterized successfully!
#
# Rasterizing Cotton_rf_rt land use with a c factor of 0.13999999999999999
# Input No Data defined as 0.0. Value 0.13999999999999999 if is not 0.0 and nan if it is.
# 0.13999999999999999
# Cotton_rf_rt rasterized successfully!
#
# Rasterizing Soybeans_irr_rt land use with a c factor of 0.11199999999999999
# Input No Data defined as 0.0. Value 0.11199999999999999 if is not 0.0 and nan if it is.
# 0.11199999999999999
# Soybeans_irr_rt rasterized successfully!
#
# Rasterizing Sunflower_irr_rt land use with a c factor of 0.0875
# Input No Data defined as 0.0. Value 0.0875 if is not 0.0 and nan if it is.
# 0.0875
# Sunflower_irr_rt rasterized successfully!
#
# Rasterizing Soybeans_rf_rt land use with a c factor of 0.11199999999999999
# Input No Data defined as 0.0. Value 0.11199999999999999 if is not 0.0 and nan if it is.
# 0.11199999999999999
# Soybeans_rf_rt rasterized successfully!
#
# Rasterizing Sunflower_rf_rt land use with a c factor of 0.0875
# Input No Data defined as 0.0. Value 0.0875 if is not 0.0 and nan if it is.
# 0.0875
# Sunflower_rf_rt rasterized successfully!
#
# Rasterizing Wheat_rf_ron_rt land use with a c factor of 0.0462
# Input No Data defined as 0.0. Value 0.0462 if is not 0.0 and nan if it is.
# 0.0462
# Wheat_rf_ron_rt rasterized successfully!
#
# Rasterizing Wheat_rf_roff_rt land use with a c factor of 0.105
# Input No Data defined as 0.0. Value 0.105 if is not 0.0 and nan if it is.
# 0.105
# Wheat_rf_roff_rt rasterized successfully!

# %% [markdown]
# Now downsampling into 25km

# %%
input_folder = "../data/soil_erosion/C_Factors/10km/"
output_folder = "../data/soil_erosion/C_Factors/25km/"
rlsk_fp = "../data/soil_erosion/rlsk_2012.tif"

for file in os.listdir(input_folder):
    # file names
    file_name = os.path.basename(file)

    if "_rt" in file_name:
        new_file_name = file_name.replace("10km", "25km")
        input_path = input_folder + file_name
        output_path = output_folder + new_file_name
        
        # Operation
        mc.resample_to_match(src_path=input_path, target_path=rlsk_fp, output_path=output_path)
        print(f"{file_name} resampled into rlsk raster resolution")
    else:
        continue
# Out:
# cfactor_10km_Barley_irr_roff_rt.tif resampled into rlsk raster resolution
# cfactor_10km_Barley_irr_ron_rt.tif resampled into rlsk raster resolution
# cfactor_10km_Barley_rf_roff_rt.tif resampled into rlsk raster resolution
# cfactor_10km_Barley_rf_ron_rt.tif resampled into rlsk raster resolution
# cfactor_10km_Cotton_irr_rt.tif resampled into rlsk raster resolution
# cfactor_10km_Cotton_rf_rt.tif resampled into rlsk raster resolution
# cfactor_10km_Maize_irr_roff_rt.tif resampled into rlsk raster resolution
# cfactor_10km_Maize_irr_ron_rt.tif resampled into rlsk raster resolution
# cfactor_10km_Maize_rf_roff_rt.tif resampled into rlsk raster resolution
# cfactor_10km_Maize_rf_ron_rt.tif resampled into rlsk raster resolution
# cfactor_10km_Rapeseed_irr_roff_rt.tif resampled into rlsk raster resolution
# cfactor_10km_Rapeseed_irr_ron_rt.tif resampled into rlsk raster resolution
# cfactor_10km_Rapeseed_rf_roff_rt.tif resampled into rlsk raster resolution
# cfactor_10km_Rapeseed_rf_ron_rt.tif resampled into rlsk raster resolution
# cfactor_10km_Sorghum_irr_roff_rt.tif resampled into rlsk raster resolution
# cfactor_10km_Sorghum_irr_ron_rt.tif resampled into rlsk raster resolution
# cfactor_10km_Sorghum_rf_roff_rt.tif resampled into rlsk raster resolution
# cfactor_10km_Sorghum_rf_ron_rt.tif resampled into rlsk raster resolution
# cfactor_10km_Soybeans_irr_rt.tif resampled into rlsk raster resolution
# cfactor_10km_Soybeans_rf_rt.tif resampled into rlsk raster resolution
# cfactor_10km_Sunflower_irr_rt.tif resampled into rlsk raster resolution
# cfactor_10km_Sunflower_rf_rt.tif resampled into rlsk raster resolution
# cfactor_10km_Wheat_irr_roff_rt.tif resampled into rlsk raster resolution
# cfactor_10km_Wheat_irr_ron_rt.tif resampled into rlsk raster resolution
# cfactor_10km_Wheat_rf_roff_rt.tif resampled into rlsk raster resolution
# cfactor_10km_Wheat_rf_ron_rt.tif resampled into rlsk raster resolution

# %% [markdown]
# ## Soil Erosion Rates
# Now, the RLSK layer already generated can be multiplied by the C factor of each land use to calculate the new erosion rates

# %%
input_folder = "../data/soil_erosion/C_Factors/25km/"
output_folder = "../LEAFs/soil_erosion/raster/"

for file in os.listdir(input_folder):
    # file names
    file_name = os.path.basename(file)
    if "_rt" in file_name:
        new_file_name = file_name.replace("cfactor", "se_rate")
        input_path = input_folder + file_name
        output_path = output_folder + new_file_name
        
        # Operation
        mc.multiply_rasters([rlsk_fp, input_path], output_path)
        print(f"Soil erosion calculated for {file_name}")
    else:
        continue
# Out:
# Raster saved into ../LEAFs/soil_erosion/raster/se_rate_25km_Barley_irr_roff_rt.tif
# Soil erosion calculated for cfactor_25km_Barley_irr_roff_rt.tif
# Raster saved into ../LEAFs/soil_erosion/raster/se_rate_25km_Barley_irr_ron_rt.tif
# Soil erosion calculated for cfactor_25km_Barley_irr_ron_rt.tif
# Raster saved into ../LEAFs/soil_erosion/raster/se_rate_25km_Barley_rf_roff_rt.tif
# Soil erosion calculated for cfactor_25km_Barley_rf_roff_rt.tif
# Raster saved into ../LEAFs/soil_erosion/raster/se_rate_25km_Barley_rf_ron_rt.tif
# Soil erosion calculated for cfactor_25km_Barley_rf_ron_rt.tif
# Raster saved into ../LEAFs/soil_erosion/raster/se_rate_25km_Cotton_irr_rt.tif
# Soil erosion calculated for cfactor_25km_Cotton_irr_rt.tif
# Raster saved into ../LEAFs/soil_erosion/raster/se_rate_25km_Cotton_rf_rt.tif
# Soil erosion calculated for cfactor_25km_Cotton_rf_rt.tif
# Raster saved into ../LEAFs/soil_erosion/raster/se_rate_25km_Maize_irr_roff_rt.tif
# Soil erosion calculated for cfactor_25km_Maize_irr_roff_rt.tif
# Raster saved into ../LEAFs/soil_erosion/raster/se_rate_25km_Maize_irr_ron_rt.tif
# Soil erosion calculated for cfactor_25km_Maize_irr_ron_rt.tif
# Raster saved into ../LEAFs/soil_erosion/raster/se_rate_25km_Maize_rf_roff_rt.tif
# Soil erosion calculated for cfactor_25km_Maize_rf_roff_rt.tif
# Raster saved into ../LEAFs/soil_erosion/raster/se_rate_25km_Maize_rf_ron_rt.tif
# Soil erosion calculated for cfactor_25km_Maize_rf_ron_rt.tif
# Raster saved into ../LEAFs/soil_erosion/raster/se_rate_25km_Rapeseed_irr_roff_rt.tif
# Soil erosion calculated for cfactor_25km_Rapeseed_irr_roff_rt.tif
# Raster saved into ../LEAFs/soil_erosion/raster/se_rate_25km_Rapeseed_irr_ron_rt.tif
# Soil erosion calculated for cfactor_25km_Rapeseed_irr_ron_rt.tif
# Raster saved into ../LEAFs/soil_erosion/raster/se_rate_25km_Rapeseed_rf_roff_rt.tif
# Soil erosion calculated for cfactor_25km_Rapeseed_rf_roff_rt.tif
# Raster saved into ../LEAFs/soil_erosion/raster/se_rate_25km_Rapeseed_rf_ron_rt.tif
# Soil erosion calculated for cfactor_25km_Rapeseed_rf_ron_rt.tif
# Raster saved into ../LEAFs/soil_erosion/raster/se_rate_25km_Sorghum_irr_roff_rt.tif
# Soil erosion calculated for cfactor_25km_Sorghum_irr_roff_rt.tif
# Raster saved into ../LEAFs/soil_erosion/raster/se_rate_25km_Sorghum_irr_ron_rt.tif
# Soil erosion calculated for cfactor_25km_Sorghum_irr_ron_rt.tif
# Raster saved into ../LEAFs/soil_erosion/raster/se_rate_25km_Sorghum_rf_roff_rt.tif
# Soil erosion calculated for cfactor_25km_Sorghum_rf_roff_rt.tif
# Raster saved into ../LEAFs/soil_erosion/raster/se_rate_25km_Sorghum_rf_ron_rt.tif
# Soil erosion calculated for cfactor_25km_Sorghum_rf_ron_rt.tif
# Raster saved into ../LEAFs/soil_erosion/raster/se_rate_25km_Soybeans_irr_rt.tif
# Soil erosion calculated for cfactor_25km_Soybeans_irr_rt.tif
# Raster saved into ../LEAFs/soil_erosion/raster/se_rate_25km_Soybeans_rf_rt.tif
# Soil erosion calculated for cfactor_25km_Soybeans_rf_rt.tif
# Raster saved into ../LEAFs/soil_erosion/raster/se_rate_25km_Sunflower_irr_rt.tif
# Soil erosion calculated for cfactor_25km_Sunflower_irr_rt.tif
# Raster saved into ../LEAFs/soil_erosion/raster/se_rate_25km_Sunflower_rf_rt.tif
# Soil erosion calculated for cfactor_25km_Sunflower_rf_rt.tif
# Raster saved into ../LEAFs/soil_erosion/raster/se_rate_25km_Wheat_irr_roff_rt.tif
# Soil erosion calculated for cfactor_25km_Wheat_irr_roff_rt.tif
# Raster saved into ../LEAFs/soil_erosion/raster/se_rate_25km_Wheat_irr_ron_rt.tif
# Soil erosion calculated for cfactor_25km_Wheat_irr_ron_rt.tif
# Raster saved into ../LEAFs/soil_erosion/raster/se_rate_25km_Wheat_rf_roff_rt.tif
# Soil erosion calculated for cfactor_25km_Wheat_rf_roff_rt.tif
# Raster saved into ../LEAFs/soil_erosion/raster/se_rate_25km_Wheat_rf_ron_rt.tif
# Soil erosion calculated for cfactor_25km_Wheat_rf_ron_rt.tif

# %% [markdown]
# ### Checking results

# %%
wheat_ron_fp = "../LEAFs/soil_erosion/raster/se_rate_25km_Rainfed_Wheat_residues_left_on_the_field.tif"
wheat_ron_rt_fp = "../LEAFs/soil_erosion/raster/se_rate_25km_Wheat_rf_ron_rt.tif"

# %%
mp.plot_raster_on_world_extremes_cutoff(wheat_ron_fp, "Soil Erosion Rate 25 km\nWheat, Residues removed from the field, Conventional Tillage", perc_cutoff=5, quantiles=10)
# Out:
# C:\Users\loyola\OneDrive - World Wildlife Fund, Inc\Documents\203. Python projects\SBTN_Test\src\sbtn_leaf\map_plotting.py:218: RuntimeWarning: overflow encountered in cast
#   data = src.read(raster_band).astype("float32", copy=False)
# C:\Users\loyola\OneDrive - World Wildlife Fund, Inc\Documents\203. Python projects\SBTN_Test\src\sbtn_leaf\map_plotting.py:90: RuntimeWarning: overflow encountered in cast
#   out[out == nodata_value] = np.nan
# Raster has 115,305 unique values. Min: 0.22. Max: 102.96
# Using quantiles
# All positives route (quantiles)

# %%
mp.plot_raster_on_world_extremes_cutoff(wheat_ron_rt_fp, "Soil Erosion Rate 25 km\nWheat, Residues removed from the field, Reduced Tillage", perc_cutoff=5, quantiles=10)
# Out:
# C:\Users\loyola\OneDrive - World Wildlife Fund, Inc\Documents\203. Python projects\SBTN_Test\src\sbtn_leaf\map_plotting.py:218: RuntimeWarning: overflow encountered in cast
#   data = src.read(raster_band).astype("float32", copy=False)
# C:\Users\loyola\OneDrive - World Wildlife Fund, Inc\Documents\203. Python projects\SBTN_Test\src\sbtn_leaf\map_plotting.py:90: RuntimeWarning: overflow encountered in cast
#   out[out == nodata_value] = np.nan
# Raster has 250,997 unique values. Min: 0.05. Max: 21.03
# Using quantiles
# All positives route (quantiles)

# %% [markdown]
# It can be seen immediately that the top values are lower for the reduced tillage option.

# %% [markdown]
# ## Calculating regional averages
# Now regional averages need to be calculated, following the same procedure as done for all baseline LEAFs
#
# ### Country
# Defining needed parameters

# %%
# Inputs that stay the same
input_folder = "../LEAFs/soil_erosion/raster/"
output_folder = "../LEAFs/soil_erosion/"
cf_name="soil_erosion"
cf_unit="t soil/ha/yr"
reset_gpck = True
calc_kwargs=dict(outlier_method="log1p_win", std_thresh = 3)
file_filter= "_rt.tif"

# %%
# Inputs that change by area type
area_type = "country"
layer_name = "se_leaf_country"
corrected_shp = gpd.read_file('../data/CountryLayers/Country_Level0/g2015_2014_0_dissolved.shp')
master_key = "ADM0_NAME"
result_key = "country"
gpckg_name = "se_reducedtillage_country"

# %% [markdown]
# Running country averages

# %%
gpkg_path, df_results = mc.build_cfs_gpkg_from_rasters(
    input_folder =input_folder,
    output_folder = output_folder,
    layer_name=layer_name,
    master_gdf=corrected_shp,           # e.g., countries, subcountries, or ecoregions
    master_key=master_key,              # 'ADM0_NAME', 'ADM1_NAME', 'ECO_NAME'
    result_key=result_key,              # must match the column emitted by your calc gdf
    file_filter= file_filter,
    gpckg_name = gpckg_name,
    cf_name=cf_name,
    cf_unit=cf_unit,
    area_type=area_type,
    calc_kwargs=calc_kwargs,
    reset_gpkg=reset_gpck,
    run_test=False                             # Use run test to run the first 3 files
)

print(f"Wrote {df_results.shape[0]} rows into {gpkg_path}")
# Out:
# 2026-01-09 13:53:48,133 - INFO - Building 'se_leaf_country' from rasters in ../LEAFs/soil_erosion/raster/ into ../LEAFs/soil_erosion/ (../LEAFs/soil_erosion/se_reducedtillage_country.gpkg)
# Processing rasters (se_leaf_country):   0%|          | 0/26 [00:00<?, ?raster/s]
# 2026-01-09 13:53:56,214 - INFO - Calculating soil_erosion for se_rate_25km_Barley_irr_roff_rt...
# Calculating soil_erosion for se_rate_25km_Barley_irr_roff_rt...
# 2026-01-09 13:54:45,040 - INFO - Calculating soil_erosion for se_rate_25km_Barley_irr_ron_rt...
# Calculating soil_erosion for se_rate_25km_Barley_irr_ron_rt...
# 2026-01-09 13:55:32,613 - INFO - Calculating soil_erosion for se_rate_25km_Barley_rf_roff_rt...
# Calculating soil_erosion for se_rate_25km_Barley_rf_roff_rt...
# 2026-01-09 13:56:19,016 - INFO - Calculating soil_erosion for se_rate_25km_Barley_rf_ron_rt...
# Calculating soil_erosion for se_rate_25km_Barley_rf_ron_rt...
# 2026-01-09 13:57:06,035 - INFO - Calculating soil_erosion for se_rate_25km_Cotton_irr_rt...
# Calculating soil_erosion for se_rate_25km_Cotton_irr_rt...
# 2026-01-09 13:57:52,715 - INFO - Calculating soil_erosion for se_rate_25km_Cotton_rf_rt...
# Calculating soil_erosion for se_rate_25km_Cotton_rf_rt...
# 2026-01-09 13:58:47,996 - INFO - Calculating soil_erosion for se_rate_25km_Maize_irr_roff_rt...
# Calculating soil_erosion for se_rate_25km_Maize_irr_roff_rt...
# 2026-01-09 13:59:38,287 - INFO - Calculating soil_erosion for se_rate_25km_Maize_irr_ron_rt...
# Calculating soil_erosion for se_rate_25km_Maize_irr_ron_rt...
# 2026-01-09 14:00:24,912 - INFO - Calculating soil_erosion for se_rate_25km_Maize_rf_roff_rt...
# Calculating soil_erosion for se_rate_25km_Maize_rf_roff_rt...
# 2026-01-09 14:01:12,422 - INFO - Calculating soil_erosion for se_rate_25km_Maize_rf_ron_rt...
# Calculating soil_erosion for se_rate_25km_Maize_rf_ron_rt...
# 2026-01-09 14:01:59,415 - INFO - Calculating soil_erosion for se_rate_25km_Rapeseed_irr_roff_rt...
# Calculating soil_erosion for se_rate_25km_Rapeseed_irr_roff_rt...
# 2026-01-09 14:02:43,041 - INFO - Calculating soil_erosion for se_rate_25km_Rapeseed_irr_ron_rt...
# Calculating soil_erosion for se_rate_25km_Rapeseed_irr_ron_rt...
# 2026-01-09 14:03:44,184 - INFO - Calculating soil_erosion for se_rate_25km_Rapeseed_rf_roff_rt...
# Calculating soil_erosion for se_rate_25km_Rapeseed_rf_roff_rt...
# 2026-01-09 14:04:43,480 - INFO - Calculating soil_erosion for se_rate_25km_Rapeseed_rf_ron_rt...
# Calculating soil_erosion for se_rate_25km_Rapeseed_rf_ron_rt...
# 2026-01-09 14:05:26,588 - INFO - Calculating soil_erosion for se_rate_25km_Sorghum_irr_roff_rt...
# Calculating soil_erosion for se_rate_25km_Sorghum_irr_roff_rt...
# 2026-01-09 14:06:13,863 - INFO - Calculating soil_erosion for se_rate_25km_Sorghum_irr_ron_rt...
# Calculating soil_erosion for se_rate_25km_Sorghum_irr_ron_rt...
# 2026-01-09 14:07:00,577 - INFO - Calculating soil_erosion for se_rate_25km_Sorghum_rf_roff_rt...
# Calculating soil_erosion for se_rate_25km_Sorghum_rf_roff_rt...
# 2026-01-09 14:07:48,829 - INFO - Calculating soil_erosion for se_rate_25km_Sorghum_rf_ron_rt...
# Calculating soil_erosion for se_rate_25km_Sorghum_rf_ron_rt...
# 2026-01-09 14:08:41,149 - INFO - Calculating soil_erosion for se_rate_25km_Soybeans_irr_rt...
# Calculating soil_erosion for se_rate_25km_Soybeans_irr_rt...
# 2026-01-09 14:10:00,986 - INFO - Calculating soil_erosion for se_rate_25km_Soybeans_rf_rt...
# Calculating soil_erosion for se_rate_25km_Soybeans_rf_rt...
# 2026-01-09 14:11:37,025 - INFO - Calculating soil_erosion for se_rate_25km_Sunflower_irr_rt...
# Calculating soil_erosion for se_rate_25km_Sunflower_irr_rt...
# 2026-01-09 14:12:53,881 - INFO - Calculating soil_erosion for se_rate_25km_Sunflower_rf_rt...
# Calculating soil_erosion for se_rate_25km_Sunflower_rf_rt...
# 2026-01-09 14:14:01,703 - INFO - Calculating soil_erosion for se_rate_25km_Wheat_irr_roff_rt...
# Calculating soil_erosion for se_rate_25km_Wheat_irr_roff_rt...
# 2026-01-09 14:15:09,122 - INFO - Calculating soil_erosion for se_rate_25km_Wheat_irr_ron_rt...
# Calculating soil_erosion for se_rate_25km_Wheat_irr_ron_rt...
# 2026-01-09 14:16:20,569 - INFO - Calculating soil_erosion for se_rate_25km_Wheat_rf_roff_rt...
# Calculating soil_erosion for se_rate_25km_Wheat_rf_roff_rt...
# 2026-01-09 14:17:41,910 - INFO - Calculating soil_erosion for se_rate_25km_Wheat_rf_ron_rt...
# Calculating soil_erosion for se_rate_25km_Wheat_rf_ron_rt...
# 2026-01-09 14:18:59,689 - INFO - Wrote 7176 attribute rows into ../LEAFs/soil_erosion/se_reducedtillage_country.gpkg (geometry layer='geometry_layer', values layer='se_leaf_country').
# Wrote 21528 rows into ../LEAFs/soil_erosion/se_reducedtillage_country.gpkg

# %% [markdown]
# #### Checking results...

# %%
gdf_test_values = gpd.read_file(gpkg_path, layer=layer_name)
gdf_test_values.sort_values(by=["cf"], ascending=False).head()
# Out:
#               ADM0_NAME                       flow_name          cf  \
# 1670  Arunachal Pradesh  se_rate_25km_Maize_irr_roff_rt  186.806824
# 2222  Arunachal Pradesh   se_rate_25km_Maize_rf_roff_rt  186.806824
# 2239             Bhutan   se_rate_25km_Maize_rf_roff_rt  183.050552
# 1687             Bhutan  se_rate_25km_Maize_irr_roff_rt  183.050552
# 1118  Arunachal Pradesh      se_rate_25km_Cotton_irr_rt  181.095062
#
#        cf_median      cf_std                        _source_file
# 1670  151.899307  140.352951  se_rate_25km_Maize_irr_roff_rt.tif
# 2222  151.899307  140.352951   se_rate_25km_Maize_rf_roff_rt.tif
# 2239  164.956009  129.090836   se_rate_25km_Maize_rf_roff_rt.tif
# 1687  164.956009  129.090836  se_rate_25km_Maize_irr_roff_rt.tif
# 1118  149.062775  147.265839      se_rate_25km_Cotton_irr_rt.tif

# %% [markdown]
# Merging geometries

# %%
gdf_test_geometries = gpd.read_file(gpkg_path, layer="geometry_layer")
gdf_test = gdf_test_geometries.merge(gdf_test_values.drop(columns="_source_file"), how="left", on="ADM0_NAME")

# %% [markdown]
# Plotting one crop

# %%
test_flow = "se_rate_25km_Barley_irr_ron_rt"

# %%
country_leafs_check = gdf_test[gdf_test["flow_name"]==test_flow]

# %%
fig, ax = plt.subplots(figsize=(14, 8)) 
country_leafs_check.plot(column="cf", ax=ax, cmap="viridis", 
           legend=True, 
           legend_kwds={"label": "Soil Erosion [t/ha/yr]", "shrink": 0.8}, 
           missing_kwds={"color": "lightgrey", "label": "No value"}) 

ax.set_title("Soil Erosion Rate\nBarley, Irrigated, Residues left on the field, Reduced Tillage")
plt.tight_layout() 
plt.show()

# %% [markdown]
# Cheching csv

# %%
df_results.sort_values(by="value", ascending=False).head(10)
# Out:
#               ADM0_NAME            country       value     metric  \
# 4982  Arunachal Pradesh  Arunachal Pradesh  186.806823    cf_mean
# 6638  Arunachal Pradesh  Arunachal Pradesh  186.806823    cf_mean
# 6655             Bhutan             Bhutan  183.050551    cf_mean
# 4999             Bhutan             Bhutan  183.050551    cf_mean
# 3326  Arunachal Pradesh  Arunachal Pradesh  181.095059    cf_mean
# 4154  Arunachal Pradesh  Arunachal Pradesh  181.095059    cf_mean
# 5275             Bhutan             Bhutan  164.956007  cf_median
# 6931             Bhutan             Bhutan  164.956007  cf_median
# 5810  Arunachal Pradesh  Arunachal Pradesh  164.378268    cf_mean
# 7466  Arunachal Pradesh  Arunachal Pradesh  164.378268    cf_mean
#
#                            flow_name
# 4982  se_rate_25km_Maize_irr_roff_rt
# 6638   se_rate_25km_Maize_rf_roff_rt
# 6655   se_rate_25km_Maize_rf_roff_rt
# 4999  se_rate_25km_Maize_irr_roff_rt
# 3326      se_rate_25km_Cotton_irr_rt
# 4154       se_rate_25km_Cotton_rf_rt
# 5275  se_rate_25km_Maize_irr_roff_rt
# 6931   se_rate_25km_Maize_rf_roff_rt
# 5810   se_rate_25km_Maize_irr_ron_rt
# 7466    se_rate_25km_Maize_rf_ron_rt

# %% [markdown]
# Same values as those on gpckg. All looks ok

# %% [markdown]
# ### Subcountries
# Now proceeding, same as for countries, with sub-country regions.
#
# Loading the necessary data and parameters

# %%
# Inputs that change by area type
area_type = "subcountry"
layer_name = "se_leaf_subcountry"
shp = gpd.read_file('../data/CountryLayers/SubCountry_Level1/g2015_2014_1.shp')
master_key = "ADM1_CODE"
result_key = "ADM1_CODE"
gpckg_name = "se_reducedtillage_subcountry"

# %% [markdown]
# Running the averages

# %%
gpkg_path, df_results = mc.build_cfs_gpkg_from_rasters(
    input_folder =input_folder,
    output_folder = output_folder,
    layer_name=layer_name,
    master_gdf=shp,           # e.g., countries, subcountries, or ecoregions
    master_key=master_key,              # 'ADM0_NAME', 'ADM1_NAME', 'ECO_NAME'
    result_key=result_key,              # must match the column emitted by your calc gdf
    file_filter= file_filter,
    gpckg_name = gpckg_name,
    cf_name=cf_name,
    cf_unit=cf_unit,
    area_type=area_type,
    calc_kwargs=calc_kwargs,
    reset_gpkg=reset_gpck,
    run_test=False                             # Use run test to run the first 3 files
)

print(f"Wrote {df_results.shape[0]} rows into {gpkg_path}")
# Out:
# 2026-01-09 14:20:07,282 - INFO - Building 'se_leaf_subcountry' from rasters in ../LEAFs/soil_erosion/raster/ into ../LEAFs/soil_erosion/ (../LEAFs/soil_erosion/se_reducedtillage_subcountry.gpkg)
# Processing rasters (se_leaf_subcountry):   0%|          | 0/26 [00:00<?, ?raster/s]
# 2026-01-09 14:20:21,203 - INFO - Calculating soil_erosion for se_rate_25km_Barley_irr_roff_rt...
# Calculating soil_erosion for se_rate_25km_Barley_irr_roff_rt...
# 2026-01-09 14:22:56,895 - INFO - Calculating soil_erosion for se_rate_25km_Barley_irr_ron_rt...
# Calculating soil_erosion for se_rate_25km_Barley_irr_ron_rt...
# 2026-01-09 14:25:29,045 - INFO - Calculating soil_erosion for se_rate_25km_Barley_rf_roff_rt...
# Calculating soil_erosion for se_rate_25km_Barley_rf_roff_rt...
# 2026-01-09 14:28:09,429 - INFO - Calculating soil_erosion for se_rate_25km_Barley_rf_ron_rt...
# Calculating soil_erosion for se_rate_25km_Barley_rf_ron_rt...
# 2026-01-09 14:30:48,068 - INFO - Calculating soil_erosion for se_rate_25km_Cotton_irr_rt...
# Calculating soil_erosion for se_rate_25km_Cotton_irr_rt...
# 2026-01-09 14:33:08,215 - INFO - Calculating soil_erosion for se_rate_25km_Cotton_rf_rt...
# Calculating soil_erosion for se_rate_25km_Cotton_rf_rt...
# 2026-01-09 14:35:34,541 - INFO - Calculating soil_erosion for se_rate_25km_Maize_irr_roff_rt...
# Calculating soil_erosion for se_rate_25km_Maize_irr_roff_rt...
# 2026-01-09 14:38:04,506 - INFO - Calculating soil_erosion for se_rate_25km_Maize_irr_ron_rt...
# Calculating soil_erosion for se_rate_25km_Maize_irr_ron_rt...
# 2026-01-09 14:40:36,945 - INFO - Calculating soil_erosion for se_rate_25km_Maize_rf_roff_rt...
# Calculating soil_erosion for se_rate_25km_Maize_rf_roff_rt...
# 2026-01-09 14:43:10,032 - INFO - Calculating soil_erosion for se_rate_25km_Maize_rf_ron_rt...
# Calculating soil_erosion for se_rate_25km_Maize_rf_ron_rt...
# 2026-01-09 14:45:44,340 - INFO - Calculating soil_erosion for se_rate_25km_Rapeseed_irr_roff_rt...
# Calculating soil_erosion for se_rate_25km_Rapeseed_irr_roff_rt...
# 2026-01-09 14:48:09,409 - INFO - Calculating soil_erosion for se_rate_25km_Rapeseed_irr_ron_rt...
# Calculating soil_erosion for se_rate_25km_Rapeseed_irr_ron_rt...
# 2026-01-09 14:51:18,802 - INFO - Calculating soil_erosion for se_rate_25km_Rapeseed_rf_roff_rt...
# Calculating soil_erosion for se_rate_25km_Rapeseed_rf_roff_rt...
# 2026-01-09 14:54:11,028 - INFO - Calculating soil_erosion for se_rate_25km_Rapeseed_rf_ron_rt...
# Calculating soil_erosion for se_rate_25km_Rapeseed_rf_ron_rt...
# 2026-01-09 14:56:36,412 - INFO - Calculating soil_erosion for se_rate_25km_Sorghum_irr_roff_rt...
# Calculating soil_erosion for se_rate_25km_Sorghum_irr_roff_rt...
# 2026-01-09 14:59:05,247 - INFO - Calculating soil_erosion for se_rate_25km_Sorghum_irr_ron_rt...
# Calculating soil_erosion for se_rate_25km_Sorghum_irr_ron_rt...
# 2026-01-09 15:01:46,542 - INFO - Calculating soil_erosion for se_rate_25km_Sorghum_rf_roff_rt...
# Calculating soil_erosion for se_rate_25km_Sorghum_rf_roff_rt...
# 2026-01-09 15:04:05,770 - INFO - Calculating soil_erosion for se_rate_25km_Sorghum_rf_ron_rt...
# Calculating soil_erosion for se_rate_25km_Sorghum_rf_ron_rt...
# 2026-01-09 15:07:09,105 - INFO - Calculating soil_erosion for se_rate_25km_Soybeans_irr_rt...
# Calculating soil_erosion for se_rate_25km_Soybeans_irr_rt...
# 2026-01-09 15:09:26,347 - INFO - Calculating soil_erosion for se_rate_25km_Soybeans_rf_rt...
# Calculating soil_erosion for se_rate_25km_Soybeans_rf_rt...
# 2026-01-09 15:11:38,388 - INFO - Calculating soil_erosion for se_rate_25km_Sunflower_irr_rt...
# Calculating soil_erosion for se_rate_25km_Sunflower_irr_rt...
# 2026-01-09 15:14:05,849 - INFO - Calculating soil_erosion for se_rate_25km_Sunflower_rf_rt...
# Calculating soil_erosion for se_rate_25km_Sunflower_rf_rt...
# 2026-01-09 15:16:25,936 - INFO - Calculating soil_erosion for se_rate_25km_Wheat_irr_roff_rt...
# Calculating soil_erosion for se_rate_25km_Wheat_irr_roff_rt...
# 2026-01-09 15:18:57,510 - INFO - Calculating soil_erosion for se_rate_25km_Wheat_irr_ron_rt...
# Calculating soil_erosion for se_rate_25km_Wheat_irr_ron_rt...
# 2026-01-09 15:22:19,803 - INFO - Calculating soil_erosion for se_rate_25km_Wheat_rf_roff_rt...
# Calculating soil_erosion for se_rate_25km_Wheat_rf_roff_rt...
# 2026-01-09 15:25:47,895 - INFO - Calculating soil_erosion for se_rate_25km_Wheat_rf_ron_rt...
# Calculating soil_erosion for se_rate_25km_Wheat_rf_ron_rt...
# 2026-01-09 15:28:43,492 - INFO - Wrote 88972 attribute rows into ../LEAFs/soil_erosion/se_reducedtillage_subcountry.gpkg (geometry layer='geometry_layer', values layer='se_leaf_subcountry').
# Wrote 266916 rows into ../LEAFs/soil_erosion/se_reducedtillage_subcountry.gpkg

# %% [markdown]
# #### Checking results

# %%
gdf_test_values = gpd.read_file(gpkg_path, layer=layer_name)
gdf_test_values.sort_values(by=["cf"], ascending=False).head()
# Out:
#        ADM1_CODE                       flow_name          cf   cf_median  \
# 62993       1139    se_rate_25km_Soybeans_irr_rt  515.895874  515.895874
# 66415       1139     se_rate_25km_Soybeans_rf_rt  515.895874  515.895874
# 22663      41310  se_rate_25km_Maize_irr_roff_rt  442.913666  393.247559
# 29507      41310   se_rate_25km_Maize_rf_roff_rt  442.913666  393.247559
# 83444       3304   se_rate_25km_Wheat_rf_roff_rt  420.186859  420.186859
#
#           cf_std                        _source_file
# 62993   0.000000    se_rate_25km_Soybeans_irr_rt.tif
# 66415   0.000000     se_rate_25km_Soybeans_rf_rt.tif
# 22663  55.528408  se_rate_25km_Maize_irr_roff_rt.tif
# 29507  55.528408   se_rate_25km_Maize_rf_roff_rt.tif
# 83444   0.000000   se_rate_25km_Wheat_rf_roff_rt.tif

# %%
gdf_test_geometries = gpd.read_file(gpkg_path, layer="geometry_layer")
gdf_test = gdf_test_geometries.merge(gdf_test_values.drop(columns="_source_file"), how="left", on="ADM1_CODE")

# %% [markdown]
# Plotting one crop

# %%
subcountry_leafs_check = gdf_test[gdf_test["flow_name"]==test_flow]

# %%
fig, ax = plt.subplots(figsize=(14, 8)) 
subcountry_leafs_check.plot(column="cf", ax=ax, cmap="viridis", 
           legend=True, 
           legend_kwds={"label": "Soil Erosion [t/ha/yr]", "shrink": 0.8}, 
           missing_kwds={"color": "lightgrey", "label": "No value"}) 

ax.set_title("Soil Erosion Rate\nBarley, Irrigated, Residues left on the field, Reduced Tillage")
plt.tight_layout() 
plt.show()

# %% [markdown]
# ### Ecoregions
# Finally, ecoregions

# %%
# Inputs that change by area type
area_type = "ecoregion"
layer_name = "se_leaf_ecoregions"
master_key = "ECO_ID"
result_key = "er_id"
gpckg_name = "se_reducedtillage_ecoregions"
shp = gpd.read_file("../data/Ecoregions2017/Ecoregions2017.shp")

# %%
gpkg_path, df_results = mc.build_cfs_gpkg_from_rasters(
    input_folder =input_folder,
    output_folder = output_folder,
    layer_name=layer_name,
    master_gdf=shp,           # e.g., countries, subcountries, or ecoregions
    master_key=master_key,              # 'ADM0_NAME', 'ADM1_NAME', 'ECO_NAME'
    result_key=result_key,              # must match the column emitted by your calc gdf
    file_filter= file_filter,
    gpckg_name = gpckg_name,
    cf_name=cf_name,
    cf_unit=cf_unit,
    area_type=area_type,
    calc_kwargs=calc_kwargs,
    reset_gpkg=reset_gpck,
    run_test=False                             # Use run test to run the first 3 files
)

print(f"Wrote {df_results.shape[0]} rows into {gpkg_path}")
# Out:
# 2026-01-09 15:29:48,787 - INFO - Building 'se_leaf_ecoregions' from rasters in ../LEAFs/soil_erosion/raster/ into ../LEAFs/soil_erosion/ (../LEAFs/soil_erosion/se_reducedtillage_ecoregions.gpkg)
# Processing rasters (se_leaf_ecoregions):   0%|          | 0/26 [00:00<?, ?raster/s]
# 2026-01-09 15:30:06,181 - INFO - Calculating soil_erosion for se_rate_25km_Barley_irr_roff_rt...
# Calculating soil_erosion for se_rate_25km_Barley_irr_roff_rt...
# 2026-01-09 15:33:11,371 - INFO - Calculating soil_erosion for se_rate_25km_Barley_irr_ron_rt...
# Calculating soil_erosion for se_rate_25km_Barley_irr_ron_rt...
# 2026-01-09 15:35:42,410 - INFO - Calculating soil_erosion for se_rate_25km_Barley_rf_roff_rt...
# Calculating soil_erosion for se_rate_25km_Barley_rf_roff_rt...
# 2026-01-09 15:38:14,886 - INFO - Calculating soil_erosion for se_rate_25km_Barley_rf_ron_rt...
# Calculating soil_erosion for se_rate_25km_Barley_rf_ron_rt...
# 2026-01-09 15:40:45,564 - INFO - Calculating soil_erosion for se_rate_25km_Cotton_irr_rt...
# Calculating soil_erosion for se_rate_25km_Cotton_irr_rt...
# 2026-01-09 15:43:21,998 - INFO - Calculating soil_erosion for se_rate_25km_Cotton_rf_rt...
# Calculating soil_erosion for se_rate_25km_Cotton_rf_rt...
# 2026-01-09 15:45:25,364 - INFO - Calculating soil_erosion for se_rate_25km_Maize_irr_roff_rt...
# Calculating soil_erosion for se_rate_25km_Maize_irr_roff_rt...
# 2026-01-09 15:47:30,796 - INFO - Calculating soil_erosion for se_rate_25km_Maize_irr_ron_rt...
# Calculating soil_erosion for se_rate_25km_Maize_irr_ron_rt...
# 2026-01-09 15:50:14,662 - INFO - Calculating soil_erosion for se_rate_25km_Maize_rf_roff_rt...
# Calculating soil_erosion for se_rate_25km_Maize_rf_roff_rt...
# 2026-01-09 15:53:11,023 - INFO - Calculating soil_erosion for se_rate_25km_Maize_rf_ron_rt...
# Calculating soil_erosion for se_rate_25km_Maize_rf_ron_rt...
# 2026-01-09 15:56:00,517 - INFO - Calculating soil_erosion for se_rate_25km_Rapeseed_irr_roff_rt...
# Calculating soil_erosion for se_rate_25km_Rapeseed_irr_roff_rt...
# 2026-01-09 15:58:42,959 - INFO - Calculating soil_erosion for se_rate_25km_Rapeseed_irr_ron_rt...
# Calculating soil_erosion for se_rate_25km_Rapeseed_irr_ron_rt...
# 2026-01-09 16:01:27,627 - INFO - Calculating soil_erosion for se_rate_25km_Rapeseed_rf_roff_rt...
# Calculating soil_erosion for se_rate_25km_Rapeseed_rf_roff_rt...
# 2026-01-09 16:04:09,917 - INFO - Calculating soil_erosion for se_rate_25km_Rapeseed_rf_ron_rt...
# Calculating soil_erosion for se_rate_25km_Rapeseed_rf_ron_rt...
# 2026-01-09 16:06:52,293 - INFO - Calculating soil_erosion for se_rate_25km_Sorghum_irr_roff_rt...
# Calculating soil_erosion for se_rate_25km_Sorghum_irr_roff_rt...
# 2026-01-09 16:09:43,128 - INFO - Calculating soil_erosion for se_rate_25km_Sorghum_irr_ron_rt...
# Calculating soil_erosion for se_rate_25km_Sorghum_irr_ron_rt...
# 2026-01-09 16:12:30,572 - INFO - Calculating soil_erosion for se_rate_25km_Sorghum_rf_roff_rt...
# Calculating soil_erosion for se_rate_25km_Sorghum_rf_roff_rt...
# 2026-01-09 16:15:20,410 - INFO - Calculating soil_erosion for se_rate_25km_Sorghum_rf_ron_rt...
# Calculating soil_erosion for se_rate_25km_Sorghum_rf_ron_rt...
# 2026-01-09 16:18:12,565 - INFO - Calculating soil_erosion for se_rate_25km_Soybeans_irr_rt...
# Calculating soil_erosion for se_rate_25km_Soybeans_irr_rt...
# 2026-01-09 16:21:02,532 - INFO - Calculating soil_erosion for se_rate_25km_Soybeans_rf_rt...
# Calculating soil_erosion for se_rate_25km_Soybeans_rf_rt...
# 2026-01-09 16:23:50,583 - INFO - Calculating soil_erosion for se_rate_25km_Sunflower_irr_rt...
# Calculating soil_erosion for se_rate_25km_Sunflower_irr_rt...
# 2026-01-09 16:26:38,750 - INFO - Calculating soil_erosion for se_rate_25km_Sunflower_rf_rt...
# Calculating soil_erosion for se_rate_25km_Sunflower_rf_rt...
# 2026-01-09 16:29:27,309 - INFO - Calculating soil_erosion for se_rate_25km_Wheat_irr_roff_rt...
# Calculating soil_erosion for se_rate_25km_Wheat_irr_roff_rt...
# 2026-01-09 16:32:20,367 - INFO - Calculating soil_erosion for se_rate_25km_Wheat_irr_ron_rt...
# Calculating soil_erosion for se_rate_25km_Wheat_irr_ron_rt...
# 2026-01-09 16:35:11,218 - INFO - Calculating soil_erosion for se_rate_25km_Wheat_rf_roff_rt...
# Calculating soil_erosion for se_rate_25km_Wheat_rf_roff_rt...
# 2026-01-09 16:38:00,486 - INFO - Calculating soil_erosion for se_rate_25km_Wheat_rf_ron_rt...
# Calculating soil_erosion for se_rate_25km_Wheat_rf_ron_rt...
# 2026-01-09 16:40:50,764 - INFO - Wrote 22022 attribute rows into ../LEAFs/soil_erosion/se_reducedtillage_ecoregions.gpkg (geometry layer='geometry_layer', values layer='se_leaf_ecoregions').
# Wrote 66066 rows into ../LEAFs/soil_erosion/se_reducedtillage_ecoregions.gpkg

# %% [markdown]
# #### Checking Results

# %%
gdf_test_values = gpd.read_file(gpkg_path, layer=layer_name)
gdf_test_values.sort_values(by=["cf"], ascending=False).head()
# Out:
#        ECO_ID                       flow_name          cf   cf_median  \
# 20364     520   se_rate_25km_Wheat_rf_roff_rt  406.159393  406.159393
# 5713      546  se_rate_25km_Maize_irr_roff_rt  381.687744  381.687744
# 7407      546   se_rate_25km_Maize_rf_roff_rt  381.687744  381.687744
# 20731     478   se_rate_25km_Wheat_rf_roff_rt  338.406708  192.340958
# 6560      546   se_rate_25km_Maize_irr_ron_rt  335.885223  335.885223
#
#           cf_std                        _source_file
# 20364    0.00000   se_rate_25km_Wheat_rf_roff_rt.tif
# 5713     0.00000  se_rate_25km_Maize_irr_roff_rt.tif
# 7407     0.00000   se_rate_25km_Maize_rf_roff_rt.tif
# 20731  242.96051   se_rate_25km_Wheat_rf_roff_rt.tif
# 6560     0.00000   se_rate_25km_Maize_irr_ron_rt.tif

# %%
gdf_test_geometries = gpd.read_file(gpkg_path, layer="geometry_layer")
gdf_test = gdf_test_geometries.merge(gdf_test_values.drop(columns="_source_file"), how="left", on="ECO_ID")

# %% [markdown]
# Plotting one crop

# %%
er_leafs_check = gdf_test[gdf_test["flow_name"]==test_flow]

# %%
fig, ax = plt.subplots(figsize=(14, 8)) 
er_leafs_check.plot(column="cf", ax=ax, cmap="viridis", 
           legend=True, 
           legend_kwds={"label": "Soil Erosion [t/ha/yr]", "shrink": 0.8}, 
           missing_kwds={"color": "lightgrey", "label": "No value"}) 

ax.set_title("Soil Erosion Rate\nBarley, Irrigated, Residues left on the field, Reduced Tillage")
plt.tight_layout() 
plt.show()
