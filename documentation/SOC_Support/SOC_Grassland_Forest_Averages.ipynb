# %% [markdown]
# # Forest and Grassland Averages
# Notebook to create needed averages with updated functions to ensure consistency.

# %% [markdown]
# ## Setup

# %%
import os
import polars as pl
import matplotlib.pyplot as plt
from pathlib import Path
import numpy as np
import rasterio
import importlib
from rasterio.warp import reproject
from rasterio.enums import Resampling
import geopandas as gpd

from sbtn_leaf.paths import data_path
import sbtn_leaf.map_plotting as mp
import sbtn_leaf.map_calculations as mc
import sbtn_leaf.cropcalcs as cropcalcs
import sbtn_leaf.RothC_Raster as rothc
# Out:
# Could not determine dtype for column 1, falling back to string

# %%
project_root = Path.cwd().parents[1]   # adjust number
soc_raster_folder = project_root/"LEAFs/SOC/rasters/"
soc_folder = project_root/"LEAFs/SOC/"

# %% [markdown]
# ## Averages

# %% [markdown]
# Constant inputs

# %%
# Inputs that stay the same
input_folder = soc_raster_folder
output_folder = soc_folder
cf_name = "SOC_2030"
cf_unit = "t C/ha"
reset_gpck = True

# %% [markdown]
# ### Countries

# %% [markdown]
# Regional inputs

# %%
# Inputs that change by area type
area_type = "country"
layer_name = "soc_leaf_country"
corrected_shp = gpd.read_file(project_root/'data/CountryLayers/Country_Level0/g2015_2014_0_dissolved.shp')
master_key = "ADM0_NAME"
result_key = "country"

# %% [markdown]
# Running averages

# %%
gpkg_path, df_results = mc.build_cfs_gpkg_from_rasters(
    gpckg_name="SOC_2030_country_forest_grass",
    input_folder = str(input_folder),
    output_folder = str(output_folder),
    layer_name=layer_name,
    master_gdf=corrected_shp,           # e.g., countries, subcountries, or ecoregions
    master_key=master_key,              # or 'ISO_A3', 'ADM1_NAME', 'ECO_NAME'
    result_key=result_key,              # must match the column emitted by your calc gdf
    cf_name=cf_name,
    cf_unit=cf_unit,
    area_type=area_type,
    calc_kwargs=dict(raster_band = 15, outlier_method="log1p_win", q_low = 0.01, q_high = 0.99),     
    reset_gpkg=reset_gpck,
    run_test=False,                             # Use run test to run the first 3 files
    max_workers=4
)

print(f"Wrote {df_results.shape[0]} rows into {gpkg_path}")
# Out:
# 2026-05-13 13:42:17,955 - INFO - Building 'soc_leaf_country' from rasters in c:\Users\loyola\OneDrive - World Wildlife Fund, Inc\Documents\203. Python projects\SBTN_Test\LEAFs\SOC\rasters into c:\Users\loyola\OneDrive - World Wildlife Fund, Inc\Documents\203. Python projects\SBTN_Test\LEAFs\SOC (c:\Users\loyola\OneDrive - World Wildlife Fund, Inc\Documents\203. Python projects\SBTN_Test\LEAFs\SOCSOC_2030_country_forest_grass.gpkg)
# Processing rasters (soc_leaf_country):   0%|          | 0/21 [00:00<?, ?raster/s]
# 2026-05-13 13:42:33,675 - INFO - Calculating SOC_2030 for BRDC_Boreal dry_2030y_SOC...
# Calculating SOC_2030 for BRDC_Boreal dry_2030y_SOC...
# 2026-05-13 13:42:33,676 - INFO - Calculating SOC_2030 for BRDC_Boreal moist_2030y_SOC...
# Calculating SOC_2030 for BRDC_Boreal moist_2030y_SOC...2026-05-13 13:42:33,679 - INFO - Calculating SOC_2030 for BRDC_Cold temperate dry_2030y_SOC...
#
# 2026-05-13 13:42:33,683 - INFO - Calculating SOC_2030 for BRDC_Cold temperate moist_2030y_SOC...
# Calculating SOC_2030 for BRDC_Cold temperate dry_2030y_SOC...
# Processing rasters (soc_leaf_country):   0%|          | 0/21 [00:00<?, ?raster/s]
# Calculating SOC_2030 for BRDC_Cold temperate moist_2030y_SOC...
# 2026-05-13 13:45:50,292 - INFO - Calculating SOC_2030 for BRDC_Subtropical_2030y_SOC...
# Calculating SOC_2030 for BRDC_Subtropical_2030y_SOC...
# 2026-05-13 13:46:00,402 - INFO - Calculating SOC_2030 for BRDC_Tropical_2030y_SOC...
# Calculating SOC_2030 for BRDC_Tropical_2030y_SOC...
# 2026-05-13 13:46:16,941 - INFO - Calculating SOC_2030 for BRDC_Warm temperate dry_2030y_SOC...
# Calculating SOC_2030 for BRDC_Warm temperate dry_2030y_SOC...
# 2026-05-13 13:46:58,001 - INFO - Calculating SOC_2030 for BRDC_Warm temperate moist_2030y_SOC...
# Calculating SOC_2030 for BRDC_Warm temperate moist_2030y_SOC...
# 2026-05-13 13:48:09,877 - INFO - Calculating SOC_2030 for NEEV_Boreal dry_2030y_SOC...
# Calculating SOC_2030 for NEEV_Boreal dry_2030y_SOC...
# c:\Users\loyola\OneDrive - World Wildlife Fund, Inc\Documents\203. Python projects\SBTN_Test\.venv\Lib\site-packages\rasterio\features.py:392: NotGeoreferencedWarning: Dataset has no geotransform, gcps, or rpcs. The identity matrix will be returned.
#   _rasterize(valid_shapes, out, transform, all_touched, merge_alg)
# 2026-05-13 13:49:29,842 - INFO - Calculating SOC_2030 for NEEV_Boreal moist_2030y_SOC...
# Calculating SOC_2030 for NEEV_Boreal moist_2030y_SOC...
# 2026-05-13 13:49:37,499 - INFO - Calculating SOC_2030 for NEEV_Cold temperate dry_2030y_SOC...
# Calculating SOC_2030 for NEEV_Cold temperate dry_2030y_SOC...
# 2026-05-13 13:49:59,985 - INFO - Calculating SOC_2030 for NEEV_Cold temperate moist_2030y_SOC...
# Calculating SOC_2030 for NEEV_Cold temperate moist_2030y_SOC...
# 2026-05-13 13:51:12,339 - INFO - Calculating SOC_2030 for NEEV_Subtropical_2030y_SOC...
# Calculating SOC_2030 for NEEV_Subtropical_2030y_SOC...
# 2026-05-13 13:53:06,734 - INFO - Calculating SOC_2030 for NEEV_Tropical_2030y_SOC...
# Calculating SOC_2030 for NEEV_Tropical_2030y_SOC...
# 2026-05-13 13:53:23,791 - INFO - Calculating SOC_2030 for NEEV_Warm temperate dry_2030y_SOC...
# Calculating SOC_2030 for NEEV_Warm temperate dry_2030y_SOC...
# 2026-05-13 13:53:55,126 - INFO - Calculating SOC_2030 for natural_grassland_cattle_avg_2030y_SOC...
# Calculating SOC_2030 for natural_grassland_cattle_avg_2030y_SOC...
# 2026-05-13 13:55:59,853 - INFO - Calculating SOC_2030 for natural_grassland_cattle_avg_sheep_goat_2030y_SOC...
# Calculating SOC_2030 for natural_grassland_cattle_avg_sheep_goat_2030y_SOC...
# 2026-05-13 13:56:13,164 - INFO - Calculating SOC_2030 for natural_grassland_cattle_hps_2030y_SOC...
# Calculating SOC_2030 for natural_grassland_cattle_hps_2030y_SOC...
# 2026-05-13 13:58:18,684 - INFO - Calculating SOC_2030 for natural_grassland_cattle_lps_2030y_SOC...
# Calculating SOC_2030 for natural_grassland_cattle_lps_2030y_SOC...
# 2026-05-13 13:59:47,274 - INFO - Calculating SOC_2030 for natural_grassland_goat_2030y_SOC...
# Calculating SOC_2030 for natural_grassland_goat_2030y_SOC...
# 2026-05-13 14:01:31,733 - INFO - Calculating SOC_2030 for natural_grassland_sheep_2030y_SOC...
# Calculating SOC_2030 for natural_grassland_sheep_2030y_SOC...
# 2026-05-13 14:04:06,498 - INFO - Wrote 5796 attribute rows into c:\Users\loyola\OneDrive - World Wildlife Fund, Inc\Documents\203. Python projects\SBTN_Test\LEAFs\SOCSOC_2030_country_forest_grass.gpkg (geometry layer='geometry_layer', values layer='soc_leaf_country').
# Wrote 17388 rows into c:\Users\loyola\OneDrive - World Wildlife Fund, Inc\Documents\203. Python projects\SBTN_Test\LEAFs\SOCSOC_2030_country_forest_grass.gpkg
