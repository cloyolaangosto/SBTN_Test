# %% [markdown]
# # SOC Baseline LEAFs
# This notebook documents the generation of currently available SOC LEAFs for SBTN Land v2 Land Quality Target. Full documentaion of the SOC model can be found on [SOC_Documentation](../documentation/SOC_Documentation.md) and an example of how to generate new crop SOC LEAFs on [SOC_LEAF_Example](../examples/SOC_LEAF_Example.ipynb).
#
# Here, LEAFs are generated for 1) annual crops, 2) permanent crops, and 3) forest & grassland land uses. As model generate annual outputs, only the end year is preserved, in this case 2030.

# %% [markdown]
# ## Step 1 - Data Gathering and Preparation
# As explained in SOC Documentation, several data layers need to be gathered.
#
# ### 1.1 - Soil & Weather
# Precipitation and air temperature data have been downloaded and processed. It be found under [data/](../data/). SoilGrids data have been downloaded and processed into UHTH zones in the needed format and is also available in the same folder.
#
# **🚧 TODO: Update reference 🚧**
# This data is too large to be be hosted in a github repository. Instructions into how to download it can be found on XXX
#
# ### 1.2 - Commodity Data
# #### 1.2.1 - Land use
# Land use layers have been adapted from Morais, Teixeria & Domingos (2019) and can be found under [data/land_use/](../data/land_use/). These layers include annual & permanent crops, forestry, and grasslands.

# %% [markdown]
# #### 1.2.2 - Annual & Permanent Crops
# ##### 1.2.2.1 - Yields
# Commodity yield input data from FAO has already been summarized and can be found at [data/crops/fao_crop_yields_1423.csv](../data/crops/fao_crop_yields_1423.csv) file. The needed SPAM data has been downloaded into [data/crops/spam2020V2r0_global_yield](data/crops/spam2020V2r0_global_yield) folder. For each run of the RothC model, yields per pixel are stochastically calculated using SPAM and FAO data by averaging 100 normal distribution draws, using the standard deviation per country reported by FAO for each commodity.
#
# ##### 1.2.2.2 -Irrigation, crop potential evapotranspiration, and plant cover
# Potential evapotranspiration, and thus irrigation, as well as plant cover can are calculated using prepare_crop_data_irrigation_plantcover for a single crop or  `cropcalcs.prepare_crop_scenarios_PET_PlantCover_only` for a series of crops and land management options. All needed data can be found on [data/crops](../data/crops) folder with the exception of SPAM rasters which should be indepedently downloaded.
#
# Calcualtions are performed as follows:

# %%
# Loading modules
import sbtn_leaf.RothC_Raster as rothC
from sbtn_leaf.paths import data_path, LEAFs_dir
import sbtn_leaf.map_plotting as maplot
import sbtn_leaf.cropcalcs as cropcalcs

import importlib
import polars as pl
import geopandas as gpd
import sbtn_leaf.map_calculations as mc
import matplotlib.pyplot as plt
# Out:
# Could not determine dtype for column 1, falling back to string

# %% [markdown]
# ##### Annual Crops

# %% [markdown]
# One crop example

# %%
output_crop_folder = "../data/crops/rothc_support"

# %%
# Needed filepaths
lu_filepath = "../data/land_use/lu_Irrigated_Maize_residues_left_on_the_field.tif"

# %%
# Preparing crop data
cropcalcs.prepare_crop_data_irrigation_plantcover(
    crop_name = "Maize",
    crop_type= "annual",
    crop_practice_string = "irr",
    lu_data_path = lu_filepath,
    output_data_folder = output_crop_folder,
    all_new_files=True
)
# Out:
# Creating PET raster...
# C:\Users\loyola\OneDrive - World Wildlife Fund, Inc\Documents\203. Python projects\SBTN_Test\src\sbtn_leaf\data_loader.py:216: DataOrientationWarning: Row orientation inferred during DataFrame construction. Explicitly specify the orientation by passing `orient="row"` to silence this warning.
#   table = pl.DataFrame(THERMAL_CLIMATE_ROWS, schema=["id", "TC_Name", "TC_Group"])
# Precomputing Kc curves for group: 100%|██████████| 6/6 [00:00<00:00, 72.85it/s]
#     Precomputing Kc curve for group: Tropics
#     Precomputing Kc curve for group: Subtropics summer rainfall
#     Precomputing Kc curve for group: Subtropics winter rainfall
#     Precomputing Kc curve for group: Oceanic temperate
#     Precomputing Kc curve for group: Sub-continental temperate and continental temperate
#     Precomputing Kc curve for group: Sub-continental boreal, continental boreal and polar/arctic
# Applying Kc to thremal groups: 100%|██████████| 6/6 [00:00<00:00,  6.10it/s]
# PET calculation completed for crop 'Maize' succesfully.
# Creating irrigation raster...
# Irrigation raster saved to ..\data\crops\rothc_support\Maize_irr_monthly.tif
# Creating plant cover raster...
# Plant cover raster saved to ..\data\crops\rothc_support\Maize_pc_monthly.tif
# Irrigation, PET, and plant cover rasters created for Maize, irr!!!

# %% [markdown]
# All permanent crops included

# %%
# Filepath
annual_crop_rothc_prep_fp = data_path("crops", "rothc_support", "annual_crop_rothc_dataprep_inventory.csv")

# %%
# Preparing rothc needed files
annuals_unique_data_prepared = cropcalcs.prepare_crop_scenarios_PET_PlantCover_only(annual_crop_rothc_prep_fp)
# Out:
# Creating a unique list of rasters with different land use maps...
#
# Preparing irrigation and plant cover data for Barley, irr_ron
# Creating PET raster...
# C:\Users\loyola\OneDrive - World Wildlife Fund, Inc\Documents\203. Python projects\SBTN_Test\src\sbtn_leaf\data_loader.py:216: DataOrientationWarning: Row orientation inferred during DataFrame construction. Explicitly specify the orientation by passing `orient="row"` to silence this warning.
#   table = pl.DataFrame(THERMAL_CLIMATE_ROWS, schema=["id", "TC_Name", "TC_Group"])
# PET calculation completed for crop 'Barley' succesfully.
# Creating irrigation raster...
# Irrigation raster saved to ..\data\crops\rothc_support\Barley_irr_ron_irr_monthly.tif
# Creating plant cover raster...
# Plant cover raster saved to ..\data\crops\rothc_support\Barley_irr_ron_pc_monthly.tif
# Irrigation, PET, and plant cover rasters created for Barley, irr_ron!!!
# Next!
#
# Preparing irrigation and plant cover data for Barley, irr_roff
# Creating PET raster...
# PET calculation completed for crop 'Barley' succesfully.
# Creating irrigation raster...
# Irrigation raster saved to ..\data\crops\rothc_support\Barley_irr_roff_irr_monthly.tif
# Creating plant cover raster...
# Plant cover raster saved to ..\data\crops\rothc_support\Barley_irr_roff_pc_monthly.tif
# Irrigation, PET, and plant cover rasters created for Barley, irr_roff!!!
# Next!
#
# Preparing irrigation and plant cover data for Cabbage, irr
# Creating PET raster...
# PET calculation completed for crop 'Cabbage' succesfully.
# Creating irrigation raster...
# Irrigation raster saved to ..\data\crops\rothc_support\Cabbage_irr_irr_monthly.tif
# Creating plant cover raster...
# Plant cover raster saved to ..\data\crops\rothc_support\Cabbage_irr_pc_monthly.tif
# Irrigation, PET, and plant cover rasters created for Cabbage, irr!!!
# Next!
#
# Preparing irrigation and plant cover data for Carrot, irr
# Creating PET raster...
# PET calculation completed for crop 'Carrot' succesfully.
# Creating irrigation raster...
# Irrigation raster saved to ..\data\crops\rothc_support\Carrot_irr_irr_monthly.tif
# Creating plant cover raster...
# Plant cover raster saved to ..\data\crops\rothc_support\Carrot_irr_pc_monthly.tif
# Irrigation, PET, and plant cover rasters created for Carrot, irr!!!
# Next!
#
# Preparing irrigation and plant cover data for Cotton, irr
# Creating PET raster...
# PET calculation completed for crop 'Cotton' succesfully.
# Creating irrigation raster...
# Irrigation raster saved to ..\data\crops\rothc_support\Cotton_irr_irr_monthly.tif
# Creating plant cover raster...
# Plant cover raster saved to ..\data\crops\rothc_support\Cotton_irr_pc_monthly.tif
# Irrigation, PET, and plant cover rasters created for Cotton, irr!!!
# Next!
#
# Preparing irrigation and plant cover data for Maize, irr_ron
# Creating PET raster...
# PET calculation completed for crop 'Maize' succesfully.
# Creating irrigation raster...
# Irrigation raster saved to ..\data\crops\rothc_support\Maize_irr_ron_irr_monthly.tif
# Creating plant cover raster...
# Plant cover raster saved to ..\data\crops\rothc_support\Maize_irr_ron_pc_monthly.tif
# Irrigation, PET, and plant cover rasters created for Maize, irr_ron!!!
# Next!
#
# Preparing irrigation and plant cover data for Maize, irr_roff
# Creating PET raster...
# PET calculation completed for crop 'Maize' succesfully.
# Creating irrigation raster...
# Irrigation raster saved to ..\data\crops\rothc_support\Maize_irr_roff_irr_monthly.tif
# Creating plant cover raster...
# Plant cover raster saved to ..\data\crops\rothc_support\Maize_irr_roff_pc_monthly.tif
# Irrigation, PET, and plant cover rasters created for Maize, irr_roff!!!
# Next!
#
# Preparing irrigation and plant cover data for Onion, irr
# Creating PET raster...
# PET calculation completed for crop 'Onion' succesfully.
# Creating irrigation raster...
# Irrigation raster saved to ..\data\crops\rothc_support\Onion_irr_irr_monthly.tif
# Creating plant cover raster...
# Plant cover raster saved to ..\data\crops\rothc_support\Onion_irr_pc_monthly.tif
# Irrigation, PET, and plant cover rasters created for Onion, irr!!!
# Next!
#
# Preparing irrigation and plant cover data for Potato, irr
# Creating PET raster...
# PET calculation completed for crop 'Potato' succesfully.
# Creating irrigation raster...
# Irrigation raster saved to ..\data\crops\rothc_support\Potato_irr_irr_monthly.tif
# Creating plant cover raster...
# Plant cover raster saved to ..\data\crops\rothc_support\Potato_irr_pc_monthly.tif
# Irrigation, PET, and plant cover rasters created for Potato, irr!!!
# Next!
#
# Preparing irrigation and plant cover data for Rapeseed, irr_ron
# Creating PET raster...
# PET calculation completed for crop 'Rapeseed' succesfully.
# Creating irrigation raster...
# Irrigation raster saved to ..\data\crops\rothc_support\Rapeseed_irr_ron_irr_monthly.tif
# Creating plant cover raster...
# Plant cover raster saved to ..\data\crops\rothc_support\Rapeseed_irr_ron_pc_monthly.tif
# Irrigation, PET, and plant cover rasters created for Rapeseed, irr_ron!!!
# Next!
#
# Preparing irrigation and plant cover data for Rice, irr
# Creating PET raster...
# PET calculation completed for crop 'Rice' succesfully.
# Creating irrigation raster...
# Irrigation raster saved to ..\data\crops\rothc_support\Rice_irr_irr_monthly.tif
# Creating plant cover raster...
# Plant cover raster saved to ..\data\crops\rothc_support\Rice_irr_pc_monthly.tif
# Irrigation, PET, and plant cover rasters created for Rice, irr!!!
# Next!
#
# Preparing irrigation and plant cover data for Sorghum, irr_ron
# Creating PET raster...
# PET calculation completed for crop 'Sorghum' succesfully.
# Creating irrigation raster...
# Irrigation raster saved to ..\data\crops\rothc_support\Sorghum_irr_ron_irr_monthly.tif
# Creating plant cover raster...
# Plant cover raster saved to ..\data\crops\rothc_support\Sorghum_irr_ron_pc_monthly.tif
# Irrigation, PET, and plant cover rasters created for Sorghum, irr_ron!!!
# Next!
#
# Preparing irrigation and plant cover data for Sorghum, irr_roff
# Creating PET raster...
# PET calculation completed for crop 'Sorghum' succesfully.
# Creating irrigation raster...
# Irrigation raster saved to ..\data\crops\rothc_support\Sorghum_irr_roff_irr_monthly.tif
# Creating plant cover raster...
# Plant cover raster saved to ..\data\crops\rothc_support\Sorghum_irr_roff_pc_monthly.tif
# Irrigation, PET, and plant cover rasters created for Sorghum, irr_roff!!!
# Next!
#
# Preparing irrigation and plant cover data for Soybean, irr
# Creating PET raster...
# PET calculation completed for crop 'Soybean' succesfully.
# Creating irrigation raster...
# Irrigation raster saved to ..\data\crops\rothc_support\Soybean_irr_irr_monthly.tif
# Creating plant cover raster...
# Plant cover raster saved to ..\data\crops\rothc_support\Soybean_irr_pc_monthly.tif
# Irrigation, PET, and plant cover rasters created for Soybean, irr!!!
# Next!
#
# Preparing irrigation and plant cover data for Sugar beet, irr
# Creating PET raster...
# PET calculation completed for crop 'Sugar beet' succesfully.
# Creating irrigation raster...
# Irrigation raster saved to ..\data\crops\rothc_support\Sugar beet_irr_irr_monthly.tif
# Creating plant cover raster...
# Plant cover raster saved to ..\data\crops\rothc_support\Sugar beet_irr_pc_monthly.tif
# Irrigation, PET, and plant cover rasters created for Sugar beet, irr!!!
# Next!
#
# Preparing irrigation and plant cover data for Sunflower, irr
# Creating PET raster...
# PET calculation completed for crop 'Sunflower' succesfully.
# Creating irrigation raster...
# Irrigation raster saved to ..\data\crops\rothc_support\Sunflower_irr_irr_monthly.tif
# Creating plant cover raster...
# Plant cover raster saved to ..\data\crops\rothc_support\Sunflower_irr_pc_monthly.tif
# Irrigation, PET, and plant cover rasters created for Sunflower, irr!!!
# Next!
#
# Preparing irrigation and plant cover data for Sweet potato, irr
# Creating PET raster...
# PET calculation completed for crop 'Sweet potato' succesfully.
# Creating irrigation raster...
# Irrigation raster saved to ..\data\crops\rothc_support\Sweet potato_irr_irr_monthly.tif
# Creating plant cover raster...
# Plant cover raster saved to ..\data\crops\rothc_support\Sweet potato_irr_pc_monthly.tif
# Irrigation, PET, and plant cover rasters created for Sweet potato, irr!!!
# Next!
#
# Preparing irrigation and plant cover data for Tobacco, irr
# Creating PET raster...
# PET calculation completed for crop 'Tobacco' succesfully.
# Creating irrigation raster...
# Irrigation raster saved to ..\data\crops\rothc_support\Tobacco_irr_irr_monthly.tif
# Creating plant cover raster...
# Plant cover raster saved to ..\data\crops\rothc_support\Tobacco_irr_pc_monthly.tif
# Irrigation, PET, and plant cover rasters created for Tobacco, irr!!!
# Next!
#
# Preparing irrigation and plant cover data for Tomato, irr
# Creating PET raster...
# PET calculation completed for crop 'Tomato' succesfully.
# Creating irrigation raster...
# Irrigation raster saved to ..\data\crops\rothc_support\Tomato_irr_irr_monthly.tif
# Creating plant cover raster...
# Plant cover raster saved to ..\data\crops\rothc_support\Tomato_irr_pc_monthly.tif
# Irrigation, PET, and plant cover rasters created for Tomato, irr!!!
# Next!
#
# Preparing irrigation and plant cover data for Wheat, irr_ron
# Creating PET raster...
# PET calculation completed for crop 'Wheat' succesfully.
# Creating irrigation raster...
# Irrigation raster saved to ..\data\crops\rothc_support\Wheat_irr_ron_irr_monthly.tif
# Creating plant cover raster...
# Plant cover raster saved to ..\data\crops\rothc_support\Wheat_irr_ron_pc_monthly.tif
# Irrigation, PET, and plant cover rasters created for Wheat, irr_ron!!!
# Next!
#
# Preparing irrigation and plant cover data for Wheat, irr_roff
# Creating PET raster...
# PET calculation completed for crop 'Wheat' succesfully.
# Creating irrigation raster...
# Irrigation raster saved to ..\data\crops\rothc_support\Wheat_irr_roff_irr_monthly.tif
# Creating plant cover raster...
# Plant cover raster saved to ..\data\crops\rothc_support\Wheat_irr_roff_pc_monthly.tif
# Irrigation, PET, and plant cover rasters created for Wheat, irr_roff!!!
# Next!
#
# Preparing irrigation and plant cover data for Barley, rf_ron
# Creating PET raster...
# PET calculation completed for crop 'Barley' succesfully.
# Irrigation not needed. Skipping...
# Creating plant cover raster...
# Plant cover raster saved to ..\data\crops\rothc_support\Barley_rf_ron_pc_monthly.tif
# Irrigation, PET, and plant cover rasters created for Barley, rf_ron!!!
# Next!
#
# Preparing irrigation and plant cover data for Barley, rf_roff
# Creating PET raster...
# PET calculation completed for crop 'Barley' succesfully.
# Irrigation not needed. Skipping...
# Creating plant cover raster...
# Plant cover raster saved to ..\data\crops\rothc_support\Barley_rf_roff_pc_monthly.tif
# Irrigation, PET, and plant cover rasters created for Barley, rf_roff!!!
# Next!
#
# Preparing irrigation and plant cover data for Cotton, rf
# Creating PET raster...
# PET calculation completed for crop 'Cotton' succesfully.
# Irrigation not needed. Skipping...
# Creating plant cover raster...
# Plant cover raster saved to ..\data\crops\rothc_support\Cotton_rf_pc_monthly.tif
# Irrigation, PET, and plant cover rasters created for Cotton, rf!!!
# Next!
#
# Preparing irrigation and plant cover data for Maize, rf
# Creating PET raster...
# PET calculation completed for crop 'Maize' succesfully.
# Irrigation not needed. Skipping...
# Creating plant cover raster...
# Plant cover raster saved to ..\data\crops\rothc_support\Maize_rf_pc_monthly.tif
# Irrigation, PET, and plant cover rasters created for Maize, rf!!!
# Next!
#
# Preparing irrigation and plant cover data for Potato, rf
# Creating PET raster...
# PET calculation completed for crop 'Potato' succesfully.
# Irrigation not needed. Skipping...
# Creating plant cover raster...
# Plant cover raster saved to ..\data\crops\rothc_support\Potato_rf_pc_monthly.tif
# Irrigation, PET, and plant cover rasters created for Potato, rf!!!
# Next!
#
# Preparing irrigation and plant cover data for Rapeseed, rf_ron
# Creating PET raster...
# PET calculation completed for crop 'Rapeseed' succesfully.
# Irrigation not needed. Skipping...
# Creating plant cover raster...
# Plant cover raster saved to ..\data\crops\rothc_support\Rapeseed_rf_ron_pc_monthly.tif
# Irrigation, PET, and plant cover rasters created for Rapeseed, rf_ron!!!
# Next!
#
# Preparing irrigation and plant cover data for Sorghum, rf
# Creating PET raster...
# PET calculation completed for crop 'Sorghum' succesfully.
# Irrigation not needed. Skipping...
# Creating plant cover raster...
# Plant cover raster saved to ..\data\crops\rothc_support\Sorghum_rf_pc_monthly.tif
# Irrigation, PET, and plant cover rasters created for Sorghum, rf!!!
# Next!
#
# Preparing irrigation and plant cover data for Sorghum, rf
# Creating PET raster...
# PET calculation completed for crop 'Sorghum' succesfully.
# Irrigation not needed. Skipping...
# Creating plant cover raster...
# Plant cover raster saved to ..\data\crops\rothc_support\Sorghum_rf_pc_monthly.tif
# Irrigation, PET, and plant cover rasters created for Sorghum, rf!!!
# Next!
#
# Preparing irrigation and plant cover data for Soybean, rf
# Creating PET raster...
# PET calculation completed for crop 'Soybean' succesfully.
# Irrigation not needed. Skipping...
# Creating plant cover raster...
# Plant cover raster saved to ..\data\crops\rothc_support\Soybean_rf_pc_monthly.tif
# Irrigation, PET, and plant cover rasters created for Soybean, rf!!!
# Next!
#
# Preparing irrigation and plant cover data for Sunflower, rf
# Creating PET raster...
# PET calculation completed for crop 'Sunflower' succesfully.
# Irrigation not needed. Skipping...
# Creating plant cover raster...
# Plant cover raster saved to ..\data\crops\rothc_support\Sunflower_rf_pc_monthly.tif
# Irrigation, PET, and plant cover rasters created for Sunflower, rf!!!
# Next!
#
# Preparing irrigation and plant cover data for Sweet potato, rf
# Creating PET raster...
# PET calculation completed for crop 'Sweet potato' succesfully.
# Irrigation not needed. Skipping...
# Creating plant cover raster...
# Plant cover raster saved to ..\data\crops\rothc_support\Sweet potato_rf_pc_monthly.tif
# Irrigation, PET, and plant cover rasters created for Sweet potato, rf!!!
# Next!
#
# Preparing irrigation and plant cover data for Tobacco, rf
# Creating PET raster...
# PET calculation completed for crop 'Tobacco' succesfully.
# Irrigation not needed. Skipping...
# Creating plant cover raster...
# Plant cover raster saved to ..\data\crops\rothc_support\Tobacco_rf_pc_monthly.tif
# Irrigation, PET, and plant cover rasters created for Tobacco, rf!!!
# Next!
#
# Preparing irrigation and plant cover data for Tomato, rf
# Creating PET raster...
# PET calculation completed for crop 'Tomato' succesfully.
# Irrigation not needed. Skipping...
# Creating plant cover raster...
# Plant cover raster saved to ..\data\crops\rothc_support\Tomato_rf_pc_monthly.tif
# Irrigation, PET, and plant cover rasters created for Tomato, rf!!!
# Next!
#
# Preparing irrigation and plant cover data for Wheat, rf_roff
# Creating PET raster...
# PET calculation completed for crop 'Wheat' succesfully.
# Irrigation not needed. Skipping...
# Creating plant cover raster...
# Plant cover raster saved to ..\data\crops\rothc_support\Wheat_rf_roff_pc_monthly.tif
# Irrigation, PET, and plant cover rasters created for Wheat, rf_roff!!!
# Next!
#
# Preparing irrigation and plant cover data for Groundnut, irr
# Creating PET raster...
# PET calculation completed for crop 'Groundnut' succesfully.
# Creating irrigation raster...
# Irrigation raster saved to ..\data\crops\rothc_support\Groundnut_irr_irr_monthly.tif
# Creating plant cover raster...
# Plant cover raster saved to ..\data\crops\rothc_support\Groundnut_irr_pc_monthly.tif
# Irrigation, PET, and plant cover rasters created for Groundnut, irr!!!
# Next!
#
# Preparing irrigation and plant cover data for Rapeseed, irr_roff
# Creating PET raster...
# PET calculation completed for crop 'Rapeseed' succesfully.
# Creating irrigation raster...
# Irrigation raster saved to ..\data\crops\rothc_support\Rapeseed_irr_roff_irr_monthly.tif
# Creating plant cover raster...
# Plant cover raster saved to ..\data\crops\rothc_support\Rapeseed_irr_roff_pc_monthly.tif
# Irrigation, PET, and plant cover rasters created for Rapeseed, irr_roff!!!
# Next!

# %% [markdown]
# Checking which scenarios were created...

# %%
annuals_unique_data_prepared.sort_values(by=["crop_name", "crop_practice_string"])
# Out:
#        crop_name crop_type crop_practice_string  \
# 1         Barley    annual             irr_roff
# 0         Barley    annual              irr_ron
# 22        Barley    annual              rf_roff
# 21        Barley    annual               rf_ron
# 2        Cabbage    annual                  irr
# 3         Carrot    annual                  irr
# 4         Cotton    annual                  irr
# 23        Cotton    annual                   rf
# 35     Groundnut    annual                  irr
# 6          Maize    annual             irr_roff
# 5          Maize    annual              irr_ron
# 24         Maize    annual                   rf
# 7          Onion    annual                  irr
# 8         Potato    annual                  irr
# 25        Potato    annual                   rf
# 36      Rapeseed    annual             irr_roff
# 9       Rapeseed    annual              irr_ron
# 26      Rapeseed    annual               rf_ron
# 10          Rice    annual                  irr
# 12       Sorghum    annual             irr_roff
# 11       Sorghum    annual              irr_ron
# 27       Sorghum    annual                   rf
# 28       Sorghum    annual                   rf
# 13       Soybean    annual                  irr
# 29       Soybean    annual                   rf
# 14    Sugar beet    annual                  irr
# 15     Sunflower    annual                  irr
# 30     Sunflower    annual                   rf
# 16  Sweet potato    annual                  irr
# 31  Sweet potato    annual                   rf
# 17       Tobacco    annual                  irr
# 32       Tobacco    annual                   rf
# 18        Tomato    annual                  irr
# 33        Tomato    annual                   rf
# 20         Wheat    annual             irr_roff
# 19         Wheat    annual              irr_ron
# 34         Wheat    annual              rf_roff
#
#                                               lu_path  \
# 1   ../data/land_use/lu_Irrigated_Barley_residues_...
# 0   ../data/land_use/lu_Irrigated_Barley_residues_...
# 22  ../data/land_use/lu_Rainfed_Barley_residues_re...
# 21  ../data/land_use/lu_Rainfed_Barley_residues_le...
# 2          ../data/land_use/lu_Irrigated_Cabbages.tif
# 3           ../data/land_use/lu_Irrigated_Carrots.tif
# 4            ../data/land_use/lu_Irrigated_cotton.tif
# 23             ../data/land_use/lu_Rainfed_cotton.tif
# 35       ../data/land_use/lu_Irrigated_Groundnuts.tif
# 6   ../data/land_use/lu_Irrigated_Maize_residues_r...
# 5   ../data/land_use/lu_Irrigated_Maize_residues_l...
# 24  ../data/land_use/lu_Rainfed_Maize_residues_rem...
# 7            ../data/land_use/lu_Irrigated_Onions.tif
# 8          ../data/land_use/lu_Irrigated_Potatoes.tif
# 25           ../data/land_use/lu_Rainfed_Potatoes.tif
# 36  ../data/land_use/lu_Irrigated_Rapeseed_residue...
# 9   ../data/land_use/lu_Irrigated_Rapeseed_residue...
# 26  ../data/land_use/lu_Rainfed_Rapeseed_residues_...
# 10             ../data/land_use/lu_Irrigated_Rice.tif
# 12  ../data/land_use/lu_Irrigated_Sorghum_residues...
# 11  ../data/land_use/lu_Irrigated_Sorghum_residues...
# 27  ../data/land_use/lu_Rainfed_Sorghum_residues_l...
# 28  ../data/land_use/lu_Rainfed_Sorghum_residues_r...
# 13         ../data/land_use/lu_Irrigated_Soybeans.tif
# 29           ../data/land_use/lu_Rainfed_Soybeans.tif
# 14        ../data/land_use/lu_Irrigated_Sugarbeet.tif
# 15        ../data/land_use/lu_Irrigated_Sunflower.tif
# 30          ../data/land_use/lu_Rainfed_Sunflower.tif
# 16   ../data/land_use/lu_Irrigated_Sweet_potatoes.tif
# 31     ../data/land_use/lu_Rainfed_Sweet_potatoes.tif
# 17          ../data/land_use/lu_Irrigated_Tobacco.tif
# 32            ../data/land_use/lu_Rainfed_Tobacco.tif
# 18         ../data/land_use/lu_Irrigated_Tomatoes.tif
# 33           ../data/land_use/lu_Rainfed_Tomatoes.tif
# 20  ../data/land_use/lu_Irrigated_Wheat_residues_r...
# 19  ../data/land_use/lu_Irrigated_Wheat_residues_l...
# 34  ../data/land_use/lu_Rainfed_Wheat_residues_rem...
#
#                                              pet_path  \
# 1   ..\data\crops\rothc_support\Barley_irr_roff_pe...
# 0   ..\data\crops\rothc_support\Barley_irr_ron_pet...
# 22  ..\data\crops\rothc_support\Barley_rf_roff_pet...
# 21  ..\data\crops\rothc_support\Barley_rf_ron_pet_...
# 2   ..\data\crops\rothc_support\Cabbage_irr_pet_mo...
# 3   ..\data\crops\rothc_support\Carrot_irr_pet_mon...
# 4   ..\data\crops\rothc_support\Cotton_irr_pet_mon...
# 23  ..\data\crops\rothc_support\Cotton_rf_pet_mont...
# 35  ..\data\crops\rothc_support\Groundnut_irr_pet_...
# 6   ..\data\crops\rothc_support\Maize_irr_roff_pet...
# 5   ..\data\crops\rothc_support\Maize_irr_ron_pet_...
# 24  ..\data\crops\rothc_support\Maize_rf_pet_month...
# 7   ..\data\crops\rothc_support\Onion_irr_pet_mont...
# 8   ..\data\crops\rothc_support\Potato_irr_pet_mon...
# 25  ..\data\crops\rothc_support\Potato_rf_pet_mont...
# 36  ..\data\crops\rothc_support\Rapeseed_irr_roff_...
# 9   ..\data\crops\rothc_support\Rapeseed_irr_ron_p...
# 26  ..\data\crops\rothc_support\Rapeseed_rf_ron_pe...
# 10  ..\data\crops\rothc_support\Rice_irr_pet_month...
# 12  ..\data\crops\rothc_support\Sorghum_irr_roff_p...
# 11  ..\data\crops\rothc_support\Sorghum_irr_ron_pe...
# 27  ..\data\crops\rothc_support\Sorghum_rf_pet_mon...
# 28  ..\data\crops\rothc_support\Sorghum_rf_pet_mon...
# 13  ..\data\crops\rothc_support\Soybean_irr_pet_mo...
# 29  ..\data\crops\rothc_support\Soybean_rf_pet_mon...
# 14  ..\data\crops\rothc_support\Sugar beet_irr_pet...
# 15  ..\data\crops\rothc_support\Sunflower_irr_pet_...
# 30  ..\data\crops\rothc_support\Sunflower_rf_pet_m...
# 16  ..\data\crops\rothc_support\Sweet potato_irr_p...
# 31  ..\data\crops\rothc_support\Sweet potato_rf_pe...
# 17  ..\data\crops\rothc_support\Tobacco_irr_pet_mo...
# 32  ..\data\crops\rothc_support\Tobacco_rf_pet_mon...
# 18  ..\data\crops\rothc_support\Tomato_irr_pet_mon...
# 33  ..\data\crops\rothc_support\Tomato_rf_pet_mont...
# 20  ..\data\crops\rothc_support\Wheat_irr_roff_pet...
# 19  ..\data\crops\rothc_support\Wheat_irr_ron_pet_...
# 34  ..\data\crops\rothc_support\Wheat_rf_roff_pet_...
#
#                                              irr_path  \
# 1   ..\data\crops\rothc_support\Barley_irr_roff_ir...
# 0   ..\data\crops\rothc_support\Barley_irr_ron_irr...
# 22                                               None
# 21                                               None
# 2   ..\data\crops\rothc_support\Cabbage_irr_irr_mo...
# 3   ..\data\crops\rothc_support\Carrot_irr_irr_mon...
# 4   ..\data\crops\rothc_support\Cotton_irr_irr_mon...
# 23                                               None
# 35  ..\data\crops\rothc_support\Groundnut_irr_irr_...
# 6   ..\data\crops\rothc_support\Maize_irr_roff_irr...
# 5   ..\data\crops\rothc_support\Maize_irr_ron_irr_...
# 24                                               None
# 7   ..\data\crops\rothc_support\Onion_irr_irr_mont...
# 8   ..\data\crops\rothc_support\Potato_irr_irr_mon...
# 25                                               None
# 36  ..\data\crops\rothc_support\Rapeseed_irr_roff_...
# 9   ..\data\crops\rothc_support\Rapeseed_irr_ron_i...
# 26                                               None
# 10  ..\data\crops\rothc_support\Rice_irr_irr_month...
# 12  ..\data\crops\rothc_support\Sorghum_irr_roff_i...
# 11  ..\data\crops\rothc_support\Sorghum_irr_ron_ir...
# 27                                               None
# 28                                               None
# 13  ..\data\crops\rothc_support\Soybean_irr_irr_mo...
# 29                                               None
# 14  ..\data\crops\rothc_support\Sugar beet_irr_irr...
# 15  ..\data\crops\rothc_support\Sunflower_irr_irr_...
# 30                                               None
# 16  ..\data\crops\rothc_support\Sweet potato_irr_i...
# 31                                               None
# 17  ..\data\crops\rothc_support\Tobacco_irr_irr_mo...
# 32                                               None
# 18  ..\data\crops\rothc_support\Tomato_irr_irr_mon...
# 33                                               None
# 20  ..\data\crops\rothc_support\Wheat_irr_roff_irr...
# 19  ..\data\crops\rothc_support\Wheat_irr_ron_irr_...
# 34                                               None
#
#                                       plantcover_path
# 1   ..\data\crops\rothc_support\Barley_irr_roff_pc...
# 0   ..\data\crops\rothc_support\Barley_irr_ron_pc_...
# 22  ..\data\crops\rothc_support\Barley_rf_roff_pc_...
# 21  ..\data\crops\rothc_support\Barley_rf_ron_pc_m...
# 2   ..\data\crops\rothc_support\Cabbage_irr_pc_mon...
# 3   ..\data\crops\rothc_support\Carrot_irr_pc_mont...
# 4   ..\data\crops\rothc_support\Cotton_irr_pc_mont...
# 23  ..\data\crops\rothc_support\Cotton_rf_pc_month...
# 35  ..\data\crops\rothc_support\Groundnut_irr_pc_m...
# 6   ..\data\crops\rothc_support\Maize_irr_roff_pc_...
# 5   ..\data\crops\rothc_support\Maize_irr_ron_pc_m...
# 24  ..\data\crops\rothc_support\Maize_rf_pc_monthl...
# 7   ..\data\crops\rothc_support\Onion_irr_pc_month...
# 8   ..\data\crops\rothc_support\Potato_irr_pc_mont...
# 25  ..\data\crops\rothc_support\Potato_rf_pc_month...
# 36  ..\data\crops\rothc_support\Rapeseed_irr_roff_...
# 9   ..\data\crops\rothc_support\Rapeseed_irr_ron_p...
# 26  ..\data\crops\rothc_support\Rapeseed_rf_ron_pc...
# 10  ..\data\crops\rothc_support\Rice_irr_pc_monthl...
# 12  ..\data\crops\rothc_support\Sorghum_irr_roff_p...
# 11  ..\data\crops\rothc_support\Sorghum_irr_ron_pc...
# 27  ..\data\crops\rothc_support\Sorghum_rf_pc_mont...
# 28  ..\data\crops\rothc_support\Sorghum_rf_pc_mont...
# 13  ..\data\crops\rothc_support\Soybean_irr_pc_mon...
# 29  ..\data\crops\rothc_support\Soybean_rf_pc_mont...
# 14  ..\data\crops\rothc_support\Sugar beet_irr_pc_...
# 15  ..\data\crops\rothc_support\Sunflower_irr_pc_m...
# 30  ..\data\crops\rothc_support\Sunflower_rf_pc_mo...
# 16  ..\data\crops\rothc_support\Sweet potato_irr_p...
# 31  ..\data\crops\rothc_support\Sweet potato_rf_pc...
# 17  ..\data\crops\rothc_support\Tobacco_irr_pc_mon...
# 32  ..\data\crops\rothc_support\Tobacco_rf_pc_mont...
# 18  ..\data\crops\rothc_support\Tomato_irr_pc_mont...
# 33  ..\data\crops\rothc_support\Tomato_rf_pc_month...
# 20  ..\data\crops\rothc_support\Wheat_irr_roff_pc_...
# 19  ..\data\crops\rothc_support\Wheat_irr_ron_pc_m...
# 34  ..\data\crops\rothc_support\Wheat_rf_roff_pc_m...

# %% [markdown]
# Saving it to create easily the next set of data for rothC runs...

# %%
annuals_unique_data_prepared.to_csv("../data/crops/rothc_support/annual_crops_data_path.csv", sep=";", index=False)

# %% [markdown]
# ##### Permanent Crops

# %% [markdown]
# One crop example

# %%
# Needed filepaths
lu_filepath = "../data/land_use/lu_Irrigated_Coffee.tif"
spam_coffee_all = "../data/crops/spam2020V2r0_global_yield/spam2020_V2r0_global_Y_COFF_A.tif"
spam_coffee_irr = "../data/crops/spam2020V2r0_global_yield/spam2020_V2r0_global_Y_COFF_I.tif"
spam_coffee_rain = "../data/crops/spam2020V2r0_global_yield/spam2020_V2r0_global_Y_COFF_R.tif"

# %%
cropcalcs.prepare_crop_data_irrigation_plantcover(
    crop_name = "Coffee",
    crop_type= "permanent",
    crop_practice_string = "irr",
    lu_data_path = lu_filepath,
    output_data_folder = output_crop_folder,
    all_new_files=True
)
# Out:
# Creating PET raster...
# Precomputing Kc curves for group: 100%|██████████| 6/6 [00:00<00:00, 68.92it/s]
#     Precomputing Kc curve for group: Tropics
#     Precomputing Kc curve for group: Subtropics summer rainfall
#     Precomputing Kc curve for group: Subtropics winter rainfall
#     Precomputing Kc curve for group: Oceanic temperate
#     Precomputing Kc curve for group: Sub-continental temperate and continental temperate
#     Precomputing Kc curve for group: Sub-continental boreal, continental boreal and polar/arctic
# Applying Kc to thremal groups: 100%|██████████| 6/6 [00:00<00:00, 18.17it/s]
# PET calculation completed for crop 'Coffee' succesfully.
# Creating irrigation raster...
# Irrigation raster saved to ..\data\crops\rothc_support\Coffee_irr_monthly.tif
# Creating plant cover raster...
# Plant cover raster saved to ..\data\crops\rothc_support\Coffee_pc_monthly.tif
# Irrigation, PET, and plant cover rasters created for Coffee, irr!!!

# %% [markdown]
# All permanent crops included

# %%
permanent_crop_rothc_prep_fp = data_path("crops", "rothc_support", "permanent_crop_rothc_dataprep_inventory.csv")

# %%
perm_unique_data_prepared = cropcalcs.prepare_crop_scenarios_PET_PlantCover_only(permanent_crop_rothc_prep_fp)
# Out:
# Creating a unique list of rasters with different land use maps...
#
# Preparing irrigation and plant cover data for Apple, irr
# Creating PET raster...
# PET calculation completed for crop 'Apple' succesfully.
# Creating irrigation raster...
# Irrigation raster saved to ..\data\crops\rothc_support\Apple_irr_irr_monthly.tif
# Creating plant cover raster...
# Plant cover raster saved to ..\data\crops\rothc_support\Apple_irr_pc_monthly.tif
# Irrigation, PET, and plant cover rasters created for Apple, irr!!!
# Next!
#
# Preparing irrigation and plant cover data for Banana, irr
# Creating PET raster...
# PET calculation completed for crop 'Banana' succesfully.
# Creating irrigation raster...
# Irrigation raster saved to ..\data\crops\rothc_support\Banana_irr_irr_monthly.tif
# Creating plant cover raster...
# Plant cover raster saved to ..\data\crops\rothc_support\Banana_irr_pc_monthly.tif
# Irrigation, PET, and plant cover rasters created for Banana, irr!!!
# Next!
#
# Preparing irrigation and plant cover data for Cocoa, irr
# Creating PET raster...
# PET calculation completed for crop 'Cocoa' succesfully.
# Creating irrigation raster...
# Irrigation raster saved to ..\data\crops\rothc_support\Cocoa_irr_irr_monthly.tif
# Creating plant cover raster...
# Plant cover raster saved to ..\data\crops\rothc_support\Cocoa_irr_pc_monthly.tif
# Irrigation, PET, and plant cover rasters created for Cocoa, irr!!!
# Next!
#
# Preparing irrigation and plant cover data for Coconut, irr
# Creating PET raster...
# PET calculation completed for crop 'Coconut' succesfully.
# Creating irrigation raster...
# Irrigation raster saved to ..\data\crops\rothc_support\Coconut_irr_irr_monthly.tif
# Creating plant cover raster...
# Plant cover raster saved to ..\data\crops\rothc_support\Coconut_irr_pc_monthly.tif
# Irrigation, PET, and plant cover rasters created for Coconut, irr!!!
# Next!
#
# Preparing irrigation and plant cover data for Coffee, irr
# Creating PET raster...
# PET calculation completed for crop 'Coffee' succesfully.
# Creating irrigation raster...
# Irrigation raster saved to ..\data\crops\rothc_support\Coffee_irr_irr_monthly.tif
# Creating plant cover raster...
# Plant cover raster saved to ..\data\crops\rothc_support\Coffee_irr_pc_monthly.tif
# Irrigation, PET, and plant cover rasters created for Coffee, irr!!!
# Next!
#
# Preparing irrigation and plant cover data for Grapes, irr
# Creating PET raster...
# PET calculation completed for crop 'Grapes' succesfully.
# Creating irrigation raster...
# Irrigation raster saved to ..\data\crops\rothc_support\Grapes_irr_irr_monthly.tif
# Creating plant cover raster...
# Plant cover raster saved to ..\data\crops\rothc_support\Grapes_irr_pc_monthly.tif
# Irrigation, PET, and plant cover rasters created for Grapes, irr!!!
# Next!
#
# Preparing irrigation and plant cover data for Oil palm, irr
# Creating PET raster...
# PET calculation completed for crop 'Oil palm' succesfully.
# Creating irrigation raster...
# Irrigation raster saved to ..\data\crops\rothc_support\Oil palm_irr_irr_monthly.tif
# Creating plant cover raster...
# Plant cover raster saved to ..\data\crops\rothc_support\Oil palm_irr_pc_monthly.tif
# Irrigation, PET, and plant cover rasters created for Oil palm, irr!!!
# Next!
#
# Preparing irrigation and plant cover data for Olive, irr
# Creating PET raster...
# PET calculation completed for crop 'Olive' succesfully.
# Creating irrigation raster...
# Irrigation raster saved to ..\data\crops\rothc_support\Olive_irr_irr_monthly.tif
# Creating plant cover raster...
# Plant cover raster saved to ..\data\crops\rothc_support\Olive_irr_pc_monthly.tif
# Irrigation, PET, and plant cover rasters created for Olive, irr!!!
# Next!
#
# Preparing irrigation and plant cover data for Orange, irr
# Creating PET raster...
# PET calculation completed for crop 'Orange' succesfully.
# Creating irrigation raster...
# Irrigation raster saved to ..\data\crops\rothc_support\Orange_irr_irr_monthly.tif
# Creating plant cover raster...
# Plant cover raster saved to ..\data\crops\rothc_support\Orange_irr_pc_monthly.tif
# Irrigation, PET, and plant cover rasters created for Orange, irr!!!
# Next!
#
# Preparing irrigation and plant cover data for Apple, rf
# Creating PET raster...
# PET calculation completed for crop 'Apple' succesfully.
# Irrigation not needed. Skipping...
# Creating plant cover raster...
# Plant cover raster saved to ..\data\crops\rothc_support\Apple_rf_pc_monthly.tif
# Irrigation, PET, and plant cover rasters created for Apple, rf!!!
# Next!
#
# Preparing irrigation and plant cover data for Banana, rf
# Creating PET raster...
# PET calculation completed for crop 'Banana' succesfully.
# Irrigation not needed. Skipping...
# Creating plant cover raster...
# Plant cover raster saved to ..\data\crops\rothc_support\Banana_rf_pc_monthly.tif
# Irrigation, PET, and plant cover rasters created for Banana, rf!!!
# Next!
#
# Preparing irrigation and plant cover data for Cocoa, rf
# Creating PET raster...
# PET calculation completed for crop 'Cocoa' succesfully.
# Irrigation not needed. Skipping...
# Creating plant cover raster...
# Plant cover raster saved to ..\data\crops\rothc_support\Cocoa_rf_pc_monthly.tif
# Irrigation, PET, and plant cover rasters created for Cocoa, rf!!!
# Next!
#
# Preparing irrigation and plant cover data for Coconut, rf
# Creating PET raster...
# PET calculation completed for crop 'Coconut' succesfully.
# Irrigation not needed. Skipping...
# Creating plant cover raster...
# Plant cover raster saved to ..\data\crops\rothc_support\Coconut_rf_pc_monthly.tif
# Irrigation, PET, and plant cover rasters created for Coconut, rf!!!
# Next!
#
# Preparing irrigation and plant cover data for Coffee, rf
# Creating PET raster...
# PET calculation completed for crop 'Coffee' succesfully.
# Irrigation not needed. Skipping...
# Creating plant cover raster...
# Plant cover raster saved to ..\data\crops\rothc_support\Coffee_rf_pc_monthly.tif
# Irrigation, PET, and plant cover rasters created for Coffee, rf!!!
# Next!
#
# Preparing irrigation and plant cover data for Grapes, rf
# Creating PET raster...
# PET calculation completed for crop 'Grapes' succesfully.
# Irrigation not needed. Skipping...
# Creating plant cover raster...
# Plant cover raster saved to ..\data\crops\rothc_support\Grapes_rf_pc_monthly.tif
# Irrigation, PET, and plant cover rasters created for Grapes, rf!!!
# Next!
#
# Preparing irrigation and plant cover data for Olive, rf
# Creating PET raster...
# PET calculation completed for crop 'Olive' succesfully.
# Irrigation not needed. Skipping...
# Creating plant cover raster...
# Plant cover raster saved to ..\data\crops\rothc_support\Olive_rf_pc_monthly.tif
# Irrigation, PET, and plant cover rasters created for Olive, rf!!!
# Next!
#
# Preparing irrigation and plant cover data for Orange, rf
# Creating PET raster...
# PET calculation completed for crop 'Orange' succesfully.
# Irrigation not needed. Skipping...
# Creating plant cover raster...
# Plant cover raster saved to ..\data\crops\rothc_support\Orange_rf_pc_monthly.tif
# Irrigation, PET, and plant cover rasters created for Orange, rf!!!
# Next!
#
# Preparing irrigation and plant cover data for Sugarcane, irr
# Creating PET raster...
# PET calculation completed for crop 'Sugarcane' succesfully.
# Creating irrigation raster...
# Irrigation raster saved to ..\data\crops\rothc_support\Sugarcane_irr_irr_monthly.tif
# Creating plant cover raster...
# Plant cover raster saved to ..\data\crops\rothc_support\Sugarcane_irr_pc_monthly.tif
# Irrigation, PET, and plant cover rasters created for Sugarcane, irr!!!
# Next!
#
# Preparing irrigation and plant cover data for Sugarcane, rf
# Creating PET raster...
# PET calculation completed for crop 'Sugarcane' succesfully.
# Irrigation not needed. Skipping...
# Creating plant cover raster...
# Plant cover raster saved to ..\data\crops\rothc_support\Sugarcane_rf_pc_monthly.tif
# Irrigation, PET, and plant cover rasters created for Sugarcane, rf!!!
# Next!

# %% [markdown]
# Storing data path created

# %%
perm_unique_data_prepared
# Out:
#     crop_name  crop_type crop_practice_string  \
# 0       Apple  permanent                  irr
# 1      Banana  permanent                  irr
# 2       Cocoa  permanent                  irr
# 3     Coconut  permanent                  irr
# 4      Coffee  permanent                  irr
# 5      Grapes  permanent                  irr
# 6    Oil palm  permanent                  irr
# 7       Olive  permanent                  irr
# 8      Orange  permanent                  irr
# 9       Apple  permanent                   rf
# 10     Banana  permanent                   rf
# 11      Cocoa  permanent                   rf
# 12    Coconut  permanent                   rf
# 13     Coffee  permanent                   rf
# 14     Grapes  permanent                   rf
# 15      Olive  permanent                   rf
# 16     Orange  permanent                   rf
# 17  Sugarcane  permanent                  irr
# 18  Sugarcane  permanent                   rf
#
#                                         lu_path  \
# 0      ../data/land_use/lu_Irrigated_Apples.tif
# 1     ../data/land_use/lu_Irrigated_Bananas.tif
# 2       ../data/land_use/lu_Irrigated_Cocoa.tif
# 3    ../data/land_use/lu_Irrigated_Coconuts.tif
# 4      ../data/land_use/lu_Irrigated_Coffee.tif
# 5      ../data/land_use/lu_Irrigated_Grapes.tif
# 6    ../data/land_use/lu_Irrigated_Oil_palm.tif
# 7      ../data/land_use/lu_Irrigated_Olives.tif
# 8     ../data/land_use/lu_Irrigated_Oranges.tif
# 9        ../data/land_use/lu_Rainfed_Apples.tif
# 10      ../data/land_use/lu_Rainfed_Bananas.tif
# 11        ../data/land_use/lu_Rainfed_Cocoa.tif
# 12     ../data/land_use/lu_Rainfed_Coconuts.tif
# 13       ../data/land_use/lu_Rainfed_Coffee.tif
# 14       ../data/land_use/lu_Rainfed_Grapes.tif
# 15       ../data/land_use/lu_Rainfed_Olives.tif
# 16      ../data/land_use/lu_Rainfed_Oranges.tif
# 17  ../data/land_use/lu_Irrigated_Sugarcane.tif
# 18    ../data/land_use/lu_Rainfed_Sugarcane.tif
#
#                                              pet_path  \
# 0   ..\data\crops\rothc_support\Apple_irr_pet_mont...
# 1   ..\data\crops\rothc_support\Banana_irr_pet_mon...
# 2   ..\data\crops\rothc_support\Cocoa_irr_pet_mont...
# 3   ..\data\crops\rothc_support\Coconut_irr_pet_mo...
# 4   ..\data\crops\rothc_support\Coffee_irr_pet_mon...
# 5   ..\data\crops\rothc_support\Grapes_irr_pet_mon...
# 6   ..\data\crops\rothc_support\Oil palm_irr_pet_m...
# 7   ..\data\crops\rothc_support\Olive_irr_pet_mont...
# 8   ..\data\crops\rothc_support\Orange_irr_pet_mon...
# 9   ..\data\crops\rothc_support\Apple_rf_pet_month...
# 10  ..\data\crops\rothc_support\Banana_rf_pet_mont...
# 11  ..\data\crops\rothc_support\Cocoa_rf_pet_month...
# 12  ..\data\crops\rothc_support\Coconut_rf_pet_mon...
# 13  ..\data\crops\rothc_support\Coffee_rf_pet_mont...
# 14  ..\data\crops\rothc_support\Grapes_rf_pet_mont...
# 15  ..\data\crops\rothc_support\Olive_rf_pet_month...
# 16  ..\data\crops\rothc_support\Orange_rf_pet_mont...
# 17  ..\data\crops\rothc_support\Sugarcane_irr_pet_...
# 18  ..\data\crops\rothc_support\Sugarcane_rf_pet_m...
#
#                                              irr_path  \
# 0   ..\data\crops\rothc_support\Apple_irr_irr_mont...
# 1   ..\data\crops\rothc_support\Banana_irr_irr_mon...
# 2   ..\data\crops\rothc_support\Cocoa_irr_irr_mont...
# 3   ..\data\crops\rothc_support\Coconut_irr_irr_mo...
# 4   ..\data\crops\rothc_support\Coffee_irr_irr_mon...
# 5   ..\data\crops\rothc_support\Grapes_irr_irr_mon...
# 6   ..\data\crops\rothc_support\Oil palm_irr_irr_m...
# 7   ..\data\crops\rothc_support\Olive_irr_irr_mont...
# 8   ..\data\crops\rothc_support\Orange_irr_irr_mon...
# 9                                                None
# 10                                               None
# 11                                               None
# 12                                               None
# 13                                               None
# 14                                               None
# 15                                               None
# 16                                               None
# 17  ..\data\crops\rothc_support\Sugarcane_irr_irr_...
# 18                                               None
#
#                                       plantcover_path
# 0   ..\data\crops\rothc_support\Apple_irr_pc_month...
# 1   ..\data\crops\rothc_support\Banana_irr_pc_mont...
# 2   ..\data\crops\rothc_support\Cocoa_irr_pc_month...
# 3   ..\data\crops\rothc_support\Coconut_irr_pc_mon...
# 4   ..\data\crops\rothc_support\Coffee_irr_pc_mont...
# 5   ..\data\crops\rothc_support\Grapes_irr_pc_mont...
# 6   ..\data\crops\rothc_support\Oil palm_irr_pc_mo...
# 7   ..\data\crops\rothc_support\Olive_irr_pc_month...
# 8   ..\data\crops\rothc_support\Orange_irr_pc_mont...
# 9   ..\data\crops\rothc_support\Apple_rf_pc_monthl...
# 10  ..\data\crops\rothc_support\Banana_rf_pc_month...
# 11  ..\data\crops\rothc_support\Cocoa_rf_pc_monthl...
# 12  ..\data\crops\rothc_support\Coconut_rf_pc_mont...
# 13  ..\data\crops\rothc_support\Coffee_rf_pc_month...
# 14  ..\data\crops\rothc_support\Grapes_rf_pc_month...
# 15  ..\data\crops\rothc_support\Olive_rf_pc_monthl...
# 16  ..\data\crops\rothc_support\Orange_rf_pc_month...
# 17  ..\data\crops\rothc_support\Sugarcane_irr_pc_m...
# 18  ..\data\crops\rothc_support\Sugarcane_rf_pc_mo...

# %%
# saving
perm_unique_data_prepared.to_csv("../data/crops/rothc_support/perm_crops_data_path.csv", sep=";", index=False)

# %% [markdown]
# #### 1.2.3 - Forests
# LEAFs are developed for Broadleaf Deciduous (BRDC) and Needleleaf Evergreen (NEEV) forests for different climate zones, including:
#     1. Boreal, dry
#     2. Boreal, moist
#     3. Cold temperate, dry
#     4. Cold temperate, moist,
#     5. Subtropical,
#     6. Tropical,
#     7. Warm temperate, dry, and
#     8. Warm temperate, moist
#
# Note that not all combinations exist, and thus not all are provided.
#
# Plant cover is assumed constant through the year.
# ##### 1.2.3.1 - Litter
# Main source of carbon inputs through residues is the litter generated in forests. To estimate this, liter rates were obtained from table 3.2.1 of [IPCC 2003](https://www.ipcc-nggip.iges.or.jp/public/gpglulucf/gpglulucf_files/Chp3/Chp3_2_Forest_Land.pdf), and have been summarized in [forest_residues_IPCC](../data/forest/forest_residues_IPCC.xlsx) excel spreadsheet.
#
# To estimate litter rates, forest age need to be estimated. This were obtained from  the [Global Forest Age Dataset (GFAD)](https://research.wur.nl/en/datasets/the-global-forest-age-dataset-and-its-uncertainties-gfadv11) v1.1 is used. This dataset assigns the fraction of each grid cell to an age band (1-10, 11-20, ... 141-150) for 4 different forest types: Broadleaf Deciduous, Broadleaf Evergreen, Needleleaf Deciduous, and Needleleaf Evergreen.
#
# It should be noted that the age dataset estimates forest age for 2010. As SOC baseline is for 2016, it has been assumed that no disturbances have occurred between 2010 and 2016. Also, no management practices have been implemented thus far, and should be incorporated in the future for better representation of forest plantations.
#
# ##### 1.2.3.2 -Other data
# All other needed data based on yields, land use, and soil & weather has already been processed for crops. No further water requirements calculations beside precipitation is needed.
#
# Full description implementation of methods for Forests can be found on [SOC_LEAFs_Forest_Support](../documentation/SOC_Support/SOC_LEAFs_Forest_Support.ipynb) notebook.

# %% [markdown]
# #### 1.2.4 - Grassland
# For the moment, only natural grasslands have been generated. Managed grasslands are a natural next steps and support in their development is welcome.
#
# Plant cover is assumed constant through the year.
#
# ##### 1.2.4.1 - Plant Residues
# Resides, both above- and below-ground biomass were obtained from Table 6.4 of the [2006 IPCC - Grasslands](https://www.ipcc-nggip.iges.or.jp/public/2006gl/pdf/4_Volume4/V4_06_Ch6_Grassland.pdf) methodology report for the different thermal zones, which were then converted into FAO climate zones. Data can be found on [grassland_residues_IPCC](../data/grasslands/grassland_residues_IPCC.xlsx) excel spreadsheet.
#
# Annual plant residues are then distributed evenly through each month.
# ##### 1.2.4.2 - Animals Manure or Dung
# Animal manure is another source of carbon in grasslands. For this, an average amount of animals per hectares, including cattle, sheep and goat was determined per uhth pixel using FAO's [Gridded livestock density v4](https://data.apps.fao.org/catalog/dataset/9d1e149b-d63f-4213-978b-317a8eb42d02). Total amount of carbon from animal deposition was then calculated by using  [IPCC 2019](https://www.ipcc-nggip.iges.or.jp/public/2019rf/pdf/4_Volume4/19R_V4_Ch10_Livestock.pdf) annual nitrogen depositions per head per continent and [FAO's Farmer’s Compost Handbook—Experiences in Latin America](https://openknowledge.fao.org/server/api/core/bitstreams/0658b4e0-53e3-4ed7-89d0-ff351bec1dff/content) C:N ratios.
#
# IPCC 2019 information was then mapped into each uhth pixel. Some continents offer 3 productivity systems for cattle: high, average, and low, which should be run separately.
# Annual animal residues are then distributed evenly through each month.
#
# ##### 1.2.4.3 -Other data
# All other needed data based on land use, and soil & weather has already been processed for crops.
#
# Irrigation requirements could be calculated with $\textstyle K_c$ curves with data been provided under [K_Crop_Data.csv](../data/crops/K_Crop_Data.csv). For grasses with multiple harvest a year, new functions should be build or adapted from current ones.
#
#
# Full implementation of methods and data input needed to run RothC for grasslands can be found on [SOC_LEAFs_Grasslands_Support](../documentation/SOC_Support/SOC_LEAFs_Grasslands_Support.ipynb) notebook.

# %% [markdown]
# ## 2. Run RothC
# SOC LEAFs have been calculated for 2030, and are available as individual rasters, and csv and geopackages for ecoregion, subcountry and country averages.
#
# ### 2.1. SOC LEAFs per commodity land use rasters
# A unique function for crops (annual and permanent), forests, and grassland has been developed. CSVs with inputs have been generated for each type of commodity

# %% [markdown]
# #### 2.1.1. Annual Crops
# First, loading the files with all baseline scenarios. Due to long processing times, they've been divided into 2.

# %%
annual_crop_rothc_rf_scenarios = "../data/crops/rothc_support/annual_crops_rothc_scenarios_rainfed.xlsx"
annual_crop_rothc_irr_scenarios = "../data/crops/rothc_support/annual_crops_rothc_scenarios_irrigated.xlsx"

# %% [markdown]
# Starting with rainfed

# %%
rothC.run_rothc_crops_scenarios_from_excel(annual_crop_rothc_rf_scenarios, all_new_files=False, run_test=False)
# Out:
# Could not determine dtype for column 10, falling back to string
# Could not determine dtype for column 11, falling back to string
# Could not determine dtype for column 12, falling back to string
# Annual crop - Barley - rf_ron already exists. Skipping...
# Annual crop - Barley - rf_roff already exists. Skipping...
# Annual crop - Cotton - rf already exists. Skipping...
# Annual crop - Groundnut - rf already exists. Skipping...
# Annual crop - Maize - rf already exists. Skipping...
# Annual crop - Maize - rf already exists. Skipping...
# Annual crop - Potato - rf already exists. Skipping...
# Annual crop - Rapeseed - rf_ron already exists. Skipping...
# Annual crop - Rapeseed - rf_roff already exists. Skipping...
# Annual crop - Rice - rf already exists. Skipping...
# Annual crop - Sorghum - rf already exists. Skipping...
# Annual crop - Sorghum - rf already exists. Skipping...
# Annual crop - Soybean - rf already exists. Skipping...
# Running Annual crop - Sugar beet - rf
#     Loading environmental data...
#     Loading crop data...
#     Running RothC...
#         Calculating baseline residue inputs for annual Sugar beet using 100 stochastic runs
# RothC months:   0%|          | 0/168 [00:00<?, ?it/s]
#     RothC results saved into ..\LEAFs\SOC\rasters\Sugar beet_rf_2030y_SOC.tif
# Annual crop - Sugar beet - rf calculated. Continuing...
#
#
# Running Annual crop - Sunflower - rf
#     Loading environmental data...
#     Loading crop data...
#     Running RothC...
#         Calculating baseline residue inputs for annual Sunflower using 100 stochastic runs
# RothC months:   0%|          | 0/168 [00:00<?, ?it/s]
#     RothC results saved into ..\LEAFs\SOC\rasters\Sunflower_rf_2030y_SOC.tif
# Annual crop - Sunflower - rf calculated. Continuing...
#
#
# Running Annual crop - Sweet potato - rf
#     Loading environmental data...
#     Loading crop data...
#     Running RothC...
#         Calculating baseline residue inputs for annual Sweet potato using 100 stochastic runs
# RothC months:   0%|          | 0/168 [00:00<?, ?it/s]
#     RothC results saved into ..\LEAFs\SOC\rasters\Sweet potato_rf_2030y_SOC.tif
# Annual crop - Sweet potato - rf calculated. Continuing...
#
#
# Running Annual crop - Tobacco - rf
#     Loading environmental data...
#     Loading crop data...
#     Running RothC...
#         Calculating baseline residue inputs for annual Tobacco using 100 stochastic runs
# RothC months:   0%|          | 0/168 [00:00<?, ?it/s]
#     RothC results saved into ..\LEAFs\SOC\rasters\Tobacco_rf_2030y_SOC.tif
# Annual crop - Tobacco - rf calculated. Continuing...
#
#
# Running Annual crop - Tomato - rf
#     Loading environmental data...
#     Loading crop data...
#     Running RothC...
#         Calculating baseline residue inputs for annual Tomato using 100 stochastic runs
# RothC months:   0%|          | 0/168 [00:00<?, ?it/s]
#     RothC results saved into ..\LEAFs\SOC\rasters\Tomato_rf_2030y_SOC.tif
# Annual crop - Tomato - rf calculated. Continuing...
#
#
# Running Annual crop - Wheat - rf_ron
#     Loading environmental data...
#     Loading crop data...
#     Running RothC...
#         Calculating baseline residue inputs for annual Wheat using 100 stochastic runs
# RothC months:   0%|          | 0/168 [00:00<?, ?it/s]
#     RothC results saved into ..\LEAFs\SOC\rasters\Wheat_rf_ron_2030y_SOC.tif
# Annual crop - Wheat - rf_ron calculated. Continuing...
#
#
# Running Annual crop - Wheat - rf_roff
#     Loading environmental data...
#     Loading crop data...
#     Running RothC...
#         Residues removed. C_inputs are 0's
# RothC months:   0%|          | 0/168 [00:00<?, ?it/s]
#     RothC results saved into ..\LEAFs\SOC\rasters\Wheat_rf_roff_2030y_SOC.tif
# Annual crop - Wheat - rf_roff calculated. Continuing...

# %% [markdown]
# ##### Checking results
# Selecting one of the results generated:

# %%
results_check_roff_fp = "../LEAFs/SOC/rasters/Barley_rf_roff_2030y_SOC.tif"
results_check_ron_fp = "../LEAFs/SOC/rasters/Barley_rf_ron_2030y_SOC.tif"

# %% [markdown]
# Inspecting properties...

# %%
maplot.inspect_raster(results_check_roff_fp)
# Out:
# File: ../LEAFs/SOC/rasters/Barley_rf_roff_2030y_SOC.tif
# Driver: GTiff
# Width, Height: 4320, 2083
# Number of Bands: 15
# CRS: EPSG:4326
# Bounds: BoundingBox(left=-179.99999999999997, bottom=-89.99999999999994, right=179.99999999999991, top=83.58333333333331)
# Pixel Size: (0.0833333333333333, 0.0833333333333333)
# No-data Value: nan
#
# --- Raster Metadata ---
# description: RothC results for year 2030 for Barley_rf_roff in ton C/ha
# long_name: Soil Organic Carbon
# model: RothC rasterized vectorized
# units: t C/ha
# AREA_OR_POINT: Area
#
# --- Band Information ---
#
# Band 1:
#   Data Type: float32
#   Min Value: 6.81576681137085
#   Max Value: 153.6893768310547
#   Mean Value: 49.643985748291016
#   Standard Deviation: 19.12213897705078
#
# Band 2:
#   Data Type: float32
#   Min Value: 6.351121425628662
#   Max Value: 144.8153076171875
#   Mean Value: 46.905765533447266
#   Standard Deviation: 18.836658477783203
#
# Band 3:
#   Data Type: float32
#   Min Value: 6.054150581359863
#   Max Value: 143.7664031982422
#   Mean Value: 45.18113327026367
#   Standard Deviation: 18.536890029907227
#
# Band 4:
#   Data Type: float32
#   Min Value: 5.815150737762451
#   Max Value: 143.7664031982422
#   Mean Value: 43.791404724121094
#   Standard Deviation: 18.263988494873047
#
# Band 5:
#   Data Type: float32
#   Min Value: 5.618070602416992
#   Max Value: 143.7664031982422
#   Mean Value: 42.61482238769531
#   Standard Deviation: 18.017738342285156
#
# Band 6:
#   Data Type: float32
#   Min Value: 5.4514899253845215
#   Max Value: 143.7664031982422
#   Mean Value: 41.58421325683594
#   Standard Deviation: 17.798410415649414
#
# Band 7:
#   Data Type: float32
#   Min Value: 5.307255744934082
#   Max Value: 143.7664031982422
#   Mean Value: 40.65946578979492
#   Standard Deviation: 17.60468101501465
#
# Band 8:
#   Data Type: float32
#   Min Value: 5.17952823638916
#   Max Value: 143.7664031982422
#   Mean Value: 39.81512451171875
#   Standard Deviation: 17.434289932250977
#
# Band 9:
#   Data Type: float32
#   Min Value: 5.064115524291992
#   Max Value: 143.7664031982422
#   Mean Value: 39.03413009643555
#   Standard Deviation: 17.28463363647461
#
# Band 10:
#   Data Type: float32
#   Min Value: 4.958002090454102
#   Max Value: 143.7664031982422
#   Mean Value: 38.304569244384766
#   Standard Deviation: 17.15308952331543
#
# Band 11:
#   Data Type: float32
#   Min Value: 4.859014511108398
#   Max Value: 143.7664031982422
#   Mean Value: 37.61777877807617
#   Standard Deviation: 17.037195205688477
#
# Band 12:
#   Data Type: float32
#   Min Value: 4.76558256149292
#   Max Value: 143.7664031982422
#   Mean Value: 36.96727752685547
#   Standard Deviation: 16.934703826904297
#
# Band 13:
#   Data Type: float32
#   Min Value: 4.670802593231201
#   Max Value: 143.7664031982422
#   Mean Value: 36.34809875488281
#   Standard Deviation: 16.843618392944336
#
# Band 14:
#   Data Type: float32
#   Min Value: 4.578155994415283
#   Max Value: 143.7664031982422
#   Mean Value: 35.75634765625
#   Standard Deviation: 16.76218032836914
#
# Band 15:
#   Data Type: float32
#   Min Value: 4.470285415649414
#   Max Value: 143.7664031982422
#   Mean Value: 35.18891143798828
#   Standard Deviation: 16.6888484954834

# %%
maplot.inspect_raster(results_check_ron_fp)
# Out:
# File: ../LEAFs/SOC/rasters/Barley_rf_ron_2030y_SOC.tif
# Driver: GTiff
# Width, Height: 4320, 2083
# Number of Bands: 15
# CRS: EPSG:4326
# Bounds: BoundingBox(left=-179.99999999999997, bottom=-89.99999999999994, right=179.99999999999991, top=83.58333333333331)
# Pixel Size: (0.0833333333333333, 0.0833333333333333)
# No-data Value: nan
#
# --- Raster Metadata ---
# description: RothC results for year 2030 for Barley_rf_ron in ton C/ha
# long_name: Soil Organic Carbon
# model: RothC rasterized vectorized
# units: t C/ha
# AREA_OR_POINT: Area
#
# --- Band Information ---
#
# Band 1:
#   Data Type: float32
#   Min Value: 6.81576681137085
#   Max Value: 153.6893768310547
#   Mean Value: 49.25067138671875
#   Standard Deviation: 19.241952896118164
#
# Band 2:
#   Data Type: float32
#   Min Value: 7.1875152587890625
#   Max Value: 146.96432495117188
#   Mean Value: 47.323951721191406
#   Standard Deviation: 19.030826568603516
#
# Band 3:
#   Data Type: float32
#   Min Value: 7.551914215087891
#   Max Value: 150.16224670410156
#   Mean Value: 46.17777633666992
#   Standard Deviation: 18.80307388305664
#
# Band 4:
#   Data Type: float32
#   Min Value: 7.802217960357666
#   Max Value: 153.36016845703125
#   Mean Value: 45.27449417114258
#   Standard Deviation: 18.62132453918457
#
# Band 5:
#   Data Type: float32
#   Min Value: 8.000075340270996
#   Max Value: 156.55809020996094
#   Mean Value: 44.52035903930664
#   Standard Deviation: 18.47772216796875
#
# Band 6:
#   Data Type: float32
#   Min Value: 8.169785499572754
#   Max Value: 159.75601196289062
#   Mean Value: 43.86521530151367
#   Standard Deviation: 18.36804962158203
#
# Band 7:
#   Data Type: float32
#   Min Value: 8.184489250183105
#   Max Value: 162.9539337158203
#   Mean Value: 43.28021240234375
#   Standard Deviation: 18.288541793823242
#
# Band 8:
#   Data Type: float32
#   Min Value: 8.174274444580078
#   Max Value: 166.80799865722656
#   Mean Value: 42.747684478759766
#   Standard Deviation: 18.2355899810791
#
# Band 9:
#   Data Type: float32
#   Min Value: 8.148272514343262
#   Max Value: 171.38182067871094
#   Mean Value: 42.256187438964844
#   Standard Deviation: 18.20586395263672
#
# Band 10:
#   Data Type: float32
#   Min Value: 8.069779396057129
#   Max Value: 175.95565795898438
#   Mean Value: 41.797935485839844
#   Standard Deviation: 18.19635009765625
#
# Band 11:
#   Data Type: float32
#   Min Value: 7.953409671783447
#   Max Value: 180.5294952392578
#   Mean Value: 41.36738586425781
#   Standard Deviation: 18.20440673828125
#
# Band 12:
#   Data Type: float32
#   Min Value: 7.692119598388672
#   Max Value: 185.10333251953125
#   Mean Value: 40.9604606628418
#   Standard Deviation: 18.227724075317383
#
# Band 13:
#   Data Type: float32
#   Min Value: 7.442587852478027
#   Max Value: 189.69613647460938
#   Mean Value: 40.574066162109375
#   Standard Deviation: 18.264310836791992
#
# Band 14:
#   Data Type: float32
#   Min Value: 7.2042012214660645
#   Max Value: 194.35691833496094
#   Mean Value: 40.20580291748047
#   Standard Deviation: 18.31244659423828
#
# Band 15:
#   Data Type: float32
#   Min Value: 6.976421356201172
#   Max Value: 199.0177001953125
#   Mean Value: 39.85375213623047
#   Standard Deviation: 18.370656967163086

# %% [markdown]
# Plotting...

# %%
maplot.plot_raster_on_world_extremes_cutoff(results_check_roff_fp, "Barley, Residues removed, 2030", raster_band=15, quantiles = 10, perc_cutoff=1)
# Out:
# Raster has 667,950 unique values. Min: 8.90. Max: 76.59
# Using quantiles
# All positives route (quantiles)

# %%
maplot.plot_raster_on_world_extremes_cutoff(results_check_ron_fp, "Barley, Residues left on field, 2030", raster_band=15, quantiles = 10, perc_cutoff=1)
# Out:
# Raster has 679,581 unique values. Min: 11.34. Max: 88.19
# Using quantiles
# All positives route (quantiles)

# %%
maplot.plot_multiband_raster_timesires(results_check_ron_fp, "Global SOC Mean Time Series\nBarley, Rainfed, Residues left on Field", show_iq=True)

# %%
pct_change_ron_fp = rothC.calcuate_annual_perc_changes(results_check_ron_fp)

# %%
maplot.plot_da_on_world_extremes_cutoff(pct_change_ron_fp, "SOC Percentage change by year 2030 for\nBarley, Rainfed, Residues left on Field", band=14, cmap="RdBu", quantiles=10, perc_cutoff=1)
# Out:
# Raster has 660,347 unique values. Min: -52.00. Max: 42.02
# Using quantiles
# 2-sided route (quantiles)
# (<Figure size 1400x800 with 2 Axes>,
#  <Axes: title={'center': 'SOC Percentage change by year 2030 for\nBarley, Rainfed, Residues left on Field'}, xlabel='Projected X (map units)', ylabel='Projected Y (map units)'>)

# %% [markdown]
# All results look calculated ok. Continuing with irrigation

# %%
rothC.run_rothc_crops_scenarios_from_excel(annual_crop_rothc_irr_scenarios, all_new_files=True, run_test=False)
# Out:
# Could not determine dtype for column 11, falling back to string
# Could not determine dtype for column 12, falling back to string
# Running Annual crop - Barley - irr_ron
#     Loading environmental data...
#     Loading crop data...
#     Running RothC...
#         Calculating baseline residue inputs for annual Barley using 100 stochastic runs
# RothC months:   0%|          | 0/168 [00:00<?, ?it/s]
#     RothC results saved into ..\LEAFs\SOC\rasters\Barley_irr_ron_2030y_SOC.tif
# Annual crop - Barley - irr_ron calculated. Continuing...
#
#
# Running Annual crop - Barley - irr_roff
#     Loading environmental data...
#     Loading crop data...
#     Running RothC...
#         Residues removed. C_inputs are 0's
# RothC months:   0%|          | 0/168 [00:00<?, ?it/s]
#     RothC results saved into ..\LEAFs\SOC\rasters\Barley_irr_roff_2030y_SOC.tif
# Annual crop - Barley - irr_roff calculated. Continuing...
#
#
# Running Annual crop - Cabbage - irr
#     Loading environmental data...
#     Loading crop data...
#     Running RothC...
#         Calculating baseline residue inputs for annual Cabbage using 100 stochastic runs
# RothC months:   0%|          | 0/168 [00:00<?, ?it/s]
#     RothC results saved into ..\LEAFs\SOC\rasters\Cabbage_irr_2030y_SOC.tif
# Annual crop - Cabbage - irr calculated. Continuing...
#
#
# Running Annual crop - Carrot - irr
#     Loading environmental data...
#     Loading crop data...
#     Running RothC...
#         Calculating baseline residue inputs for annual Carrot using 100 stochastic runs
# RothC months:   0%|          | 0/168 [00:00<?, ?it/s]
#     RothC results saved into ..\LEAFs\SOC\rasters\Carrot_irr_2030y_SOC.tif
# Annual crop - Carrot - irr calculated. Continuing...
#
#
# Running Annual crop - Cotton - irr
#     Loading environmental data...
#     Loading crop data...
#     Running RothC...
#         Calculating baseline residue inputs for annual Cotton using 100 stochastic runs
# RothC months:   0%|          | 0/168 [00:00<?, ?it/s]
#     RothC results saved into ..\LEAFs\SOC\rasters\Cotton_irr_2030y_SOC.tif
# Annual crop - Cotton - irr calculated. Continuing...
#
#
# Running Annual crop - Groundnut - irr
#     Loading environmental data...
#     Loading crop data...
#     Running RothC...
#         Calculating baseline residue inputs for annual Groundnut using 100 stochastic runs
# RothC months:   0%|          | 0/168 [00:00<?, ?it/s]
#     RothC results saved into ..\LEAFs\SOC\rasters\Groundnut_irr_2030y_SOC.tif
# Annual crop - Groundnut - irr calculated. Continuing...
#
#
# Running Annual crop - Maize - irr_ron
#     Loading environmental data...
#     Loading crop data...
#     Running RothC...
#         Calculating baseline residue inputs for annual Maize using 100 stochastic runs
# RothC months:   0%|          | 0/168 [00:00<?, ?it/s]
#     RothC results saved into ..\LEAFs\SOC\rasters\Maize_irr_ron_2030y_SOC.tif
# Annual crop - Maize - irr_ron calculated. Continuing...
#
#
# Running Annual crop - Maize - irr_roff
#     Loading environmental data...
#     Loading crop data...
#     Running RothC...
#         Residues removed. C_inputs are 0's
# RothC months:   0%|          | 0/168 [00:00<?, ?it/s]
#     RothC results saved into ..\LEAFs\SOC\rasters\Maize_irr_roff_2030y_SOC.tif
# Annual crop - Maize - irr_roff calculated. Continuing...
#
#
# Running Annual crop - Onion - irr
#     Loading environmental data...
#     Loading crop data...
#     Running RothC...
#         Calculating baseline residue inputs for annual Onion using 100 stochastic runs
# RothC months:   0%|          | 0/168 [00:00<?, ?it/s]
#     RothC results saved into ..\LEAFs\SOC\rasters\Onion_irr_2030y_SOC.tif
# Annual crop - Onion - irr calculated. Continuing...
#
#
# Running Annual crop - Potato - irr
#     Loading environmental data...
#     Loading crop data...
#     Running RothC...
#         Calculating baseline residue inputs for annual Potato using 100 stochastic runs
# RothC months:   0%|          | 0/168 [00:00<?, ?it/s]
#     RothC results saved into ..\LEAFs\SOC\rasters\Potato_irr_2030y_SOC.tif
# Annual crop - Potato - irr calculated. Continuing...
#
#
# Running Annual crop - Rapeseed - irr_ron
#     Loading environmental data...
#     Loading crop data...
#     Running RothC...
#         Calculating baseline residue inputs for annual Rapeseed using 100 stochastic runs
# RothC months:   0%|          | 0/168 [00:00<?, ?it/s]
#     RothC results saved into ..\LEAFs\SOC\rasters\Rapeseed_irr_ron_2030y_SOC.tif
# Annual crop - Rapeseed - irr_ron calculated. Continuing...
#
#
# Running Annual crop - Rapeseed - irr_roff
#     Loading environmental data...
#     Loading crop data...
#     Running RothC...
#         Residues removed. C_inputs are 0's
# RothC months:   0%|          | 0/168 [00:00<?, ?it/s]
#     RothC results saved into ..\LEAFs\SOC\rasters\Rapeseed_irr_roff_2030y_SOC.tif
# Annual crop - Rapeseed - irr_roff calculated. Continuing...
#
#
# Running Annual crop - Rice - irr
#     Loading environmental data...
#     Loading crop data...
#     Running RothC...
#         Calculating baseline residue inputs for annual Rice using 100 stochastic runs
# RothC months:   0%|          | 0/168 [00:00<?, ?it/s]
#     RothC results saved into ..\LEAFs\SOC\rasters\Rice_irr_2030y_SOC.tif
# Annual crop - Rice - irr calculated. Continuing...
#
#
# Running Annual crop - Sorghum - irr_ron
#     Loading environmental data...
#     Loading crop data...
#     Running RothC...
#         Calculating baseline residue inputs for annual Sorghum using 100 stochastic runs
# RothC months:   0%|          | 0/168 [00:00<?, ?it/s]
#     RothC results saved into ..\LEAFs\SOC\rasters\Sorghum_irr_ron_2030y_SOC.tif
# Annual crop - Sorghum - irr_ron calculated. Continuing...
#
#
# Running Annual crop - Sorghum - irr_roff
#     Loading environmental data...
#     Loading crop data...
#     Running RothC...
#         Residues removed. C_inputs are 0's
# RothC months:   0%|          | 0/168 [00:00<?, ?it/s]
#     RothC results saved into ..\LEAFs\SOC\rasters\Sorghum_irr_roff_2030y_SOC.tif
# Annual crop - Sorghum - irr_roff calculated. Continuing...
#
#
# Running Annual crop - Soybean - irr
#     Loading environmental data...
#     Loading crop data...
#     Running RothC...
#         Calculating baseline residue inputs for annual Soybean using 100 stochastic runs
# RothC months:   0%|          | 0/168 [00:00<?, ?it/s]
#     RothC results saved into ..\LEAFs\SOC\rasters\Soybean_irr_2030y_SOC.tif
# Annual crop - Soybean - irr calculated. Continuing...
#
#
# Running Annual crop - Sugar beet - irr
#     Loading environmental data...
#     Loading crop data...
#     Running RothC...
#         Calculating baseline residue inputs for annual Sugar beet using 100 stochastic runs
# RothC months:   0%|          | 0/168 [00:00<?, ?it/s]
#     RothC results saved into ..\LEAFs\SOC\rasters\Sugar beet_irr_2030y_SOC.tif
# Annual crop - Sugar beet - irr calculated. Continuing...
#
#
# Running Annual crop - Sunflower - irr
#     Loading environmental data...
#     Loading crop data...
#     Running RothC...
#         Calculating baseline residue inputs for annual Sunflower using 100 stochastic runs
# RothC months:   0%|          | 0/168 [00:00<?, ?it/s]
#     RothC results saved into ..\LEAFs\SOC\rasters\Sunflower_irr_2030y_SOC.tif
# Annual crop - Sunflower - irr calculated. Continuing...
#
#
# Running Annual crop - Sweet potato - irr
#     Loading environmental data...
#     Loading crop data...
#     Running RothC...
#         Calculating baseline residue inputs for annual Sweet potato using 100 stochastic runs
# RothC months:   0%|          | 0/168 [00:00<?, ?it/s]
#     RothC results saved into ..\LEAFs\SOC\rasters\Sweet potato_irr_2030y_SOC.tif
# Annual crop - Sweet potato - irr calculated. Continuing...
#
#
# Running Annual crop - Tobacco - irr
#     Loading environmental data...
#     Loading crop data...
#     Running RothC...
#         Calculating baseline residue inputs for annual Tobacco using 100 stochastic runs
# RothC months:   0%|          | 0/168 [00:00<?, ?it/s]
#     RothC results saved into ..\LEAFs\SOC\rasters\Tobacco_irr_2030y_SOC.tif
# Annual crop - Tobacco - irr calculated. Continuing...
#
#
# Running Annual crop - Tomato - irr
#     Loading environmental data...
#     Loading crop data...
#     Running RothC...
#         Calculating baseline residue inputs for annual Tomato using 100 stochastic runs
# RothC months:   0%|          | 0/168 [00:00<?, ?it/s]
#     RothC results saved into ..\LEAFs\SOC\rasters\Tomato_irr_2030y_SOC.tif
# Annual crop - Tomato - irr calculated. Continuing...
#
#
# Running Annual crop - Wheat - irr_ron
#     Loading environmental data...
#     Loading crop data...
#     Running RothC...
#         Calculating baseline residue inputs for annual Wheat using 100 stochastic runs
# RothC months:   0%|          | 0/168 [00:00<?, ?it/s]
#     RothC results saved into ..\LEAFs\SOC\rasters\Wheat_irr_ron_2030y_SOC.tif
# Annual crop - Wheat - irr_ron calculated. Continuing...
#
#
# Running Annual crop - Wheat - irr_roff
#     Loading environmental data...
#     Loading crop data...
#     Running RothC...
#         Residues removed. C_inputs are 0's
# RothC months:   0%|          | 0/168 [00:00<?, ?it/s]
#     RothC results saved into ..\LEAFs\SOC\rasters\Wheat_irr_roff_2030y_SOC.tif
# Annual crop - Wheat - irr_roff calculated. Continuing...

# %% [markdown]
# #### 2.1.2. Permanent Crops

# %%
permanent_crop_rothc_scenarios_fp = data_path("crops", "rothc_support","permcrops_baseline_rothc_scenarios.xlsx")

# %%
importlib.reload(rothC)
# Out:
# <module 'sbtn_leaf.RothC_Raster' from 'C:\\Users\\loyola\\OneDrive - World Wildlife Fund, Inc\\Documents\\203. Python projects\\SBTN_Test\\src\\sbtn_leaf\\RothC_Raster.py'>

# %%
# Running scenarios. This takes time!
rothC.run_rothc_crops_scenarios_from_excel(permanent_crop_rothc_scenarios_fp, all_new_files=True)
# Out:
# Could not determine dtype for column 10, falling back to string
# Could not determine dtype for column 11, falling back to string
# Running Permanent crop - Apple - irr
#     Loading environmental data...
#     Loading crop data...
#     Running RothC...
# RothC months:   0%|          | 0/168 [00:00<?, ?it/s]
#     RothC results saved into ..\LEAFs\SOC\rasters\Apple_irr_2030y_SOC.tif
# Permanent crop - Apple - irr calculated. Continuing...
#
#
# Running Permanent crop - Banana - irr
#     Loading environmental data...
#     Loading crop data...
#     Running RothC...
# RothC months:   0%|          | 0/168 [00:00<?, ?it/s]
#     RothC results saved into ..\LEAFs\SOC\rasters\Banana_irr_2030y_SOC.tif
# Permanent crop - Banana - irr calculated. Continuing...
#
#
# Running Permanent crop - Cocoa - irr
#     Loading environmental data...
#     Loading crop data...
#     Running RothC...
# RothC months:   0%|          | 0/168 [00:00<?, ?it/s]
#     RothC results saved into ..\LEAFs\SOC\rasters\Cocoa_irr_2030y_SOC.tif
# Permanent crop - Cocoa - irr calculated. Continuing...
#
#
# Running Permanent crop - Coconut - irr
#     Loading environmental data...
#     Loading crop data...
#     Running RothC...
# RothC months:   0%|          | 0/168 [00:00<?, ?it/s]
#     RothC results saved into ..\LEAFs\SOC\rasters\Coconut_irr_2030y_SOC.tif
# Permanent crop - Coconut - irr calculated. Continuing...
#
#
# Running Permanent crop - Coffee - irr
#     Loading environmental data...
#     Loading crop data...
#     Running RothC...
# RothC months:   0%|          | 0/168 [00:00<?, ?it/s]
#     RothC results saved into ..\LEAFs\SOC\rasters\Coffee_irr_2030y_SOC.tif
# Permanent crop - Coffee - irr calculated. Continuing...
#
#
# Running Permanent crop - Grapes - irr
#     Loading environmental data...
#     Loading crop data...
#     Running RothC...
# RothC months:   0%|          | 0/168 [00:00<?, ?it/s]
#     RothC results saved into ..\LEAFs\SOC\rasters\Grapes_irr_2030y_SOC.tif
# Permanent crop - Grapes - irr calculated. Continuing...
#
#
# Running Permanent crop - Oil palm - irr
#     Loading environmental data...
#     Loading crop data...
#     Running RothC...
# RothC months:   0%|          | 0/168 [00:00<?, ?it/s]
#     RothC results saved into ..\LEAFs\SOC\rasters\Oil palm_irr_2030y_SOC.tif
# Permanent crop - Oil palm - irr calculated. Continuing...
#
#
# Running Permanent crop - Olive - irr
#     Loading environmental data...
#     Loading crop data...
#     Running RothC...
# RothC months:   0%|          | 0/168 [00:00<?, ?it/s]
#     RothC results saved into ..\LEAFs\SOC\rasters\Olive_irr_2030y_SOC.tif
# Permanent crop - Olive - irr calculated. Continuing...
#
#
# Running Permanent crop - Orange - irr
#     Loading environmental data...
#     Loading crop data...
#     Running RothC...
# RothC months:   0%|          | 0/168 [00:00<?, ?it/s]
#     RothC results saved into ..\LEAFs\SOC\rasters\Orange_irr_2030y_SOC.tif
# Permanent crop - Orange - irr calculated. Continuing...
#
#
# Running Permanent crop - Apple - rf
#     Loading environmental data...
#     Loading crop data...
#     Running RothC...
# RothC months:   0%|          | 0/168 [00:00<?, ?it/s]
#     RothC results saved into ..\LEAFs\SOC\rasters\Apple_rf_2030y_SOC.tif
# Permanent crop - Apple - rf calculated. Continuing...
#
#
# Running Permanent crop - Banana - rf
#     Loading environmental data...
#     Loading crop data...
#     Running RothC...
# RothC months:   0%|          | 0/168 [00:00<?, ?it/s]
#     RothC results saved into ..\LEAFs\SOC\rasters\Banana_rf_2030y_SOC.tif
# Permanent crop - Banana - rf calculated. Continuing...
#
#
# Running Permanent crop - Cocoa - rf
#     Loading environmental data...
#     Loading crop data...
#     Running RothC...
# RothC months:   0%|          | 0/168 [00:00<?, ?it/s]
#     RothC results saved into ..\LEAFs\SOC\rasters\Cocoa_rf_2030y_SOC.tif
# Permanent crop - Cocoa - rf calculated. Continuing...
#
#
# Running Permanent crop - Coconut - rf
#     Loading environmental data...
#     Loading crop data...
#     Running RothC...
# RothC months:   0%|          | 0/168 [00:00<?, ?it/s]
#     RothC results saved into ..\LEAFs\SOC\rasters\Coconut_rf_2030y_SOC.tif
# Permanent crop - Coconut - rf calculated. Continuing...
#
#
# Running Permanent crop - Coffee - rf
#     Loading environmental data...
#     Loading crop data...
#     Running RothC...
# RothC months:   0%|          | 0/168 [00:00<?, ?it/s]
#     RothC results saved into ..\LEAFs\SOC\rasters\Coffee_rf_2030y_SOC.tif
# Permanent crop - Coffee - rf calculated. Continuing...
#
#
# Running Permanent crop - Grapes - rf
#     Loading environmental data...
#     Loading crop data...
#     Running RothC...
# RothC months:   0%|          | 0/168 [00:00<?, ?it/s]
#     RothC results saved into ..\LEAFs\SOC\rasters\Grapes_rf_2030y_SOC.tif
# Permanent crop - Grapes - rf calculated. Continuing...
#
#
# Running Permanent crop - Oil palm - rf
#     Loading environmental data...
#     Loading crop data...
#     Running RothC...
# RothC months:   0%|          | 0/168 [00:00<?, ?it/s]
#     RothC results saved into ..\LEAFs\SOC\rasters\Oil palm_rf_2030y_SOC.tif
# Permanent crop - Oil palm - rf calculated. Continuing...
#
#
# Running Permanent crop - Olive - rf
#     Loading environmental data...
#     Loading crop data...
#     Running RothC...
# RothC months:   0%|          | 0/168 [00:00<?, ?it/s]
#     RothC results saved into ..\LEAFs\SOC\rasters\Olive_rf_2030y_SOC.tif
# Permanent crop - Olive - rf calculated. Continuing...
#
#
# Running Permanent crop - Orange - rf
#     Loading environmental data...
#     Loading crop data...
#     Running RothC...
# RothC months:   0%|          | 0/168 [00:00<?, ?it/s]
#     RothC results saved into ..\LEAFs\SOC\rasters\Orange_rf_2030y_SOC.tif
# Permanent crop - Orange - rf calculated. Continuing...
#
#
# Running Permanent crop - Sugarcane - irr
#     Loading environmental data...
#     Loading crop data...
#     Running RothC...
# RothC months:   0%|          | 0/168 [00:00<?, ?it/s]
#     RothC results saved into ..\LEAFs\SOC\rasters\Sugarcane_irr_2030y_SOC.tif
# Permanent crop - Sugarcane - irr calculated. Continuing...
#
#
# Running Permanent crop - Sugarcane - rf
#     Loading environmental data...
#     Loading crop data...
#     Running RothC...
# RothC months:   0%|          | 0/168 [00:00<?, ?it/s]
#     RothC results saved into ..\LEAFs\SOC\rasters\Sugarcane_rf_2030y_SOC.tif
# Permanent crop - Sugarcane - rf calculated. Continuing...

# %% [markdown]
# ##### Checking results

# %%
apple_irr_results = LEAFs_dir()/"SOC/rasters/Apple_irr_2030y_SOC.tif"
apple_rf_results = LEAFs_dir()/"SOC/rasters/Apple_rf_2030y_SOC.tif"

# %%
maplot.inspect_raster(apple_irr_results)
# Out:
# File: C:\Users\loyola\OneDrive - World Wildlife Fund, Inc\Documents\203. Python projects\SBTN_Test\LEAFs\SOC\rasters\Apple_irr_2030y_SOC.tif
# Driver: GTiff
# Width, Height: 4320, 2083
# Number of Bands: 15
# CRS: EPSG:4326
# Bounds: BoundingBox(left=-179.99999999999997, bottom=-89.99999999999994, right=179.99999999999991, top=83.58333333333331)
# Pixel Size: (0.0833333333333333, 0.0833333333333333)
# No-data Value: nan
#
# --- Raster Metadata ---
# description: RothC model results for year 2030 for Apple, irrigated
# long_name: Soil Organic Carbon
# model: RothC rasterized vectorized
# units: t C/ha
# AREA_OR_POINT: Area
#
# --- Band Information ---
#
# Band 1:
#   Data Type: float32
#   Min Value: 7.7331671714782715
#   Max Value: 166.87579345703125
#   Mean Value: 45.55247116088867
#   Standard Deviation: 17.2567138671875
#
# Band 2:
#   Data Type: float32
#   Min Value: 7.163589954376221
#   Max Value: 157.86770629882812
#   Mean Value: 42.11054611206055
#   Standard Deviation: 16.713592529296875
#
# Band 3:
#   Data Type: float32
#   Min Value: 6.804661750793457
#   Max Value: 150.665771484375
#   Mean Value: 39.95582962036133
#   Standard Deviation: 16.29538345336914
#
# Band 4:
#   Data Type: float32
#   Min Value: 6.520353317260742
#   Max Value: 144.9402618408203
#   Mean Value: 38.320213317871094
#   Standard Deviation: 15.953902244567871
#
# Band 5:
#   Data Type: float32
#   Min Value: 6.288500785827637
#   Max Value: 143.7664031982422
#   Mean Value: 36.98912048339844
#   Standard Deviation: 15.669325828552246
#
# Band 6:
#   Data Type: float32
#   Min Value: 6.093815803527832
#   Max Value: 143.7664031982422
#   Mean Value: 35.845794677734375
#   Standard Deviation: 15.429157257080078
#
# Band 7:
#   Data Type: float32
#   Min Value: 5.898993015289307
#   Max Value: 143.7664031982422
#   Mean Value: 34.824913024902344
#   Standard Deviation: 15.224106788635254
#
# Band 8:
#   Data Type: float32
#   Min Value: 5.690197467803955
#   Max Value: 143.7664031982422
#   Mean Value: 33.88887023925781
#   Standard Deviation: 15.04703426361084
#
# Band 9:
#   Data Type: float32
#   Min Value: 5.4942426681518555
#   Max Value: 143.7664031982422
#   Mean Value: 33.015350341796875
#   Standard Deviation: 14.892434120178223
#
# Band 10:
#   Data Type: float32
#   Min Value: 5.308222770690918
#   Max Value: 143.7664031982422
#   Mean Value: 32.190643310546875
#   Standard Deviation: 14.756040573120117
#
# Band 11:
#   Data Type: float32
#   Min Value: 5.130500793457031
#   Max Value: 143.7664031982422
#   Mean Value: 31.406017303466797
#   Standard Deviation: 14.634533882141113
#
# Band 12:
#   Data Type: float32
#   Min Value: 4.9601054191589355
#   Max Value: 143.7664031982422
#   Mean Value: 30.65566062927246
#   Standard Deviation: 14.525311470031738
#
# Band 13:
#   Data Type: float32
#   Min Value: 4.7964186668396
#   Max Value: 143.7664031982422
#   Mean Value: 29.93555450439453
#   Standard Deviation: 14.426313400268555
#
# Band 14:
#   Data Type: float32
#   Min Value: 4.639009952545166
#   Max Value: 143.7664031982422
#   Mean Value: 29.242809295654297
#   Standard Deviation: 14.33588981628418
#
# Band 15:
#   Data Type: float32
#   Min Value: 4.487551212310791
#   Max Value: 143.7664031982422
#   Mean Value: 28.575227737426758
#   Standard Deviation: 14.25270938873291

# %%
maplot.inspect_raster(apple_rf_results)
# Out:
# File: C:\Users\loyola\OneDrive - World Wildlife Fund, Inc\Documents\203. Python projects\SBTN_Test\LEAFs\SOC\rasters\Apple_rf_2030y_SOC.tif
# Driver: GTiff
# Width, Height: 4320, 2083
# Number of Bands: 15
# CRS: EPSG:4326
# Bounds: BoundingBox(left=-179.99999999999997, bottom=-89.99999999999994, right=179.99999999999991, top=83.58333333333331)
# Pixel Size: (0.0833333333333333, 0.0833333333333333)
# No-data Value: nan
#
# --- Raster Metadata ---
# description: RothC model results for year 2030
# long_name: Soil Organic Carbon
# model: RothC rasterized vectorized
# units: t C/ha
# AREA_OR_POINT: Area
#
# --- Band Information ---
#
# Band 1:
#   Data Type: float32
#   Min Value: 7.7331671714782715
#   Max Value: 166.87579345703125
#   Mean Value: 45.55051803588867
#   Standard Deviation: 17.253765106201172
#
# Band 2:
#   Data Type: float32
#   Min Value: 9.043563842773438
#   Max Value: 158.4442138671875
#   Mean Value: 43.507476806640625
#   Standard Deviation: 16.481914520263672
#
# Band 3:
#   Data Type: float32
#   Min Value: 9.753870964050293
#   Max Value: 151.73008728027344
#   Mean Value: 42.24873733520508
#   Standard Deviation: 15.971257209777832
#
# Band 4:
#   Data Type: float32
#   Min Value: 9.913640975952148
#   Max Value: 153.8612518310547
#   Mean Value: 41.26970291137695
#   Standard Deviation: 15.612799644470215
#
# Band 5:
#   Data Type: float32
#   Min Value: 9.831060409545898
#   Max Value: 157.2164306640625
#   Mean Value: 40.46860885620117
#   Standard Deviation: 15.350693702697754
#
# Band 6:
#   Data Type: float32
#   Min Value: 9.71329402923584
#   Max Value: 160.6094970703125
#   Mean Value: 39.7846565246582
#   Standard Deviation: 15.154772758483887
#
# Band 7:
#   Data Type: float32
#   Min Value: 9.610780715942383
#   Max Value: 163.98854064941406
#   Mean Value: 39.18048095703125
#   Standard Deviation: 15.007584571838379
#
# Band 8:
#   Data Type: float32
#   Min Value: 9.518269538879395
#   Max Value: 167.37158203125
#   Mean Value: 38.63273620605469
#   Standard Deviation: 14.898491859436035
#
# Band 9:
#   Data Type: float32
#   Min Value: 9.43001651763916
#   Max Value: 170.7618408203125
#   Mean Value: 38.12649917602539
#   Standard Deviation: 14.820563316345215
#
# Band 10:
#   Data Type: float32
#   Min Value: 9.35257339477539
#   Max Value: 174.1279296875
#   Mean Value: 37.652095794677734
#   Standard Deviation: 14.76906681060791
#
# Band 11:
#   Data Type: float32
#   Min Value: 9.238739967346191
#   Max Value: 177.52052307128906
#   Mean Value: 37.20302963256836
#   Standard Deviation: 14.740507125854492
#
# Band 12:
#   Data Type: float32
#   Min Value: 9.128218650817871
#   Max Value: 180.9053955078125
#   Mean Value: 36.774879455566406
#   Standard Deviation: 14.73232364654541
#
# Band 13:
#   Data Type: float32
#   Min Value: 9.024328231811523
#   Max Value: 184.2744140625
#   Mean Value: 36.36457443237305
#   Standard Deviation: 14.742351531982422
#
# Band 14:
#   Data Type: float32
#   Min Value: 8.926250457763672
#   Max Value: 187.65847778320312
#   Mean Value: 35.9699592590332
#   Standard Deviation: 14.768813133239746
#
# Band 15:
#   Data Type: float32
#   Min Value: 8.8331937789917
#   Max Value: 191.02064514160156
#   Mean Value: 35.58930969238281
#   Standard Deviation: 14.81026840209961

# %%
maplot.plot_raster_on_world_extremes_cutoff(apple_irr_results, title="Apples, irrigated, 2030", quantiles=10, raster_band=15, perc_cutoff=0)
# Out:
# Raster has 425,217 unique values. Min: 4.49. Max: 143.77
# Using quantiles
# All positives route (quantiles)

# %%
maplot.plot_raster_on_world_extremes_cutoff(apple_rf_results, title="Apples, rainfed, 2030", quantiles=10, raster_band=15, perc_cutoff=0)
# Out:
# Raster has 424,702 unique values. Min: 6.12. Max: 143.77
# Using quantiles
# All positives route (quantiles)

# %% [markdown]
# Checking other tomatoes too

# %%
tomato_rf_raster_fp = "../LEAFs/SOC/rasters/Tomato_rf_2030y_SOC.tif"
tomato_irr_raster_fp = "../LEAFs/SOC/rasters/Tomato_irr_2030y_SOC.tif"

# %%
maplot.plot_raster_histogram(tomato_rf_raster_fp, band=15, mask_zeros=True, log_scale=True)

# %%
maplot.plot_raster_histogram(tomato_irr_raster_fp, band=15, mask_zeros=True, log_scale=True)

# %% [markdown]
# Checking the yields...

# %%
fao_yields = pl.read_csv("../data/crops/fao_crop_yields_1423.csv", separator=";")
fao_yields_tomatoes = fao_yields.filter(pl.col("Item") == "Tomatoes")

# %%
fao_yields_tomatoes.sort(by="avg_yield_1423").head(10)
# Out:
# shape: (10, 16)
# ┌──────────────┬──────────┬───────┬────────┬───┬────────┬──────────────┬─────────────┬─────────────┐
# │ Area         ┆ Item     ┆ Unit  ┆ Y2014  ┆ … ┆ Y2023  ┆ avg_yield_14 ┆ ratio_yield ┆ sd_yields_1 │
# │ ---          ┆ ---      ┆ ---   ┆ ---    ┆   ┆ ---    ┆ 23           ┆ _20_toavg   ┆ 423         │
# │ str          ┆ str      ┆ str   ┆ f64    ┆   ┆ f64    ┆ ---          ┆ ---         ┆ ---         │
# │              ┆          ┆       ┆        ┆   ┆        ┆ f64          ┆ f64         ┆ f64         │
# ╞══════════════╪══════════╪═══════╪════════╪═══╪════════╪══════════════╪═════════════╪═════════════╡
# │ Somalia      ┆ Tomatoes ┆ kg/ha ┆ 1438.2 ┆ … ┆ 1456.9 ┆ 1455.16      ┆ 0.999217    ┆ 5.948815    │
# │ Bhutan       ┆ Tomatoes ┆ kg/ha ┆ 3881.2 ┆ … ┆ 3412.6 ┆ 3244.67      ┆ 0.900422    ┆ 536.978521  │
# │ Papua New    ┆ Tomatoes ┆ kg/ha ┆ 4162.2 ┆ … ┆ 4101.9 ┆ 4101.05      ┆ 1.011282    ┆ 47.411776   │
# │ Guinea       ┆          ┆       ┆        ┆   ┆        ┆              ┆             ┆             │
# │ Togo         ┆ Tomatoes ┆ kg/ha ┆ 4227.8 ┆ … ┆ 4245.4 ┆ 4243.29      ┆ 0.999479    ┆ 5.30084     │
# │ Nigeria      ┆ Tomatoes ┆ kg/ha ┆ 7536.9 ┆ … ┆ 3466.9 ┆ 4497.59      ┆ 1.139121    ┆ 1549.176241 │
# │ Congo        ┆ Tomatoes ┆ kg/ha ┆ 4780.3 ┆ … ┆ 4723.3 ┆ 4740.32      ┆ 1.002542    ┆ 24.729772   │
# │ Timor-Leste  ┆ Tomatoes ┆ kg/ha ┆ 5020.1 ┆ … ┆ 5177.6 ┆ 5198.79      ┆ 1.010494    ┆ 86.838821   │
# │ Djibouti     ┆ Tomatoes ┆ kg/ha ┆ 6193.3 ┆ … ┆ 4554.4 ┆ 5335.54      ┆ 1.07092     ┆ 540.090367  │
# │ Ethiopia     ┆ Tomatoes ┆ kg/ha ┆ 6108.2 ┆ … ┆ 4933.1 ┆ 5373.2       ┆ 0.824148    ┆ 917.64245   │
# │ Western      ┆ Tomatoes ┆ kg/ha ┆ 8406.0 ┆ … ┆ 4556.8 ┆ 5609.7       ┆ 1.104315    ┆ 1425.050947 │
# │ Africa       ┆          ┆       ┆        ┆   ┆        ┆              ┆             ┆             │
# └──────────────┴──────────┴───────┴────────┴───┴────────┴──────────────┴─────────────┴─────────────┘

# %%
country_gdf = gpd.read_file("../data/CountryLayers/Country_Level0/g2015_2014_0.shp")

# %%
tomato_yields_gdf = country_gdf.merge(fao_yields_tomatoes.to_pandas(), how="left", left_on="ADM0_NAME", right_on="Area")
tomato_yields_gdf = tomato_yields_gdf[["ADM0_NAME","avg_yield_1423", "geometry"]]
tomato_yields_gdf["avg_yield_1423"] = tomato_yields_gdf["avg_yield_1423"]/1000

# %%
tomato_yields_gdf.sort_values(by="avg_yield_1423", ascending=False).head(20)
# Out:
#                     ADM0_NAME  avg_yield_1423  \
# 245                   Belgium       481.26176
# 208                    Sweden       403.53462
# 217                   Finland       388.81208
# 219                   Denmark       372.94022
# 213                   Ireland       359.80000
# 206                    Norway       344.92687
# 214                   Iceland       327.17500
# 246                   Austria       295.68632
# 243                   Germany       261.10194
# 244               Switzerland       215.68486
# 242                    France       137.08723
# 175                    Kuwait       132.96724
# 248               New Zealand       116.67753
# 115                    Guyana       112.46223
# 103  United States of America        94.76992
# 230                  Portugal        90.03750
# 155                  Malaysia        88.96665
# 36                    Morocco        87.41209
# 195                   Hungary        85.54186
# 196                    Poland        84.70511
#
#                                               geometry
# 245  MULTIPOLYGON (((4.9259 51.4414, 4.92832 51.438...
# 208  MULTIPOLYGON (((12.82739 55.85452, 12.82255 55...
# 217  MULTIPOLYGON (((22.96127 59.76882, 22.95158 59...
# 219  MULTIPOLYGON (((11.02427 54.83091, 11.02181 54...
# 213  MULTIPOLYGON (((-9.46571 51.4524, -9.46665 51....
# 206  MULTIPOLYGON (((7.62775 57.9749, 7.61696 57.96...
# 214  MULTIPOLYGON (((-20.56648 63.29607, -20.582 63...
# 246  POLYGON ((15.0374 49.01236, 15.04559 49.01129,...
# 243  MULTIPOLYGON (((8.72018 47.69629, 8.72092 47.6...
# 244  POLYGON ((8.62885 47.79308, 8.62784 47.78302, ...
# 242  MULTIPOLYGON (((9.26077 41.34248, 9.25845 41.3...
# 175  MULTIPOLYGON (((47.91846 29.35839, 47.91084 29...
# 248  MULTIPOLYGON (((169.19885 -52.46692, 169.20561...
# 115  MULTIPOLYGON (((-57.4701 6.32508, -57.4701 6.3...
# 103  MULTIPOLYGON (((-155.06856 19.73047, -155.0684...
# 230  MULTIPOLYGON (((-7.82993 36.99185, -7.83723 36...
# 155  MULTIPOLYGON (((103.43385 1.30704, 103.42789 1...
# 36   MULTIPOLYGON (((-9.79329 31.49641, -9.7935 31....
# 195  POLYGON ((21.49842 48.56273, 21.50172 48.55985...
# 196  MULTIPOLYGON (((14.2708 53.70551, 14.26853 53....

# %% [markdown]
# Now loading all tomato SPAM rasters

# %%
tom_spam_a = "../data/crops/spam2020V2r0_global_yield/spam2020_V2r0_global_Y_TOMA_A.tif"
tom_spam_i = "../data/crops/spam2020V2r0_global_yield/spam2020_V2r0_global_Y_TOMA_I.tif"
tom_spam_r = "../data/crops/spam2020V2r0_global_yield/spam2020_V2r0_global_Y_TOMA_R.tif"

# %%
maplot.plot_raster_on_world_extremes_cutoff(tom_spam_a, "Tomatoe yields, SPAM, All", perc_cutoff=0, quantiles=10)
# Out:
# Raster has 4,905 unique values. Min: 0.00. Max: 1,108.10
# Using quantiles
# All positives route (quantiles)

# %% [markdown]
# So it can be seen that the SPAM raster has indeed some extreme values

# %%
tomato_yields_gdf_nordic = tomato_yields_gdf[tomato_yields_gdf["ADM0_NAME"].isin(["Belgium"])]

# %%
maplot.plot_raster_over_gdf_showpolygonvalues(tom_spam_r, tomato_yields_gdf_nordic, title="SOC for Tomato, Rainfed",polygon_linewidth=0.25, polygon_value_col="avg_yield_1423", match_color_scale=True, n_quantiles=10, polygon_alpha=.25, band=1)
# Out:
# (<Figure size 1200x800 with 2 Axes>,
#  <Axes: title={'center': 'SOC for Tomato, Rainfed'}, xlabel='Longitude', ylabel='Latitude'>)

# %% [markdown]
# Checking if the yields distribution of SPAM is similar to SOC outputs

# %%
maplot.plot_raster_histogram(tom_spam_a, band=1, mask_zeros=True, log_scale=True)

# %%
maplot.plot_raster_histogram(tom_spam_i, band=1, mask_zeros=True, log_scale=True)

# %% [markdown]
# So there are a few values over 1,000 ton/ha, which are probably outliers.

# %% [markdown]
# #### 2.1.3. Forests
# All different forest and climate types, as well as the additional input required to run RothC model, have been included in [forest_baseline_rothc_scenarios](../data/forest/forest_baseline_rothc_scenarios.xlsx).

# %%
forest_rothc_scenario_fp = data_path("forest", "forest_baseline_rothc_scenarios.xlsx")

# %%
# Running scenarios. This takes time!
rothC.run_rothC_forest_scenarios_from_excel(forest_rothc_scenario_fp, force_new_files=False)
# Out:
# Forest - BRDC - Warm temperate dry already exists. Skipping...
# Forest - BRDC - Warm temperate moist already exists. Skipping...
# Forest - BRDC - Cold temperate dry already exists. Skipping...
# Forest - BRDC - Cold temperate moist already exists. Skipping...
# Forest - BRDC - Subtropical already exists. Skipping...
# Forest - BRDC - Tropical already exists. Skipping...
# Forest - BRDC - Boreal dry already exists. Skipping...
# Forest - BRDC - Boreal moist already exists. Skipping...
# Forest - NEEV - Boreal dry already exists. Skipping...
# Forest - NEEV - Boreal moist already exists. Skipping...
# Forest - NEEV - Cold temperate dry already exists. Skipping...
# Forest - NEEV - Cold temperate moist already exists. Skipping...
# Forest - NEEV - Subtropical already exists. Skipping...
# Forest - NEEV - Tropical already exists. Skipping...
# Running Forest - NEEV - Warm temperate dry
# Loading environmental data...
# Loading forest data...
# Running RothC...
# RothC months:   0%|          | 0/168 [00:00<?, ?it/s]
# Forest - NEEV - Warm temperate dry calculated. Continuing...

# %% [markdown]
# Checking some of the results...

# %%
forest_soc_result = LEAFs_dir()/"SOC/rasters/BRDC_Warm temperate dry_2030y_SOC.tif"

# %%
maplot.inspect_raster(forest_soc_result)
# Out:
# File: C:\Users\loyola\OneDrive - World Wildlife Fund, Inc\Documents\203. Python projects\SBTN_Test\LEAFs\SOC\rasters\BRDC_Warm temperate dry_2030y_SOC.tif
# Driver: GTiff
# Width, Height: 4320, 2083
# Number of Bands: 15
# CRS: EPSG:4326
# Bounds: BoundingBox(left=-179.99999999999997, bottom=-89.99999999999994, right=179.99999999999991, top=83.58333333333331)
# Pixel Size: (0.0833333333333333, 0.0833333333333333)
# No-data Value: nan
#
# --- Raster Metadata ---
# description: Estimated RothC SOC stock in t C/ha until year 2030 for Broadleaf Deciduous - Cold temperate dry forest type
# long_name: Soil Organic Carbon
# model: RothC rasterized vectorized
# units: t C/ha
# AREA_OR_POINT: Area
#
# --- Band Information ---
#
# Band 1:
#   Data Type: float32
#   Min Value: 10.975362777709961
#   Max Value: 169.39234924316406
#   Mean Value: 58.132720947265625
#   Standard Deviation: 18.82948875427246
#
# Band 2:
#   Data Type: float32
#   Min Value: 11.94847583770752
#   Max Value: 166.47434997558594
#   Mean Value: 61.274349212646484
#   Standard Deviation: 17.005569458007812
#
# Band 3:
#   Data Type: float32
#   Min Value: 13.016973495483398
#   Max Value: 163.50933837890625
#   Mean Value: 62.02734375
#   Standard Deviation: 16.91936492919922
#
# Band 4:
#   Data Type: float32
#   Min Value: 14.128962516784668
#   Max Value: 163.45477294921875
#   Mean Value: 62.737667083740234
#   Standard Deviation: 16.87940216064453
#
# Band 5:
#   Data Type: float32
#   Min Value: 15.290679931640625
#   Max Value: 165.281494140625
#   Mean Value: 63.4182014465332
#   Standard Deviation: 16.878952026367188
#
# Band 6:
#   Data Type: float32
#   Min Value: 16.48387908935547
#   Max Value: 167.23214721679688
#   Mean Value: 64.04713439941406
#   Standard Deviation: 16.91248893737793
#
# Band 7:
#   Data Type: float32
#   Min Value: 17.710294723510742
#   Max Value: 169.30870056152344
#   Mean Value: 64.63214874267578
#   Standard Deviation: 16.97585678100586
#
# Band 8:
#   Data Type: float32
#   Min Value: 18.97219467163086
#   Max Value: 171.51693725585938
#   Mean Value: 65.1807632446289
#   Standard Deviation: 17.06563377380371
#
# Band 9:
#   Data Type: float32
#   Min Value: 19.923494338989258
#   Max Value: 174.05947875976562
#   Mean Value: 65.71276092529297
#   Standard Deviation: 17.178709030151367
#
# Band 10:
#   Data Type: float32
#   Min Value: 20.01742935180664
#   Max Value: 176.6575927734375
#   Mean Value: 66.1907958984375
#   Standard Deviation: 17.311874389648438
#
# Band 11:
#   Data Type: float32
#   Min Value: 20.094684600830078
#   Max Value: 179.2509307861328
#   Mean Value: 66.63748931884766
#   Standard Deviation: 17.462331771850586
#
# Band 12:
#   Data Type: float32
#   Min Value: 20.17021942138672
#   Max Value: 181.85232543945312
#   Mean Value: 67.0637435913086
#   Standard Deviation: 17.628599166870117
#
# Band 13:
#   Data Type: float32
#   Min Value: 20.237560272216797
#   Max Value: 184.4556884765625
#   Mean Value: 67.464111328125
#   Standard Deviation: 17.80859375
#
# Band 14:
#   Data Type: float32
#   Min Value: 20.287250518798828
#   Max Value: 187.0440673828125
#   Mean Value: 67.82746124267578
#   Standard Deviation: 17.999839782714844
#
# Band 15:
#   Data Type: float32
#   Min Value: 20.348398208618164
#   Max Value: 189.64793395996094
#   Mean Value: 68.18466186523438
#   Standard Deviation: 18.200969696044922

# %%
maplot.plot_raster_on_world_extremes_cutoff(forest_soc_result, title="BRDC_Warm temperate dry_2030y_SOC", quantiles=10, raster_band=15, perc_cutoff=0)
# Out:
# Raster has 304,273 unique values. Min: 20.35. Max: 189.65
# Using quantiles
# All positives route (quantiles)

# %% [markdown]
# Checking the distribution to see if there are outliers

# %%
maplot.plot_raster_histogram(forest_soc_result, band=15, mask_zeros=True, log_scale=True)

# %% [markdown]
# Looks pretty good, no clear outliers

# %% [markdown]
# #### 2.1.4. Grasslands
# 6 different scenarios have been generated for different combinations of animals present:
#     1. Only cattle - average,
#     2. Only cattle - high productivity,
#     3. Only cattle - low productivity,
#     4. Only sheep,
#     5. Only goat,
#     6. all animals - average productivity.
#
# A csv with all different inputs can be found in [grassland_baseline_rothc_scenarios.csv](../data/grasslands/grassland_baseline_rothc_scenarios.csv). All inputs has been already created.

# %%
# scenario filepaths
forest_rothc_scenario_fp = data_path("grasslands", "grassland_baseline_rothc_scenarios.xlsx")

# %%
# Running scenarios. This takes time!
rothC.run_rothc_grassland_scenarios_from_excel(forest_rothc_scenario_fp, force_new_files=False)
# Out:
# Grassland - natural - sheep already exists. Skipping...
# Grassland - natural - goat already exists. Skipping...
# Grassland - natural - cattle_avg_sheep_goat already exists. Skipping...
# Grassland - natural - cattle_avg already exists. Skipping...
# Grassland - natural - cattle_hps already exists. Skipping...
# Running Grassland - natural - cattle_lps
# Loading environmental data...
# Loading natural grassland data...
# Running RothC...
# RothC months:   0%|          | 0/168 [00:00<?, ?it/s]
# Grassland - natural - cattle_lps calculated. Continuing...

# %% [markdown]
# Plotting some of them...

# %%
maplot.plot_raster_on_world_extremes_cutoff("../LEAFs/SOC/rasters/natural_grassland_cattle_avg_2030y_SOC.tif", title="Natural Grasslands\n Cattle, average productivity - 2030", raster_band=15, quantiles=10, label_title="SOC Stock [t C/ha]")
# Out:
# Raster has 1,203,714 unique values. Min: 22.92. Max: 114.26
# Using quantiles
# All positives route (quantiles)

# %%
maplot.plot_raster_on_world_extremes_cutoff("../LEAFs/SOC/rasters/natural_grassland_cattle_avg_sheep_goat_2030y_SOC.tif", title="Natural Grasslands\n Cattle, average productivity, Sheep & Goat - 2030", raster_band=15, quantiles=10, label_title="SOC Stock [t C/ha]")
# Out:
# Raster has 1,203,567 unique values. Min: 23.04. Max: 114.28
# Using quantiles
# All positives route (quantiles)

# %% [markdown]
# Checking the distribution

# %%
maplot.plot_raster_histogram("../LEAFs/SOC/rasters/natural_grassland_cattle_avg_sheep_goat_2030y_SOC.tif", band=15, mask_zeros=True, log_scale=True)

# %% [markdown]
# Looks ok, with 2 clear modes, and now clear outliers

# %%
maplot.plot_raster_histogram("../LEAFs/SOC/rasters/natural_grassland_cattle_avg_2030y_SOC.tif", band=15, mask_zeros=True, log_scale=True)

# %% [markdown]
# ## Step 3 - Country, Sub-Country, and Ecoregion Avearges
# After calculating all rasters, the averages can be calculated.
#
# ### Country
# Starting with countries

# %%
# Inputs that stay the same
input_folder = "../LEAFs/SOC/rasters/"
output_folder = "../LEAFs/SOC/"
cf_name = "SOC_2030"
cf_unit = "t C/ha"
reset_gpck = True

# %%
# Inputs that change by area type
area_type = "country"
layer_name = "soc_leaf_country"
corrected_shp = gpd.read_file('../data/CountryLayers/Country_Level0/g2015_2014_0_dissolved.shp')
master_key = "ADM0_NAME"
result_key = "country"

# %%
gpkg_path, df_results = mc.build_cfs_gpkg_from_rasters(
    input_folder =input_folder,
    output_folder = output_folder,
    layer_name=layer_name,
    master_gdf=corrected_shp,           # e.g., countries, subcountries, or ecoregions
    master_key=master_key,              # or 'ISO_A3', 'ADM1_NAME', 'ECO_NAME'
    result_key=result_key,              # must match the column emitted by your calc gdf
    input_raster_key_startswith=None,
    cf_name=cf_name,
    cf_unit=cf_unit,
    area_type=area_type,
    calc_kwargs=dict(raster_band = 15, outlier_method="log1p_win", std_thresh = 3),     # Chooses the raster band. Due to outliers in crops, setting it to windsorize, replacing all values above 3 stds with mean + 3 stds.
    reset_gpkg=reset_gpck,
    run_test=False                             # Use run test to run the first 3 files
)

print(f"Wrote {df_results.shape[0]} rows into {gpkg_path}")
# Out:
# 2025-12-02 13:16:16,183 - INFO - Building 'soc_leaf_country' from rasters in ../LEAFs/SOC/rasters/ into ../LEAFs/SOC/ (../LEAFs/SOC/SOC_2030_country.gpkg)
# Processing rasters (soc_leaf_country):   0%|          | 0/82 [00:00<?, ?raster/s]
# 2025-12-02 13:16:45,608 - INFO - Calculating SOC_2030 for Apple_irr_2030y_SOC...
# Calculating SOC_2030 for Apple_irr_2030y_SOC...
# 2025-12-02 13:19:58,205 - INFO - Calculating SOC_2030 for Apple_rf_2030y_SOC...
# Calculating SOC_2030 for Apple_rf_2030y_SOC...
# 2025-12-02 13:22:59,270 - INFO - Calculating SOC_2030 for BRDC_Boreal dry_2030y_SOC...
# Calculating SOC_2030 for BRDC_Boreal dry_2030y_SOC...
# 2025-12-02 13:29:35,850 - INFO - Calculating SOC_2030 for BRDC_Boreal moist_2030y_SOC...
# Calculating SOC_2030 for BRDC_Boreal moist_2030y_SOC...
# 2025-12-02 13:32:47,955 - INFO - Calculating SOC_2030 for BRDC_Cold temperate dry_2030y_SOC...
# Calculating SOC_2030 for BRDC_Cold temperate dry_2030y_SOC...
# 2025-12-02 13:35:36,648 - INFO - Calculating SOC_2030 for BRDC_Cold temperate moist_2030y_SOC...
# Calculating SOC_2030 for BRDC_Cold temperate moist_2030y_SOC...
# 2025-12-02 13:38:14,390 - INFO - Calculating SOC_2030 for BRDC_Subtropical_2030y_SOC...
# Calculating SOC_2030 for BRDC_Subtropical_2030y_SOC...
# 2025-12-02 13:40:57,354 - INFO - Calculating SOC_2030 for BRDC_Tropical_2030y_SOC...
# Calculating SOC_2030 for BRDC_Tropical_2030y_SOC...
# 2025-12-02 13:43:36,852 - INFO - Calculating SOC_2030 for BRDC_Warm temperate dry_2030y_SOC...
# Calculating SOC_2030 for BRDC_Warm temperate dry_2030y_SOC...
# 2025-12-02 13:46:31,499 - INFO - Calculating SOC_2030 for BRDC_Warm temperate moist_2030y_SOC...
# Calculating SOC_2030 for BRDC_Warm temperate moist_2030y_SOC...
# 2025-12-02 13:49:12,650 - INFO - Calculating SOC_2030 for Banana_irr_2030y_SOC...
# Calculating SOC_2030 for Banana_irr_2030y_SOC...
# 2025-12-02 13:52:19,647 - INFO - Calculating SOC_2030 for Banana_rf_2030y_SOC...
# Calculating SOC_2030 for Banana_rf_2030y_SOC...
# 2025-12-02 13:55:06,417 - INFO - Calculating SOC_2030 for Barley_irr_roff_2030y_SOC...
# Calculating SOC_2030 for Barley_irr_roff_2030y_SOC...
# 2025-12-02 13:58:25,981 - INFO - Calculating SOC_2030 for Barley_irr_ron_2030y_SOC...
# Calculating SOC_2030 for Barley_irr_ron_2030y_SOC...
# 2025-12-02 14:01:42,015 - INFO - Calculating SOC_2030 for Barley_rf_roff_2030y_SOC...
# Calculating SOC_2030 for Barley_rf_roff_2030y_SOC...
# 2025-12-02 14:04:48,329 - INFO - Calculating SOC_2030 for Barley_rf_ron_2030y_SOC...
# Calculating SOC_2030 for Barley_rf_ron_2030y_SOC...
# 2025-12-02 14:07:46,109 - INFO - Calculating SOC_2030 for Cabbage_irr_2030y_SOC...
# Calculating SOC_2030 for Cabbage_irr_2030y_SOC...
# 2025-12-02 14:10:32,962 - INFO - Calculating SOC_2030 for Carrot_irr_2030y_SOC...
# Calculating SOC_2030 for Carrot_irr_2030y_SOC...
# 2025-12-02 14:13:24,171 - INFO - Calculating SOC_2030 for Cocoa_irr_2030y_SOC...
# Calculating SOC_2030 for Cocoa_irr_2030y_SOC...
# 2025-12-02 14:15:35,869 - INFO - Calculating SOC_2030 for Cocoa_rf_2030y_SOC...
# Calculating SOC_2030 for Cocoa_rf_2030y_SOC...
# 2025-12-02 14:17:47,206 - INFO - Calculating SOC_2030 for Coconut_irr_2030y_SOC...
# Calculating SOC_2030 for Coconut_irr_2030y_SOC...
# 2025-12-02 14:20:11,247 - INFO - Calculating SOC_2030 for Coconut_rf_2030y_SOC...
# Calculating SOC_2030 for Coconut_rf_2030y_SOC...
# 2025-12-02 14:22:37,299 - INFO - Calculating SOC_2030 for Coffee_irr_2030y_SOC...
# Calculating SOC_2030 for Coffee_irr_2030y_SOC...
# 2025-12-02 14:24:47,380 - INFO - Calculating SOC_2030 for Coffee_rf_2030y_SOC...
# Calculating SOC_2030 for Coffee_rf_2030y_SOC...
# 2025-12-02 14:26:59,308 - INFO - Calculating SOC_2030 for Cotton_irr_2030y_SOC...
# Calculating SOC_2030 for Cotton_irr_2030y_SOC...
# 2025-12-02 14:30:02,928 - INFO - Calculating SOC_2030 for Cotton_rf_2030y_SOC...
# Calculating SOC_2030 for Cotton_rf_2030y_SOC...
# 2025-12-02 14:33:00,721 - INFO - Calculating SOC_2030 for Grapes_irr_2030y_SOC...
# Calculating SOC_2030 for Grapes_irr_2030y_SOC...
# 2025-12-02 14:35:38,906 - INFO - Calculating SOC_2030 for Grapes_rf_2030y_SOC...
# Calculating SOC_2030 for Grapes_rf_2030y_SOC...
# 2025-12-02 14:38:21,354 - INFO - Calculating SOC_2030 for Groundnut_irr_2030y_SOC...
# Calculating SOC_2030 for Groundnut_irr_2030y_SOC...
# 2025-12-02 14:41:05,473 - INFO - Calculating SOC_2030 for Groundnut_rf_2030y_SOC...
# Calculating SOC_2030 for Groundnut_rf_2030y_SOC...
# 2025-12-02 14:43:58,551 - INFO - Calculating SOC_2030 for Maize_irr_roff_2030y_SOC...
# Calculating SOC_2030 for Maize_irr_roff_2030y_SOC...
# 2025-12-02 14:46:51,385 - INFO - Calculating SOC_2030 for Maize_irr_ron_2030y_SOC...
# Calculating SOC_2030 for Maize_irr_ron_2030y_SOC...
# 2025-12-02 14:49:57,662 - INFO - Calculating SOC_2030 for Maize_rf_2030y_SOC...
# Calculating SOC_2030 for Maize_rf_2030y_SOC...
# 2025-12-02 14:52:19,573 - INFO - Calculating SOC_2030 for NEEV_Boreal dry_2030y_SOC...
# Calculating SOC_2030 for NEEV_Boreal dry_2030y_SOC...
# 2025-12-02 14:54:25,262 - INFO - Calculating SOC_2030 for NEEV_Boreal moist_2030y_SOC...
# Calculating SOC_2030 for NEEV_Boreal moist_2030y_SOC...
# 2025-12-02 14:56:29,569 - INFO - Calculating SOC_2030 for NEEV_Cold temperate dry_2030y_SOC...
# Calculating SOC_2030 for NEEV_Cold temperate dry_2030y_SOC...
# 2025-12-02 14:58:34,318 - INFO - Calculating SOC_2030 for NEEV_Cold temperate moist_2030y_SOC...
# Calculating SOC_2030 for NEEV_Cold temperate moist_2030y_SOC...
# 2025-12-02 15:00:29,427 - INFO - Calculating SOC_2030 for NEEV_Subtropical_2030y_SOC...
# Calculating SOC_2030 for NEEV_Subtropical_2030y_SOC...
# 2025-12-02 15:02:20,650 - INFO - Calculating SOC_2030 for NEEV_Tropical_2030y_SOC...
# Calculating SOC_2030 for NEEV_Tropical_2030y_SOC...
# 2025-12-02 15:04:23,023 - INFO - Calculating SOC_2030 for NEEV_Warm temperate dry_2030y_SOC...
# Calculating SOC_2030 for NEEV_Warm temperate dry_2030y_SOC...
# 2025-12-02 15:07:26,406 - INFO - Calculating SOC_2030 for Oil palm_irr_2030y_SOC...
# Calculating SOC_2030 for Oil palm_irr_2030y_SOC...
# 2025-12-02 15:09:36,478 - INFO - Calculating SOC_2030 for Oil palm_rf_2030y_SOC...
# Calculating SOC_2030 for Oil palm_rf_2030y_SOC...
# 2025-12-02 15:12:10,916 - INFO - Calculating SOC_2030 for Olive_irr_2030y_SOC...
# Calculating SOC_2030 for Olive_irr_2030y_SOC...
# 2025-12-02 15:14:30,519 - INFO - Calculating SOC_2030 for Olive_rf_2030y_SOC...
# Calculating SOC_2030 for Olive_rf_2030y_SOC...
# 2025-12-02 15:16:43,646 - INFO - Calculating SOC_2030 for Onion_irr_2030y_SOC...
# Calculating SOC_2030 for Onion_irr_2030y_SOC...
# 2025-12-02 15:20:02,626 - INFO - Calculating SOC_2030 for Orange_irr_2030y_SOC...
# Calculating SOC_2030 for Orange_irr_2030y_SOC...
# 2025-12-02 15:23:37,140 - INFO - Calculating SOC_2030 for Orange_rf_2030y_SOC...
# Calculating SOC_2030 for Orange_rf_2030y_SOC...
# 2025-12-02 15:27:00,398 - INFO - Calculating SOC_2030 for Potato_irr_2030y_SOC...
# Calculating SOC_2030 for Potato_irr_2030y_SOC...
# 2025-12-02 15:30:15,582 - INFO - Calculating SOC_2030 for Potato_rf_2030y_SOC...
# Calculating SOC_2030 for Potato_rf_2030y_SOC...
# 2025-12-02 15:33:27,691 - INFO - Calculating SOC_2030 for Rapeseed_irr_roff_2030y_SOC...
# Calculating SOC_2030 for Rapeseed_irr_roff_2030y_SOC...
# 2025-12-02 15:37:09,657 - INFO - Calculating SOC_2030 for Rapeseed_irr_ron_2030y_SOC...
# Calculating SOC_2030 for Rapeseed_irr_ron_2030y_SOC...
# 2025-12-02 15:40:47,021 - INFO - Calculating SOC_2030 for Rapeseed_rf_roff_2030y_SOC...
# Calculating SOC_2030 for Rapeseed_rf_roff_2030y_SOC...
# 2025-12-02 15:44:38,985 - INFO - Calculating SOC_2030 for Rapeseed_rf_ron_2030y_SOC...
# Calculating SOC_2030 for Rapeseed_rf_ron_2030y_SOC...
# 2025-12-02 15:48:18,575 - INFO - Calculating SOC_2030 for Rice_irr_2030y_SOC...
# Calculating SOC_2030 for Rice_irr_2030y_SOC...
# 2025-12-02 15:51:44,255 - INFO - Calculating SOC_2030 for Rice_rf_2030y_SOC...
# Calculating SOC_2030 for Rice_rf_2030y_SOC...
# 2025-12-02 15:55:38,396 - INFO - Calculating SOC_2030 for Sorghum_irr_roff_2030y_SOC...
# Calculating SOC_2030 for Sorghum_irr_roff_2030y_SOC...
# 2025-12-02 15:59:24,413 - INFO - Calculating SOC_2030 for Sorghum_irr_ron_2030y_SOC...
# Calculating SOC_2030 for Sorghum_irr_ron_2030y_SOC...
# 2025-12-02 16:03:31,865 - INFO - Calculating SOC_2030 for Sorghum_rf_2030y_SOC...
# Calculating SOC_2030 for Sorghum_rf_2030y_SOC...
# 2025-12-02 16:07:36,190 - INFO - Calculating SOC_2030 for Soybean_irr_2030y_SOC...
# Calculating SOC_2030 for Soybean_irr_2030y_SOC...
# 2025-12-02 16:11:06,723 - INFO - Calculating SOC_2030 for Soybean_rf_2030y_SOC...
# Calculating SOC_2030 for Soybean_rf_2030y_SOC...
# 2025-12-02 16:15:02,216 - INFO - Calculating SOC_2030 for Sugar beet_irr_2030y_SOC...
# Calculating SOC_2030 for Sugar beet_irr_2030y_SOC...
# 2025-12-02 16:18:35,334 - INFO - Calculating SOC_2030 for Sugar beet_rf_2030y_SOC...
# Calculating SOC_2030 for Sugar beet_rf_2030y_SOC...
# 2025-12-02 16:22:14,067 - INFO - Calculating SOC_2030 for Sugarcane_irr_2030y_SOC...
# Calculating SOC_2030 for Sugarcane_irr_2030y_SOC...
# 2025-12-02 16:24:55,321 - INFO - Calculating SOC_2030 for Sugarcane_rf_2030y_SOC...
# Calculating SOC_2030 for Sugarcane_rf_2030y_SOC...
# 2025-12-02 16:27:06,341 - INFO - Calculating SOC_2030 for Sunflower_irr_2030y_SOC...
# Calculating SOC_2030 for Sunflower_irr_2030y_SOC...
# 2025-12-02 16:29:58,640 - INFO - Calculating SOC_2030 for Sunflower_rf_2030y_SOC...
# Calculating SOC_2030 for Sunflower_rf_2030y_SOC...
# 2025-12-02 16:32:52,857 - INFO - Calculating SOC_2030 for Sweet potato_irr_2030y_SOC...
# Calculating SOC_2030 for Sweet potato_irr_2030y_SOC...
# 2025-12-02 16:35:43,079 - INFO - Calculating SOC_2030 for Sweet potato_rf_2030y_SOC...
# Calculating SOC_2030 for Sweet potato_rf_2030y_SOC...
# 2025-12-02 16:38:36,064 - INFO - Calculating SOC_2030 for Tobacco_irr_2030y_SOC...
# Calculating SOC_2030 for Tobacco_irr_2030y_SOC...
# 2025-12-02 16:41:25,486 - INFO - Calculating SOC_2030 for Tobacco_rf_2030y_SOC...
# Calculating SOC_2030 for Tobacco_rf_2030y_SOC...
# 2025-12-02 16:44:05,100 - INFO - Calculating SOC_2030 for Tomato_irr_2030y_SOC...
# Calculating SOC_2030 for Tomato_irr_2030y_SOC...
# 2025-12-02 16:46:54,290 - INFO - Calculating SOC_2030 for Tomato_rf_2030y_SOC...
# Calculating SOC_2030 for Tomato_rf_2030y_SOC...
# 2025-12-02 16:54:48,986 - INFO - Calculating SOC_2030 for Wheat_irr_roff_2030y_SOC...
# Calculating SOC_2030 for Wheat_irr_roff_2030y_SOC...
# 2025-12-02 17:03:20,479 - INFO - Calculating SOC_2030 for Wheat_irr_ron_2030y_SOC...
# Calculating SOC_2030 for Wheat_irr_ron_2030y_SOC...
# 2025-12-02 17:12:30,279 - INFO - Calculating SOC_2030 for Wheat_rf_roff_2030y_SOC...
# Calculating SOC_2030 for Wheat_rf_roff_2030y_SOC...
# 2025-12-02 17:16:27,825 - INFO - Calculating SOC_2030 for Wheat_rf_ron_2030y_SOC...
# Calculating SOC_2030 for Wheat_rf_ron_2030y_SOC...
# 2025-12-02 17:19:46,610 - INFO - Calculating SOC_2030 for natural_grassland_cattle_avg_2030y_SOC...
# Calculating SOC_2030 for natural_grassland_cattle_avg_2030y_SOC...
# 2025-12-02 17:23:07,206 - INFO - Calculating SOC_2030 for natural_grassland_cattle_avg_sheep_goat_2030y_SOC...
# Calculating SOC_2030 for natural_grassland_cattle_avg_sheep_goat_2030y_SOC...
# 2025-12-02 17:26:25,784 - INFO - Calculating SOC_2030 for natural_grassland_cattle_hps_2030y_SOC...
# Calculating SOC_2030 for natural_grassland_cattle_hps_2030y_SOC...
# 2025-12-02 17:29:53,001 - INFO - Calculating SOC_2030 for natural_grassland_cattle_lps_2030y_SOC...
# Calculating SOC_2030 for natural_grassland_cattle_lps_2030y_SOC...
# 2025-12-02 17:33:32,041 - INFO - Calculating SOC_2030 for natural_grassland_goat_2030y_SOC...
# Calculating SOC_2030 for natural_grassland_goat_2030y_SOC...
# 2025-12-02 17:37:08,494 - INFO - Calculating SOC_2030 for natural_grassland_sheep_2030y_SOC...
# Calculating SOC_2030 for natural_grassland_sheep_2030y_SOC...
# 2025-12-02 17:40:46,601 - INFO - Wrote 22670 attribute rows into ../LEAFs/SOC/SOC_2030_country.gpkg (geometry layer='geometry_layer', values layer='soc_leaf_country').
# Wrote 68010 rows into ../LEAFs/SOC/SOC_2030_country.gpkg

# %% [markdown]
# Checking outputs

# %%
gpkg_path = "../LEAFs/SOC/SOC_2030_country.gpkg"

# %%
gdf_test_values = gpd.read_file(gpkg_path, layer=layer_name)
gdf_test_values.sort_values(by=["cf"]).head()
# Out:
#                          ADM0_NAME                   flow_name        cf  \
# 8556          United Arab Emirates    Maize_irr_roff_2030y_SOC  6.245543
# 3576          United Arab Emirates   Barley_irr_roff_2030y_SOC  6.278253
# 15353              Ma'tan al-Sarra  Sorghum_irr_roff_2030y_SOC  6.412316
# 15323  Iran  (Islamic Republic of)  Sorghum_irr_roff_2030y_SOC  6.450605
# 15476               Western Sahara  Sorghum_irr_roff_2030y_SOC  6.591035
#
#        cf_median    cf_std                    _source_file
# 8556    6.245543  0.000000    Maize_irr_roff_2030y_SOC.tif
# 3576    6.278253  0.000000   Barley_irr_roff_2030y_SOC.tif
# 15353   6.399345  0.318216  Sorghum_irr_roff_2030y_SOC.tif
# 15323   6.523183  0.322636  Sorghum_irr_roff_2030y_SOC.tif
# 15476   6.213234  1.009174  Sorghum_irr_roff_2030y_SOC.tif

# %% [markdown]
# And it can be seen that the output has all values. Opening the dataset it can be seen it include NaNs.
#
# To plot it, the geoemtries layer need to be imported as:

# %%
gdf_test_geometries = gpd.read_file(gpkg_path, layer="geometry_layer")

# %% [markdown]
# And then merged.

# %%
gdf_test = gdf_test_geometries.merge(gdf_test_values.drop(columns="_source_file"), how="left", on="ADM0_NAME")

# %% [markdown]
# Plotting Tomatoes

# %%
Tomato_irr = gdf_test[gdf_test["flow_name"]=="Tomato_irr_2030y_SOC"]

# %%
fig, ax = plt.subplots(figsize=(14, 8)) 
Tomato_irr.plot(column="cf", ax=ax, cmap="viridis", 
           legend=True, 
           legend_kwds={"label": "SOC [t C/ha]", "shrink": 0.8}, 
           missing_kwds={"color": "lightgrey", "label": "No value"}) 

ax.set_title("Tomatoes, Irrigated, SOC LEAFs")
plt.tight_layout() 
plt.show()

# %% [markdown]
# Checking df

# %%
df_results.sort_values(by="value", ascending=False).head(10)
# Out:
#                       ADM0_NAME                   country       value  \
# 58277                    Sweden                    Sweden  843.915360
# 58107                   Denmark                   Denmark  795.976900
# 28600                   Iceland                   Iceland  765.638306
# 28324                   Iceland                   Iceland  757.295857
# 28472  United States of America  United States of America  703.255689
# 28748  United States of America  United States of America  696.835938
# 2881                    Iceland                   Iceland  694.697693
# 2605                    Iceland                   Iceland  688.164536
# 28691        Russian Federation        Russian Federation  683.818787
# 28415        Russian Federation        Russian Federation  673.873438
#
#           metric                    flow_name
# 58277    cf_mean         Tomato_irr_2030y_SOC
# 58107    cf_mean         Tomato_irr_2030y_SOC
# 28600  cf_median  NEEV_Boreal moist_2030y_SOC
# 28324    cf_mean  NEEV_Boreal moist_2030y_SOC
# 28472    cf_mean  NEEV_Boreal moist_2030y_SOC
# 28748  cf_median  NEEV_Boreal moist_2030y_SOC
# 2881   cf_median  BRDC_Boreal moist_2030y_SOC
# 2605     cf_mean  BRDC_Boreal moist_2030y_SOC
# 28691  cf_median  NEEV_Boreal moist_2030y_SOC
# 28415    cf_mean  NEEV_Boreal moist_2030y_SOC

# %% [markdown]
# ### Subcountries
# Now proceeding, same as for countries, with sub-country regions.
#
# Loading the necessary data and parameters

# %%
# Inputs that change by area type
area_type = "subcountry"
layer_name = "soc_leaf_subcountry"
corrected_shp = gpd.read_file('../data/CountryLayers/SubCountry_Level1/g2015_2014_1.shp')
master_key = "ADM1_CODE"
result_key = "ADM1_CODE"

# %% [markdown]
# Running the averages

# %%
gpkg_path, df_results = mc.build_cfs_gpkg_from_rasters(
    input_folder =input_folder,
    output_folder = output_folder,
    layer_name=layer_name,
    master_gdf=corrected_shp,           # e.g., countries, subcountries, or ecoregions
    master_key=master_key,              # or 'ISO_A3', 'ADM1_CODE', 'ECO_NAME'
    result_key=result_key,              # must match the column emitted by your calc gdf
    input_raster_key_startswith=None,
    cf_name=cf_name,
    cf_unit=cf_unit,
    area_type=area_type,
    calc_kwargs=dict(raster_band = 15, outlier_method="log1p_win", std_thresh = 3),     # Chooses the raster band. Due to outliers in crops, setting it to windsorize, replacing all values above 3 stds with mean + 3 stds.
    reset_gpkg=True,
    run_test=False                             # Use run test to run the first 3 files
)

print(f"Wrote {df_results.shape[0]} rows into {gpkg_path}")
# Out:
# 2025-12-15 13:18:19,915 - INFO - Building 'soc_leaf_subcountry' from rasters in ../LEAFs/SOC/rasters/ into ../LEAFs/SOC/ (../LEAFs/SOC/SOC_2030_subcountry.gpkg)
# Processing rasters (soc_leaf_subcountry):   0%|          | 0/82 [00:00<?, ?raster/s]
# 2025-12-15 13:18:50,632 - INFO - Calculating SOC_2030 for Apple_irr_2030y_SOC...
# Calculating SOC_2030 for Apple_irr_2030y_SOC...
# 2025-12-15 13:38:24,842 - INFO - Calculating SOC_2030 for Apple_rf_2030y_SOC...
# Calculating SOC_2030 for Apple_rf_2030y_SOC...
# 2025-12-15 13:58:13,614 - INFO - Calculating SOC_2030 for BRDC_Boreal dry_2030y_SOC...
# Calculating SOC_2030 for BRDC_Boreal dry_2030y_SOC...
# 2025-12-15 14:16:12,608 - INFO - Calculating SOC_2030 for BRDC_Boreal moist_2030y_SOC...
# Calculating SOC_2030 for BRDC_Boreal moist_2030y_SOC...
# 2025-12-15 14:34:29,453 - INFO - Calculating SOC_2030 for BRDC_Cold temperate dry_2030y_SOC...
# Calculating SOC_2030 for BRDC_Cold temperate dry_2030y_SOC...
# 2025-12-15 14:50:53,804 - INFO - Calculating SOC_2030 for BRDC_Cold temperate moist_2030y_SOC...
# Calculating SOC_2030 for BRDC_Cold temperate moist_2030y_SOC...
# 2025-12-15 15:08:42,949 - INFO - Calculating SOC_2030 for BRDC_Subtropical_2030y_SOC...
# Calculating SOC_2030 for BRDC_Subtropical_2030y_SOC...
# 2025-12-15 15:25:49,152 - INFO - Calculating SOC_2030 for BRDC_Tropical_2030y_SOC...
# Calculating SOC_2030 for BRDC_Tropical_2030y_SOC...
# 2025-12-15 15:44:04,740 - INFO - Calculating SOC_2030 for BRDC_Warm temperate dry_2030y_SOC...
# Calculating SOC_2030 for BRDC_Warm temperate dry_2030y_SOC...
# 2025-12-15 15:59:28,854 - INFO - Calculating SOC_2030 for BRDC_Warm temperate moist_2030y_SOC...
# Calculating SOC_2030 for BRDC_Warm temperate moist_2030y_SOC...
# 2025-12-15 16:15:43,621 - INFO - Calculating SOC_2030 for Banana_irr_2030y_SOC...
# Calculating SOC_2030 for Banana_irr_2030y_SOC...
# 2025-12-15 16:31:18,317 - INFO - Calculating SOC_2030 for Banana_rf_2030y_SOC...
# Calculating SOC_2030 for Banana_rf_2030y_SOC...
# 2025-12-15 16:46:31,147 - INFO - Calculating SOC_2030 for Barley_irr_roff_2030y_SOC...
# Calculating SOC_2030 for Barley_irr_roff_2030y_SOC...
# 2025-12-15 17:04:18,541 - INFO - Calculating SOC_2030 for Barley_irr_ron_2030y_SOC...
# Calculating SOC_2030 for Barley_irr_ron_2030y_SOC...
# 2025-12-15 17:26:50,410 - INFO - Calculating SOC_2030 for Barley_rf_roff_2030y_SOC...
# Calculating SOC_2030 for Barley_rf_roff_2030y_SOC...
# 2025-12-15 17:49:10,882 - INFO - Calculating SOC_2030 for Barley_rf_ron_2030y_SOC...
# Calculating SOC_2030 for Barley_rf_ron_2030y_SOC...
# 2025-12-15 18:12:01,393 - INFO - Calculating SOC_2030 for Cabbage_irr_2030y_SOC...
# Calculating SOC_2030 for Cabbage_irr_2030y_SOC...
# 2025-12-15 18:34:44,976 - INFO - Calculating SOC_2030 for Carrot_irr_2030y_SOC...
# Calculating SOC_2030 for Carrot_irr_2030y_SOC...
# 2025-12-15 18:52:08,062 - INFO - Calculating SOC_2030 for Cocoa_irr_2030y_SOC...
# Calculating SOC_2030 for Cocoa_irr_2030y_SOC...
# 2025-12-15 19:10:23,590 - INFO - Calculating SOC_2030 for Cocoa_rf_2030y_SOC...
# Calculating SOC_2030 for Cocoa_rf_2030y_SOC...
# 2025-12-15 19:28:40,222 - INFO - Calculating SOC_2030 for Coconut_irr_2030y_SOC...
# Calculating SOC_2030 for Coconut_irr_2030y_SOC...
# 2025-12-15 19:46:51,781 - INFO - Calculating SOC_2030 for Coconut_rf_2030y_SOC...
# Calculating SOC_2030 for Coconut_rf_2030y_SOC...
# 2025-12-15 20:05:04,269 - INFO - Calculating SOC_2030 for Coffee_irr_2030y_SOC...
# Calculating SOC_2030 for Coffee_irr_2030y_SOC...
# 2025-12-15 20:23:13,420 - INFO - Calculating SOC_2030 for Coffee_rf_2030y_SOC...
# Calculating SOC_2030 for Coffee_rf_2030y_SOC...
# 2025-12-15 20:41:23,089 - INFO - Calculating SOC_2030 for Cotton_irr_2030y_SOC...
# Calculating SOC_2030 for Cotton_irr_2030y_SOC...
# 2025-12-15 21:01:04,149 - INFO - Calculating SOC_2030 for Cotton_rf_2030y_SOC...
# Calculating SOC_2030 for Cotton_rf_2030y_SOC...
# 2025-12-15 21:19:42,745 - INFO - Calculating SOC_2030 for Grapes_irr_2030y_SOC...
# Calculating SOC_2030 for Grapes_irr_2030y_SOC...
# 2025-12-15 21:38:05,149 - INFO - Calculating SOC_2030 for Grapes_rf_2030y_SOC...
# Calculating SOC_2030 for Grapes_rf_2030y_SOC...
# 2025-12-15 21:56:55,790 - INFO - Calculating SOC_2030 for Groundnut_irr_2030y_SOC...
# Calculating SOC_2030 for Groundnut_irr_2030y_SOC...
# 2025-12-15 22:13:07,025 - INFO - Calculating SOC_2030 for Groundnut_rf_2030y_SOC...
# Calculating SOC_2030 for Groundnut_rf_2030y_SOC...
# 2025-12-15 22:26:26,353 - INFO - Calculating SOC_2030 for Maize_irr_roff_2030y_SOC...
# Calculating SOC_2030 for Maize_irr_roff_2030y_SOC...
# 2025-12-15 22:40:05,361 - INFO - Calculating SOC_2030 for Maize_irr_ron_2030y_SOC...
# Calculating SOC_2030 for Maize_irr_ron_2030y_SOC...
# 2025-12-15 22:53:39,835 - INFO - Calculating SOC_2030 for Maize_rf_2030y_SOC...
# Calculating SOC_2030 for Maize_rf_2030y_SOC...
# 2025-12-15 23:07:28,375 - INFO - Calculating SOC_2030 for NEEV_Boreal dry_2030y_SOC...
# Calculating SOC_2030 for NEEV_Boreal dry_2030y_SOC...
# 2025-12-15 23:21:01,557 - INFO - Calculating SOC_2030 for NEEV_Boreal moist_2030y_SOC...
# Calculating SOC_2030 for NEEV_Boreal moist_2030y_SOC...
# 2025-12-15 23:34:21,319 - INFO - Calculating SOC_2030 for NEEV_Cold temperate dry_2030y_SOC...
# Calculating SOC_2030 for NEEV_Cold temperate dry_2030y_SOC...
# 2025-12-15 23:47:46,231 - INFO - Calculating SOC_2030 for NEEV_Cold temperate moist_2030y_SOC...
# Calculating SOC_2030 for NEEV_Cold temperate moist_2030y_SOC...
# 2025-12-16 00:01:10,672 - INFO - Calculating SOC_2030 for NEEV_Subtropical_2030y_SOC...
# Calculating SOC_2030 for NEEV_Subtropical_2030y_SOC...
# 2025-12-16 00:14:30,380 - INFO - Calculating SOC_2030 for NEEV_Tropical_2030y_SOC...
# Calculating SOC_2030 for NEEV_Tropical_2030y_SOC...
# 2025-12-16 00:27:47,845 - INFO - Calculating SOC_2030 for NEEV_Warm temperate dry_2030y_SOC...
# Calculating SOC_2030 for NEEV_Warm temperate dry_2030y_SOC...
# 2025-12-16 00:41:06,077 - INFO - Calculating SOC_2030 for Oil palm_irr_2030y_SOC...
# Calculating SOC_2030 for Oil palm_irr_2030y_SOC...
# 2025-12-16 00:54:14,958 - INFO - Calculating SOC_2030 for Oil palm_rf_2030y_SOC...
# Calculating SOC_2030 for Oil palm_rf_2030y_SOC...
# 2025-12-16 01:07:30,459 - INFO - Calculating SOC_2030 for Olive_irr_2030y_SOC...
# Calculating SOC_2030 for Olive_irr_2030y_SOC...
# 2025-12-16 01:20:44,910 - INFO - Calculating SOC_2030 for Olive_rf_2030y_SOC...
# Calculating SOC_2030 for Olive_rf_2030y_SOC...
# 2025-12-16 01:33:55,955 - INFO - Calculating SOC_2030 for Onion_irr_2030y_SOC...
# Calculating SOC_2030 for Onion_irr_2030y_SOC...
# 2025-12-16 01:47:13,187 - INFO - Calculating SOC_2030 for Orange_irr_2030y_SOC...
# Calculating SOC_2030 for Orange_irr_2030y_SOC...
# 2025-12-16 02:00:44,005 - INFO - Calculating SOC_2030 for Orange_rf_2030y_SOC...
# Calculating SOC_2030 for Orange_rf_2030y_SOC...
# 2025-12-16 02:14:13,363 - INFO - Calculating SOC_2030 for Potato_irr_2030y_SOC...
# Calculating SOC_2030 for Potato_irr_2030y_SOC...
# 2025-12-16 02:27:55,171 - INFO - Calculating SOC_2030 for Potato_rf_2030y_SOC...
# Calculating SOC_2030 for Potato_rf_2030y_SOC...
# 2025-12-16 02:41:34,423 - INFO - Calculating SOC_2030 for Rapeseed_irr_roff_2030y_SOC...
# Calculating SOC_2030 for Rapeseed_irr_roff_2030y_SOC...
# 2025-12-16 02:54:59,901 - INFO - Calculating SOC_2030 for Rapeseed_irr_ron_2030y_SOC...
# Calculating SOC_2030 for Rapeseed_irr_ron_2030y_SOC...
# 2025-12-16 03:08:30,010 - INFO - Calculating SOC_2030 for Rapeseed_rf_roff_2030y_SOC...
# Calculating SOC_2030 for Rapeseed_rf_roff_2030y_SOC...
# 2025-12-16 03:21:58,974 - INFO - Calculating SOC_2030 for Rapeseed_rf_ron_2030y_SOC...
# Calculating SOC_2030 for Rapeseed_rf_ron_2030y_SOC...
# 2025-12-16 03:35:27,448 - INFO - Calculating SOC_2030 for Rice_irr_2030y_SOC...
# Calculating SOC_2030 for Rice_irr_2030y_SOC...
# 2025-12-16 03:48:53,829 - INFO - Calculating SOC_2030 for Rice_rf_2030y_SOC...
# Calculating SOC_2030 for Rice_rf_2030y_SOC...
# 2025-12-16 04:02:24,162 - INFO - Calculating SOC_2030 for Sorghum_irr_roff_2030y_SOC...
# Calculating SOC_2030 for Sorghum_irr_roff_2030y_SOC...
# 2025-12-16 08:41:48,694 - INFO - Calculating SOC_2030 for Sorghum_irr_ron_2030y_SOC...
# Calculating SOC_2030 for Sorghum_irr_ron_2030y_SOC...
# 2025-12-16 08:55:19,384 - INFO - Calculating SOC_2030 for Sorghum_rf_2030y_SOC...
# Calculating SOC_2030 for Sorghum_rf_2030y_SOC...
# 2025-12-16 09:09:00,350 - INFO - Calculating SOC_2030 for Soybean_irr_2030y_SOC...
# Calculating SOC_2030 for Soybean_irr_2030y_SOC...
# 2025-12-16 09:22:30,672 - INFO - Calculating SOC_2030 for Soybean_rf_2030y_SOC...
# Calculating SOC_2030 for Soybean_rf_2030y_SOC...
# 2025-12-16 09:36:07,076 - INFO - Calculating SOC_2030 for Sugar beet_irr_2030y_SOC...
# Calculating SOC_2030 for Sugar beet_irr_2030y_SOC...
# 2025-12-16 09:52:06,996 - INFO - Calculating SOC_2030 for Sugar beet_rf_2030y_SOC...
# Calculating SOC_2030 for Sugar beet_rf_2030y_SOC...
# 2025-12-16 10:09:34,292 - INFO - Calculating SOC_2030 for Sugarcane_irr_2030y_SOC...
# Calculating SOC_2030 for Sugarcane_irr_2030y_SOC...
# 2025-12-16 11:00:25,269 - INFO - Calculating SOC_2030 for Sugarcane_rf_2030y_SOC...
# Calculating SOC_2030 for Sugarcane_rf_2030y_SOC...
# 2025-12-16 11:22:02,081 - INFO - Calculating SOC_2030 for Sunflower_irr_2030y_SOC...
# Calculating SOC_2030 for Sunflower_irr_2030y_SOC...
# 2025-12-16 11:43:36,592 - INFO - Calculating SOC_2030 for Sunflower_rf_2030y_SOC...
# Calculating SOC_2030 for Sunflower_rf_2030y_SOC...
# 2025-12-16 12:18:30,951 - INFO - Calculating SOC_2030 for Sweet potato_irr_2030y_SOC...
# Calculating SOC_2030 for Sweet potato_irr_2030y_SOC...
# 2025-12-16 12:35:38,559 - INFO - Calculating SOC_2030 for Sweet potato_rf_2030y_SOC...
# Calculating SOC_2030 for Sweet potato_rf_2030y_SOC...
# 2025-12-16 12:53:14,699 - INFO - Calculating SOC_2030 for Tobacco_irr_2030y_SOC...
# Calculating SOC_2030 for Tobacco_irr_2030y_SOC...
# 2025-12-16 13:10:58,275 - INFO - Calculating SOC_2030 for Tobacco_rf_2030y_SOC...
# Calculating SOC_2030 for Tobacco_rf_2030y_SOC...
# 2025-12-16 13:28:38,630 - INFO - Calculating SOC_2030 for Tomato_irr_2030y_SOC...
# Calculating SOC_2030 for Tomato_irr_2030y_SOC...
# 2025-12-16 13:45:53,556 - INFO - Calculating SOC_2030 for Tomato_rf_2030y_SOC...
# Calculating SOC_2030 for Tomato_rf_2030y_SOC...
# 2025-12-16 14:04:36,618 - INFO - Calculating SOC_2030 for Wheat_irr_roff_2030y_SOC...
# Calculating SOC_2030 for Wheat_irr_roff_2030y_SOC...
# 2025-12-16 14:23:54,936 - INFO - Calculating SOC_2030 for Wheat_irr_ron_2030y_SOC...
# Calculating SOC_2030 for Wheat_irr_ron_2030y_SOC...
# 2025-12-16 14:44:51,465 - INFO - Calculating SOC_2030 for Wheat_rf_roff_2030y_SOC...
# Calculating SOC_2030 for Wheat_rf_roff_2030y_SOC...
# 2025-12-16 15:03:15,456 - INFO - Calculating SOC_2030 for Wheat_rf_ron_2030y_SOC...
# Calculating SOC_2030 for Wheat_rf_ron_2030y_SOC...
# 2025-12-16 15:21:45,307 - INFO - Calculating SOC_2030 for natural_grassland_cattle_avg_2030y_SOC...
# Calculating SOC_2030 for natural_grassland_cattle_avg_2030y_SOC...
# 2025-12-16 15:39:34,103 - INFO - Calculating SOC_2030 for natural_grassland_cattle_avg_sheep_goat_2030y_SOC...
# Calculating SOC_2030 for natural_grassland_cattle_avg_sheep_goat_2030y_SOC...
# 2025-12-16 15:58:16,588 - INFO - Calculating SOC_2030 for natural_grassland_cattle_hps_2030y_SOC...
# Calculating SOC_2030 for natural_grassland_cattle_hps_2030y_SOC...
# 2025-12-16 16:27:17,119 - INFO - Calculating SOC_2030 for natural_grassland_cattle_lps_2030y_SOC...
# Calculating SOC_2030 for natural_grassland_cattle_lps_2030y_SOC...
# 2025-12-16 17:00:31,569 - INFO - Calculating SOC_2030 for natural_grassland_goat_2030y_SOC...
# Calculating SOC_2030 for natural_grassland_goat_2030y_SOC...
# 2025-12-16 17:39:09,120 - INFO - Calculating SOC_2030 for natural_grassland_sheep_2030y_SOC...
# Calculating SOC_2030 for natural_grassland_sheep_2030y_SOC...
# 2025-12-16 17:57:49,661 - INFO - Wrote 280604 attribute rows into ../LEAFs/SOC/SOC_2030_subcountry.gpkg (geometry layer='geometry_layer', values layer='soc_leaf_subcountry').
# Wrote 841812 rows into ../LEAFs/SOC/SOC_2030_subcountry.gpkg

# %% [markdown]
# Checking results...

# %%
gdf_test_values = gpd.read_file(gpkg_path, layer=layer_name)
gdf_test_values.sort_values(by=["cf"], ascending=False).head()
# Out:
#         ADM1_CODE             flow_name           cf    cf_median      cf_std  \
# 242311       2789  Tomato_irr_2030y_SOC  1751.586426  1749.381470    4.320960
# 242315       2793  Tomato_irr_2030y_SOC  1745.841553  1746.632080    2.144287
# 242457       1078  Tomato_irr_2030y_SOC  1612.102661  1614.350098    8.157726
# 242469      40857  Tomato_irr_2030y_SOC  1598.019043  1599.647705    9.471235
# 242468      40856  Tomato_irr_2030y_SOC  1538.114624  1599.386230  268.761505
#
#                     _source_file
# 242311  Tomato_irr_2030y_SOC.tif
# 242315  Tomato_irr_2030y_SOC.tif
# 242457  Tomato_irr_2030y_SOC.tif
# 242469  Tomato_irr_2030y_SOC.tif
# 242468  Tomato_irr_2030y_SOC.tif

# %% [markdown]
# And it can be seen that the output has all values. Opening the dataset it can be seen it include NaNs.
#
# To plot it, the geoemtries layer need to be imported as:

# %%
gdf_test_geometries = gpd.read_file(gpkg_path, layer="geometry_layer")

# %% [markdown]
# And then merged.

# %%
gdf_test = gdf_test_geometries.merge(gdf_test_values.drop(columns="_source_file"), how="left", on="ADM1_CODE")

# %% [markdown]
# Plotting Apples

# %%
Apples_irr = gdf_test[gdf_test["flow_name"]=="Apple_irr_2030y_SOC"]
Tomato_irr = gdf_test[gdf_test["flow_name"]=="Tomato_irr_2030y_SOC"]

# %%
fig, ax = plt.subplots(figsize=(14, 8)) 
Apples_irr.plot(column="cf", ax=ax, cmap="viridis", 
           legend=True, 
           legend_kwds={"label": "SOC [t C/ha]", "shrink": 0.8}, 
           missing_kwds={"color": "lightgrey", "label": "No value"}) 

ax.set_title("Apples, Irrigated, SOC LEAFs")
plt.tight_layout() 
plt.show()

# %%
fig, ax = plt.subplots(figsize=(14, 8)) 
Tomato_irr.plot(column="cf", ax=ax, cmap="viridis", 
           legend=True, 
           legend_kwds={"label": "SOC [t C/ha]", "shrink": 0.8}, 
           missing_kwds={"color": "lightgrey", "label": "No value"}) 

ax.set_title("Tomatoes, Irrigated, SOC LEAFs")
plt.tight_layout() 
plt.show()

# %% [markdown]
# ### Ecoregions
# Finally, ecoregions are run

# %%
# Inputs that change by area type
area_type = "ecoregion"
layer_name = "soc_leaf_ecoregions"
master_key = "ECO_ID"
result_key = "er_id"
er_gdf = gpd.read_file("../data/Ecoregions2017/Ecoregions2017.shp")

# %%
gpkg_path, df_results = mc.build_cfs_gpkg_from_rasters(
    input_folder =input_folder,
    output_folder = output_folder,
    layer_name=layer_name,
    master_gdf=er_gdf,           # e.g., countries, subcountries, or ecoregions
    master_key=master_key,              # or 'ISO_A3', 'ADM1_NAME', 'ECO_NAME'
    result_key=result_key,              # must match the column emitted by your calc gdf
    input_raster_key_startswith=None,
    cf_name=cf_name,
    cf_unit=cf_unit,
    area_type=area_type,
    calc_kwargs=dict(raster_band = 15, outlier_method="log1p_win", std_thresh = 3),     # Chooses the raster band. Due to outliers in crops, setting it to windsorize, replacing all values above 3 stds with mean + 3 stds.
    reset_gpkg=reset_gpck,
    run_test=False                             # Use run test to run the first 3 files
)

print(f"Wrote {df_results.shape[0]} rows into {gpkg_path}")
# Out:
# 2025-12-04 09:49:37,727 - INFO - Building 'soc_leaf_ecoregions' from rasters in ../LEAFs/SOC/rasters/ into ../LEAFs/SOC/ (../LEAFs/SOC/SOC_2030_ecoregion.gpkg)
# Processing rasters (soc_leaf_ecoregions):   0%|          | 0/82 [00:00<?, ?raster/s]
# 2025-12-04 09:49:52,619 - INFO - Calculating SOC_2030 for Apple_irr_2030y_SOC...
# Calculating SOC_2030 for Apple_irr_2030y_SOC...
# 2025-12-04 09:57:03,985 - INFO - Calculating SOC_2030 for Apple_rf_2030y_SOC...
# Calculating SOC_2030 for Apple_rf_2030y_SOC...
# 2025-12-04 10:05:08,133 - INFO - Calculating SOC_2030 for BRDC_Boreal dry_2030y_SOC...
# Calculating SOC_2030 for BRDC_Boreal dry_2030y_SOC...
# 2025-12-04 10:11:47,054 - INFO - Calculating SOC_2030 for BRDC_Boreal moist_2030y_SOC...
# Calculating SOC_2030 for BRDC_Boreal moist_2030y_SOC...
# 2025-12-04 10:18:10,508 - INFO - Calculating SOC_2030 for BRDC_Cold temperate dry_2030y_SOC...
# Calculating SOC_2030 for BRDC_Cold temperate dry_2030y_SOC...
# 2025-12-04 10:23:08,967 - INFO - Calculating SOC_2030 for BRDC_Cold temperate moist_2030y_SOC...
# Calculating SOC_2030 for BRDC_Cold temperate moist_2030y_SOC...
# 2025-12-04 10:28:12,411 - INFO - Calculating SOC_2030 for BRDC_Subtropical_2030y_SOC...
# Calculating SOC_2030 for BRDC_Subtropical_2030y_SOC...
# 2025-12-04 10:33:24,016 - INFO - Calculating SOC_2030 for BRDC_Tropical_2030y_SOC...
# Calculating SOC_2030 for BRDC_Tropical_2030y_SOC...
# 2025-12-04 10:37:49,345 - INFO - Calculating SOC_2030 for BRDC_Warm temperate dry_2030y_SOC...
# Calculating SOC_2030 for BRDC_Warm temperate dry_2030y_SOC...
# 2025-12-04 10:43:31,740 - INFO - Calculating SOC_2030 for BRDC_Warm temperate moist_2030y_SOC...
# Calculating SOC_2030 for BRDC_Warm temperate moist_2030y_SOC...
# 2025-12-04 10:49:23,133 - INFO - Calculating SOC_2030 for Banana_irr_2030y_SOC...
# Calculating SOC_2030 for Banana_irr_2030y_SOC...
# 2025-12-04 10:54:56,169 - INFO - Calculating SOC_2030 for Banana_rf_2030y_SOC...
# Calculating SOC_2030 for Banana_rf_2030y_SOC...
# 2025-12-04 10:59:11,246 - INFO - Calculating SOC_2030 for Barley_irr_roff_2030y_SOC...
# Calculating SOC_2030 for Barley_irr_roff_2030y_SOC...
# 2025-12-04 11:05:52,408 - INFO - Calculating SOC_2030 for Barley_irr_ron_2030y_SOC...
# Calculating SOC_2030 for Barley_irr_ron_2030y_SOC...
# 2025-12-04 11:12:43,430 - INFO - Calculating SOC_2030 for Barley_rf_roff_2030y_SOC...
# Calculating SOC_2030 for Barley_rf_roff_2030y_SOC...
# 2025-12-04 11:18:58,461 - INFO - Calculating SOC_2030 for Barley_rf_ron_2030y_SOC...
# Calculating SOC_2030 for Barley_rf_ron_2030y_SOC...
# 2025-12-04 11:24:45,296 - INFO - Calculating SOC_2030 for Cabbage_irr_2030y_SOC...
# Calculating SOC_2030 for Cabbage_irr_2030y_SOC...
# 2025-12-04 11:31:12,705 - INFO - Calculating SOC_2030 for Carrot_irr_2030y_SOC...
# Calculating SOC_2030 for Carrot_irr_2030y_SOC...
# 2025-12-04 11:37:46,424 - INFO - Calculating SOC_2030 for Cocoa_irr_2030y_SOC...
# Calculating SOC_2030 for Cocoa_irr_2030y_SOC...
# 2025-12-04 11:42:34,271 - INFO - Calculating SOC_2030 for Cocoa_rf_2030y_SOC...
# Calculating SOC_2030 for Cocoa_rf_2030y_SOC...
# 2025-12-04 11:47:57,479 - INFO - Calculating SOC_2030 for Coconut_irr_2030y_SOC...
# Calculating SOC_2030 for Coconut_irr_2030y_SOC...
# 2025-12-04 11:52:54,573 - INFO - Calculating SOC_2030 for Coconut_rf_2030y_SOC...
# Calculating SOC_2030 for Coconut_rf_2030y_SOC...
# 2025-12-04 11:57:50,512 - INFO - Calculating SOC_2030 for Coffee_irr_2030y_SOC...
# Calculating SOC_2030 for Coffee_irr_2030y_SOC...
# 2025-12-04 12:02:45,377 - INFO - Calculating SOC_2030 for Coffee_rf_2030y_SOC...
# Calculating SOC_2030 for Coffee_rf_2030y_SOC...
# 2025-12-04 12:12:48,507 - INFO - Calculating SOC_2030 for Cotton_irr_2030y_SOC...
# Calculating SOC_2030 for Cotton_irr_2030y_SOC...
# 2025-12-04 12:31:10,671 - INFO - Calculating SOC_2030 for Cotton_rf_2030y_SOC...
# Calculating SOC_2030 for Cotton_rf_2030y_SOC...
# 2025-12-04 12:46:19,580 - INFO - Calculating SOC_2030 for Grapes_irr_2030y_SOC...
# Calculating SOC_2030 for Grapes_irr_2030y_SOC...
# 2025-12-04 13:03:47,939 - INFO - Calculating SOC_2030 for Grapes_rf_2030y_SOC...
# Calculating SOC_2030 for Grapes_rf_2030y_SOC...
# 2025-12-04 13:22:31,525 - INFO - Calculating SOC_2030 for Groundnut_irr_2030y_SOC...
# Calculating SOC_2030 for Groundnut_irr_2030y_SOC...
# 2025-12-04 13:41:12,085 - INFO - Calculating SOC_2030 for Groundnut_rf_2030y_SOC...
# Calculating SOC_2030 for Groundnut_rf_2030y_SOC...
# 2025-12-04 13:57:28,015 - INFO - Calculating SOC_2030 for Maize_irr_roff_2030y_SOC...
# Calculating SOC_2030 for Maize_irr_roff_2030y_SOC...
# 2025-12-04 14:07:03,327 - INFO - Calculating SOC_2030 for Maize_irr_ron_2030y_SOC...
# Calculating SOC_2030 for Maize_irr_ron_2030y_SOC...
# 2025-12-04 14:15:34,116 - INFO - Calculating SOC_2030 for Maize_rf_2030y_SOC...
# Calculating SOC_2030 for Maize_rf_2030y_SOC...
# 2025-12-04 14:21:55,032 - INFO - Calculating SOC_2030 for NEEV_Boreal dry_2030y_SOC...
# Calculating SOC_2030 for NEEV_Boreal dry_2030y_SOC...
# 2025-12-04 14:28:07,935 - INFO - Calculating SOC_2030 for NEEV_Boreal moist_2030y_SOC...
# Calculating SOC_2030 for NEEV_Boreal moist_2030y_SOC...
# 2025-12-04 14:34:58,686 - INFO - Calculating SOC_2030 for NEEV_Cold temperate dry_2030y_SOC...
# Calculating SOC_2030 for NEEV_Cold temperate dry_2030y_SOC...
# 2025-12-04 14:41:13,683 - INFO - Calculating SOC_2030 for NEEV_Cold temperate moist_2030y_SOC...
# Calculating SOC_2030 for NEEV_Cold temperate moist_2030y_SOC...
# 2025-12-04 14:47:16,821 - INFO - Calculating SOC_2030 for NEEV_Subtropical_2030y_SOC...
# Calculating SOC_2030 for NEEV_Subtropical_2030y_SOC...
# 2025-12-04 14:56:00,034 - INFO - Calculating SOC_2030 for NEEV_Tropical_2030y_SOC...
# Calculating SOC_2030 for NEEV_Tropical_2030y_SOC...
# 2025-12-04 15:02:28,104 - INFO - Calculating SOC_2030 for NEEV_Warm temperate dry_2030y_SOC...
# Calculating SOC_2030 for NEEV_Warm temperate dry_2030y_SOC...
# 2025-12-04 15:09:49,110 - INFO - Calculating SOC_2030 for Oil palm_irr_2030y_SOC...
# Calculating SOC_2030 for Oil palm_irr_2030y_SOC...
# 2025-12-04 15:17:14,415 - INFO - Calculating SOC_2030 for Oil palm_rf_2030y_SOC...
# Calculating SOC_2030 for Oil palm_rf_2030y_SOC...
# 2025-12-04 15:22:58,175 - INFO - Calculating SOC_2030 for Olive_irr_2030y_SOC...
# Calculating SOC_2030 for Olive_irr_2030y_SOC...
# 2025-12-04 15:28:54,897 - INFO - Calculating SOC_2030 for Olive_rf_2030y_SOC...
# Calculating SOC_2030 for Olive_rf_2030y_SOC...
# 2025-12-04 15:34:21,911 - INFO - Calculating SOC_2030 for Onion_irr_2030y_SOC...
# Calculating SOC_2030 for Onion_irr_2030y_SOC...
# 2025-12-04 15:40:03,449 - INFO - Calculating SOC_2030 for Orange_irr_2030y_SOC...
# Calculating SOC_2030 for Orange_irr_2030y_SOC...
# 2025-12-04 15:46:47,785 - INFO - Calculating SOC_2030 for Orange_rf_2030y_SOC...
# Calculating SOC_2030 for Orange_rf_2030y_SOC...
# 2025-12-04 15:53:06,094 - INFO - Calculating SOC_2030 for Potato_irr_2030y_SOC...
# Calculating SOC_2030 for Potato_irr_2030y_SOC...
# 2025-12-04 15:59:33,694 - INFO - Calculating SOC_2030 for Potato_rf_2030y_SOC...
# Calculating SOC_2030 for Potato_rf_2030y_SOC...
# 2025-12-04 16:06:25,715 - INFO - Calculating SOC_2030 for Rapeseed_irr_roff_2030y_SOC...
# Calculating SOC_2030 for Rapeseed_irr_roff_2030y_SOC...
# 2025-12-04 16:13:17,275 - INFO - Calculating SOC_2030 for Rapeseed_irr_ron_2030y_SOC...
# Calculating SOC_2030 for Rapeseed_irr_ron_2030y_SOC...
# 2025-12-04 16:20:01,547 - INFO - Calculating SOC_2030 for Rapeseed_rf_roff_2030y_SOC...
# Calculating SOC_2030 for Rapeseed_rf_roff_2030y_SOC...
# 2025-12-04 16:25:47,154 - INFO - Calculating SOC_2030 for Rapeseed_rf_ron_2030y_SOC...
# Calculating SOC_2030 for Rapeseed_rf_ron_2030y_SOC...
# 2025-12-04 16:31:05,557 - INFO - Calculating SOC_2030 for Rice_irr_2030y_SOC...
# Calculating SOC_2030 for Rice_irr_2030y_SOC...
# 2025-12-04 16:37:12,455 - INFO - Calculating SOC_2030 for Rice_rf_2030y_SOC...
# Calculating SOC_2030 for Rice_rf_2030y_SOC...
# 2025-12-04 16:43:45,219 - INFO - Calculating SOC_2030 for Sorghum_irr_roff_2030y_SOC...
# Calculating SOC_2030 for Sorghum_irr_roff_2030y_SOC...
# 2025-12-04 16:50:41,284 - INFO - Calculating SOC_2030 for Sorghum_irr_ron_2030y_SOC...
# Calculating SOC_2030 for Sorghum_irr_ron_2030y_SOC...
# 2025-12-04 16:57:35,081 - INFO - Calculating SOC_2030 for Sorghum_rf_2030y_SOC...
# Calculating SOC_2030 for Sorghum_rf_2030y_SOC...
# 2025-12-04 17:04:09,756 - INFO - Calculating SOC_2030 for Soybean_irr_2030y_SOC...
# Calculating SOC_2030 for Soybean_irr_2030y_SOC...
# 2025-12-04 17:10:41,804 - INFO - Calculating SOC_2030 for Soybean_rf_2030y_SOC...
# Calculating SOC_2030 for Soybean_rf_2030y_SOC...
# 2025-12-04 17:17:44,314 - INFO - Calculating SOC_2030 for Sugar beet_irr_2030y_SOC...
# Calculating SOC_2030 for Sugar beet_irr_2030y_SOC...
# 2025-12-04 17:23:52,082 - INFO - Calculating SOC_2030 for Sugar beet_rf_2030y_SOC...
# Calculating SOC_2030 for Sugar beet_rf_2030y_SOC...
# 2025-12-04 17:30:20,587 - INFO - Calculating SOC_2030 for Sugarcane_irr_2030y_SOC...
# Calculating SOC_2030 for Sugarcane_irr_2030y_SOC...
# 2025-12-04 17:37:06,453 - INFO - Calculating SOC_2030 for Sugarcane_rf_2030y_SOC...
# Calculating SOC_2030 for Sugarcane_rf_2030y_SOC...
# 2025-12-04 17:43:30,592 - INFO - Calculating SOC_2030 for Sunflower_irr_2030y_SOC...
# Calculating SOC_2030 for Sunflower_irr_2030y_SOC...
# 2025-12-04 17:49:22,598 - INFO - Calculating SOC_2030 for Sunflower_rf_2030y_SOC...
# Calculating SOC_2030 for Sunflower_rf_2030y_SOC...
# 2025-12-04 17:55:13,433 - INFO - Calculating SOC_2030 for Sweet potato_irr_2030y_SOC...
# Calculating SOC_2030 for Sweet potato_irr_2030y_SOC...
# 2025-12-04 18:00:29,765 - INFO - Calculating SOC_2030 for Sweet potato_rf_2030y_SOC...
# Calculating SOC_2030 for Sweet potato_rf_2030y_SOC...
# 2025-12-04 18:05:55,443 - INFO - Calculating SOC_2030 for Tobacco_irr_2030y_SOC...
# Calculating SOC_2030 for Tobacco_irr_2030y_SOC...
# 2025-12-04 18:11:24,298 - INFO - Calculating SOC_2030 for Tobacco_rf_2030y_SOC...
# Calculating SOC_2030 for Tobacco_rf_2030y_SOC...
# 2025-12-04 18:16:55,725 - INFO - Calculating SOC_2030 for Tomato_irr_2030y_SOC...
# Calculating SOC_2030 for Tomato_irr_2030y_SOC...
# 2025-12-04 18:22:29,281 - INFO - Calculating SOC_2030 for Tomato_rf_2030y_SOC...
# Calculating SOC_2030 for Tomato_rf_2030y_SOC...
# 2025-12-04 18:27:59,497 - INFO - Calculating SOC_2030 for Wheat_irr_roff_2030y_SOC...
# Calculating SOC_2030 for Wheat_irr_roff_2030y_SOC...
# 2025-12-04 18:33:30,574 - INFO - Calculating SOC_2030 for Wheat_irr_ron_2030y_SOC...
# Calculating SOC_2030 for Wheat_irr_ron_2030y_SOC...
# 2025-12-04 18:38:49,793 - INFO - Calculating SOC_2030 for Wheat_rf_roff_2030y_SOC...
# Calculating SOC_2030 for Wheat_rf_roff_2030y_SOC...
# 2025-12-04 18:44:11,175 - INFO - Calculating SOC_2030 for Wheat_rf_ron_2030y_SOC...
# Calculating SOC_2030 for Wheat_rf_ron_2030y_SOC...
# 2025-12-04 18:49:29,970 - INFO - Calculating SOC_2030 for natural_grassland_cattle_avg_2030y_SOC...
# Calculating SOC_2030 for natural_grassland_cattle_avg_2030y_SOC...
# 2025-12-04 18:54:48,286 - INFO - Calculating SOC_2030 for natural_grassland_cattle_avg_sheep_goat_2030y_SOC...
# Calculating SOC_2030 for natural_grassland_cattle_avg_sheep_goat_2030y_SOC...
# 2025-12-04 19:00:08,770 - INFO - Calculating SOC_2030 for natural_grassland_cattle_hps_2030y_SOC...
# Calculating SOC_2030 for natural_grassland_cattle_hps_2030y_SOC...
# 2025-12-04 19:05:29,469 - INFO - Calculating SOC_2030 for natural_grassland_cattle_lps_2030y_SOC...
# Calculating SOC_2030 for natural_grassland_cattle_lps_2030y_SOC...
# 2025-12-04 19:10:48,556 - INFO - Calculating SOC_2030 for natural_grassland_goat_2030y_SOC...
# Calculating SOC_2030 for natural_grassland_goat_2030y_SOC...
# 2025-12-04 19:16:10,933 - INFO - Calculating SOC_2030 for natural_grassland_sheep_2030y_SOC...
# Calculating SOC_2030 for natural_grassland_sheep_2030y_SOC...
# 2025-12-04 19:21:45,114 - INFO - Wrote 69454 attribute rows into ../LEAFs/SOC/SOC_2030_ecoregion.gpkg (geometry layer='geometry_layer', values layer='soc_leaf_ecoregions').
# Wrote 208362 rows into ../LEAFs/SOC/SOC_2030_ecoregion.gpkg

# %% [markdown]
# Checking outputs

# %%
# gpkg_path = "../LEAFs/SOC/SOC_2030_country.gpkg"

# %%
gdf_test_values = gpd.read_file(gpkg_path, layer=layer_name)
gdf_test_values.sort_values(by=["cf"], ascending=False).head()
# Out:
#        ECO_ID                    flow_name          cf   cf_median  \
# 28868     410  NEEV_Boreal moist_2030y_SOC  941.591675  941.591675
# 60129     672         Tomato_irr_2030y_SOC  932.782715  462.020935
# 28840     408  NEEV_Boreal moist_2030y_SOC  847.401001  819.939087
# 28838     407  NEEV_Boreal moist_2030y_SOC  824.646240  824.849792
# 29513     781  NEEV_Boreal moist_2030y_SOC  774.189331  775.478577
#
#            cf_std                     _source_file
# 28868    0.000000  NEEV_Boreal moist_2030y_SOC.tif
# 60129  599.298218         Tomato_irr_2030y_SOC.tif
# 28840   69.088402  NEEV_Boreal moist_2030y_SOC.tif
# 28838    7.331543  NEEV_Boreal moist_2030y_SOC.tif
# 29513   24.046566  NEEV_Boreal moist_2030y_SOC.tif

# %% [markdown]
# And it can be seen that the output has all values. Opening the dataset it can be seen it include NaNs.
#
# To plot it, the geoemtries layer need to be imported as:

# %%
gdf_test_geometries = gpd.read_file(gpkg_path, layer="geometry_layer")

# %% [markdown]
# And then merged.

# %%
gdf_test = gdf_test_geometries.merge(gdf_test_values.drop(columns="_source_file"), how="left", on="ECO_ID")

# %% [markdown]
# Plotting Apples

# %%
Apples_irr = gdf_test[gdf_test["flow_name"]=="Apple_irr_2030y_SOC"]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 Apples_irr = gdf_test[gdf_test["flow_name"]=="Apple_irr_2030y_SOC"]
#
# NameError: name 'gdf_test' is not defined

# %%
fig, ax = plt.subplots(figsize=(14, 8)) 
Apples_irr.plot(column="cf", ax=ax, cmap="viridis", 
           legend=True, 
           legend_kwds={"label": "SOC [t C/ha]", "shrink": 0.8}, 
           missing_kwds={"color": "lightgrey", "label": "No value"}) 

ax.set_title("Apples, Irrigated, SOC LEAFs")
plt.tight_layout() 
plt.show()
