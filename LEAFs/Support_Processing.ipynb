# %% [markdown]
# # Support file processing
# File to do all pre-processing needed that shouldn't be uploaded

# %% [markdown]
# ## Generating all land use maps...
#
# Loading inventory of SOC Foreground files

# %%
# modules
import polars as pl
import numpy as np
import sbtn_leaf.map_calculations as mc
import sbtn_leaf.map_plotting as mp

# files
files_inventory = pl.read_csv("../data/SOC_Foreground_files/foreground_occupation_file_index.csv")

# %%
files_inventory.head()
# Out:
# shape: (5, 3)
# ┌────────────────────────────────┬────────────────────────────────┬────────────────────────────────┐
# │ file_name                      ┆ land_use                       ┆ path                           │
# │ ---                            ┆ ---                            ┆ ---                            │
# │ str                            ┆ str                            ┆ str                            │
# ╞════════════════════════════════╪════════════════════════════════╪════════════════════════════════╡
# │ Occ_foreground_Broadleaf_Decid ┆ Broadleaf_Deciduous_Boreal_dry ┆ ../data/soc_Raster_Foreground_ │
# │ …                              ┆                                ┆ …                              │
# │ Occ_foreground_Broadleaf_Decid ┆ Broadleaf_Deciduous_Boreal_moi ┆ ../data/soc_Raster_Foreground_ │
# │ …                              ┆ …                              ┆ …                              │
# │ Occ_foreground_Broadleaf_Decid ┆ Broadleaf_Deciduous_Cold_tempe ┆ ../data/soc_Raster_Foreground_ │
# │ …                              ┆ …                              ┆ …                              │
# │ Occ_foreground_Broadleaf_Decid ┆ Broadleaf_Deciduous_Cold_tempe ┆ ../data/soc_Raster_Foreground_ │
# │ …                              ┆ …                              ┆ …                              │
# │ Occ_foreground_Broadleaf_Decid ┆ Broadleaf_Deciduous_Subtropica ┆ ../data/soc_Raster_Foreground_ │
# │ …                              ┆ …                              ┆ …                              │
# └────────────────────────────────┴────────────────────────────────┴────────────────────────────────┘

# %% [markdown]
# Now creating the loop

# %%
mp.inspect_raster("../data/SOC_Foreground_files/Occ_foreground_Broadleaf_Deciduous_Boreal_dry.tif")
# Out:
# File: ../data/SOC_Foreground_files/Occ_foreground_Broadleaf_Deciduous_Boreal_dry.tif
# Driver: GTiff
# Width, Height: 4320, 2083
# Number of Bands: 1
# CRS: EPSG:4326
# Bounds: BoundingBox(left=-179.99999999999997, bottom=-89.99999999999994, right=179.99999999999991, top=83.58333333333331)
# Pixel Size: (0.0833333333333333, 0.0833333333333333)
# No-data Value: None
#
# --- Raster Metadata ---
# TIFFTAG_SOFTWARE: MATLAB 9.8, Mapping Toolbox 4.10
# AREA_OR_POINT: Area
#
# --- Band Information ---
#
# Band 1:
#   Data Type: float64
#   Min Value: 50.9646539740672
#   Max Value: 27020.6993905685
#   Mean Value: 508.318560865058
#   Standard Deviation: 656.1209725770067

# %%
mp.plot_raster_histogram("../data/SOC_Foreground_files/Occ_foreground_Broadleaf_Deciduous_Boreal_dry.tif", bins=100)

# %%
output_folder = "../data/land_use/"

# %%
for row in files_inventory.iter_rows(named=True):
    input_path = row["path"]
    land_use_type = row["land_use"]
    output_path = output_folder + "lu_" + land_use_type + ".tif"

    print(f"Creating a land use raster for {land_use_type}")

    mc.binarize_raster(input_path, output_path)
    print(f"{land_use_type} rasterized succesfully!\n")
# Out:
# Creating a land use raster for Broadleaf_Deciduous_Boreal_dry
# Broadleaf_Deciduous_Boreal_dry rasterized succesfully!
#
# Creating a land use raster for Broadleaf_Deciduous_Boreal_moist
# Broadleaf_Deciduous_Boreal_moist rasterized succesfully!
#
# Creating a land use raster for Broadleaf_Deciduous_Cold_temperate_dry
# Broadleaf_Deciduous_Cold_temperate_dry rasterized succesfully!
#
# Creating a land use raster for Broadleaf_Deciduous_Cold_temperate_moist
# Broadleaf_Deciduous_Cold_temperate_moist rasterized succesfully!
#
# Creating a land use raster for Broadleaf_Deciduous_Subtropical
# Broadleaf_Deciduous_Subtropical rasterized succesfully!
#
# Creating a land use raster for Broadleaf_Deciduous_Tropical
# Broadleaf_Deciduous_Tropical rasterized succesfully!
#
# Creating a land use raster for Broadleaf_Deciduous_Warm_temperate_dry
# Broadleaf_Deciduous_Warm_temperate_dry rasterized succesfully!
#
# Creating a land use raster for Broadleaf_Deciduous_Warm_temperate_moist
# Broadleaf_Deciduous_Warm_temperate_moist rasterized succesfully!
#
# Creating a land use raster for Grassland
# Grassland rasterized succesfully!
#
# Creating a land use raster for Irrigated_Apples
# Irrigated_Apples rasterized succesfully!
#
# Creating a land use raster for Irrigated_Bananas
# Irrigated_Bananas rasterized succesfully!
#
# Creating a land use raster for Irrigated_Barley_residues_left_on_the_field
# Irrigated_Barley_residues_left_on_the_field rasterized succesfully!
#
# Creating a land use raster for Irrigated_Barley_residues_removed_from_the_field
# Irrigated_Barley_residues_removed_from_the_field rasterized succesfully!
#
# Creating a land use raster for Irrigated_Cabbages
# Irrigated_Cabbages rasterized succesfully!
#
# Creating a land use raster for Irrigated_Carrots
# Irrigated_Carrots rasterized succesfully!
#
# Creating a land use raster for Irrigated_Cocoa
# Irrigated_Cocoa rasterized succesfully!
#
# Creating a land use raster for Irrigated_Coconuts
# Irrigated_Coconuts rasterized succesfully!
#
# Creating a land use raster for Irrigated_Coffee
# Irrigated_Coffee rasterized succesfully!
#
# Creating a land use raster for Irrigated_cotton
# Irrigated_cotton rasterized succesfully!
#
# Creating a land use raster for Irrigated_Grapes
# Irrigated_Grapes rasterized succesfully!
#
# Creating a land use raster for Irrigated_Groundnuts
# Irrigated_Groundnuts rasterized succesfully!
#
# Creating a land use raster for Irrigated_Maize_residues_left_on_the_field
# Irrigated_Maize_residues_left_on_the_field rasterized succesfully!
#
# Creating a land use raster for Irrigated_Maize_residues_removed_from_the_field
# Irrigated_Maize_residues_removed_from_the_field rasterized succesfully!
#
# Creating a land use raster for Irrigated_Oil_palm
# Irrigated_Oil_palm rasterized succesfully!
#
# Creating a land use raster for Irrigated_Olives
# Irrigated_Olives rasterized succesfully!
#
# Creating a land use raster for Irrigated_Onions
# Irrigated_Onions rasterized succesfully!
#
# Creating a land use raster for Irrigated_Oranges
# Irrigated_Oranges rasterized succesfully!
#
# Creating a land use raster for Irrigated_Potatoes
# Irrigated_Potatoes rasterized succesfully!
#
# Creating a land use raster for Irrigated_Rapeseed_residues_left_on_the_field
# Irrigated_Rapeseed_residues_left_on_the_field rasterized succesfully!
#
# Creating a land use raster for Irrigated_Rapeseed_residues_removed_from_the_field
# Irrigated_Rapeseed_residues_removed_from_the_field rasterized succesfully!
#
# Creating a land use raster for Irrigated_Rice
# Irrigated_Rice rasterized succesfully!
#
# Creating a land use raster for Irrigated_Sorghum_residues_left_on_the_field
# Irrigated_Sorghum_residues_left_on_the_field rasterized succesfully!
#
# Creating a land use raster for Irrigated_Sorghum_residues_removed_from_the_field
# Irrigated_Sorghum_residues_removed_from_the_field rasterized succesfully!
#
# Creating a land use raster for Irrigated_Soybeans
# Irrigated_Soybeans rasterized succesfully!
#
# Creating a land use raster for Irrigated_Sugarbeet
# Irrigated_Sugarbeet rasterized succesfully!
#
# Creating a land use raster for Irrigated_Sugarcane
# Irrigated_Sugarcane rasterized succesfully!
#
# Creating a land use raster for Irrigated_Sunflower
# Irrigated_Sunflower rasterized succesfully!
#
# Creating a land use raster for Irrigated_Sweet_potatoes
# Irrigated_Sweet_potatoes rasterized succesfully!
#
# Creating a land use raster for Irrigated_Tobacco
# Irrigated_Tobacco rasterized succesfully!
#
# Creating a land use raster for Irrigated_Tomatoes
# Irrigated_Tomatoes rasterized succesfully!
#
# Creating a land use raster for Irrigated_Wheat_residues_left_on_the_field
# Irrigated_Wheat_residues_left_on_the_field rasterized succesfully!
#
# Creating a land use raster for Irrigated_Wheat_residues_removed_from_the_field
# Irrigated_Wheat_residues_removed_from_the_field rasterized succesfully!
#
# Creating a land use raster for Needleleaf_Evergreen_Boreal_dry
# Needleleaf_Evergreen_Boreal_dry rasterized succesfully!
#
# Creating a land use raster for Needleleaf_Evergreen_Boreal_moist
# Needleleaf_Evergreen_Boreal_moist rasterized succesfully!
#
# Creating a land use raster for Needleleaf_Evergreen_Cold_temperate_dry
# Needleleaf_Evergreen_Cold_temperate_dry rasterized succesfully!
#
# Creating a land use raster for Needleleaf_Evergreen_Cold_temperate_moist
# Needleleaf_Evergreen_Cold_temperate_moist rasterized succesfully!
#
# Creating a land use raster for Needleleaf_Evergreen_Subtropical
# Needleleaf_Evergreen_Subtropical rasterized succesfully!
#
# Creating a land use raster for Needleleaf_Evergreen_Tropical
# Needleleaf_Evergreen_Tropical rasterized succesfully!
#
# Creating a land use raster for Needleleaf_Evergreen_Warm_temperate_dry
# Needleleaf_Evergreen_Warm_temperate_dry rasterized succesfully!
#
# Creating a land use raster for Needleleaf_Evergreen_Warm_temperate_moist
# Needleleaf_Evergreen_Warm_temperate_moist rasterized succesfully!
#
# Creating a land use raster for Rainfed_Apples
# Rainfed_Apples rasterized succesfully!
#
# Creating a land use raster for Rainfed_Bananas
# Rainfed_Bananas rasterized succesfully!
#
# Creating a land use raster for Rainfed_Barley_residues_left_on_the_field
# Rainfed_Barley_residues_left_on_the_field rasterized succesfully!
#
# Creating a land use raster for Rainfed_Barley_residues_removed_from_the_field
# Rainfed_Barley_residues_removed_from_the_field rasterized succesfully!
#
# Creating a land use raster for Rainfed_Cocoa
# Rainfed_Cocoa rasterized succesfully!
#
# Creating a land use raster for Rainfed_Coconuts
# Rainfed_Coconuts rasterized succesfully!
#
# Creating a land use raster for Rainfed_Coffee
# Rainfed_Coffee rasterized succesfully!
#
# Creating a land use raster for Rainfed_cotton
# Rainfed_cotton rasterized succesfully!
#
# Creating a land use raster for Rainfed_Grapes
# Rainfed_Grapes rasterized succesfully!
#
# Creating a land use raster for Rainfed_Groundnuts
# Rainfed_Groundnuts rasterized succesfully!
#
# Creating a land use raster for Rainfed_Maize_residues_left_on_the_field
# Rainfed_Maize_residues_left_on_the_field rasterized succesfully!
#
# Creating a land use raster for Rainfed_Maize_residues_removed_from_the_field
# Rainfed_Maize_residues_removed_from_the_field rasterized succesfully!
#
# Creating a land use raster for Rainfed_Oil_palm
# Rainfed_Oil_palm rasterized succesfully!
#
# Creating a land use raster for Rainfed_Olives
# Rainfed_Olives rasterized succesfully!
#
# Creating a land use raster for Rainfed_Oranges
# Rainfed_Oranges rasterized succesfully!
#
# Creating a land use raster for Rainfed_Potatoes
# Rainfed_Potatoes rasterized succesfully!
#
# Creating a land use raster for Rainfed_Rapeseed_residues_left_on_the_field
# Rainfed_Rapeseed_residues_left_on_the_field rasterized succesfully!
#
# Creating a land use raster for Rainfed_Rapeseed_residues_removed_from_the_field
# Rainfed_Rapeseed_residues_removed_from_the_field rasterized succesfully!
#
# Creating a land use raster for Rainfed_Rice
# Rainfed_Rice rasterized succesfully!
#
# Creating a land use raster for Rainfed_Sorghum_residues_left_on_the_field
# Rainfed_Sorghum_residues_left_on_the_field rasterized succesfully!
#
# Creating a land use raster for Rainfed_Sorghum_residues_removed_from_the_field
# Rainfed_Sorghum_residues_removed_from_the_field rasterized succesfully!
#
# Creating a land use raster for Rainfed_Soybeans
# Rainfed_Soybeans rasterized succesfully!
#
# Creating a land use raster for Rainfed_Sugarbeet
# Rainfed_Sugarbeet rasterized succesfully!
#
# Creating a land use raster for Rainfed_Sugarcane
# Rainfed_Sugarcane rasterized succesfully!
#
# Creating a land use raster for Rainfed_Sunflower
# Rainfed_Sunflower rasterized succesfully!
#
# Creating a land use raster for Rainfed_Sweet_potatoes
# Rainfed_Sweet_potatoes rasterized succesfully!
#
# Creating a land use raster for Rainfed_Tobacco
# Rainfed_Tobacco rasterized succesfully!
#
# Creating a land use raster for Rainfed_Tomatoes
# Rainfed_Tomatoes rasterized succesfully!
#
# Creating a land use raster for Rainfed_Wheat_residues_left_on_the_field
# Rainfed_Wheat_residues_left_on_the_field rasterized succesfully!
#
# Creating a land use raster for Rainfed_Wheat_residues_removed_from_the_field
# Rainfed_Wheat_residues_removed_from_the_field rasterized succesfully!
#
# Creating a land use raster for Urban
# Urban rasterized succesfully!

# %% [markdown]
# Inpsecting...

# %%
test_file = "../data/land_use/lu_Irrigated_Maize_residues_left_on_the_field.tif"

# %%
mp.inspect_raster(test_file)
# Out:
# File: ../data/land_use/lu_Irrigated_Maize_residues_left_on_the_field.tif
# Driver: GTiff
# Width, Height: 4320, 2083
# Number of Bands: 1
# CRS: EPSG:4326
# Bounds: BoundingBox(left=-179.99999999999997, bottom=-89.99999999999994, right=179.99999999999991, top=83.58333333333331)
# Pixel Size: (0.0833333333333333, 0.0833333333333333)
# No-data Value: 255.0
#
# --- Raster Metadata ---
# AREA_OR_POINT: Area
#
# --- Band Information ---
#
# Band 1:
#   Data Type: uint8
#   Min Value: 1
#   Max Value: 1
#   Mean Value: 1.0
#   Standard Deviation: 0.0

# %%
mp.plot_raster_on_world_extremes_cutoff(test_file, "Land Use for\nIrrigated_Maize_residues_left_on_the_field", alpha=0)
# Out:
# Raster has 1 different values. Min: 1.00. Max: 1.00
