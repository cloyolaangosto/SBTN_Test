# %% [markdown]
# # Soil Erosion Example
#
# TO BE COMPLETED IN THE FUTURE

# %%
import sbtn_leaf.map_plotting as mplot

# %%
map = "../data/soil_weather/sf_2012.tif"

# %%
mplot.plot_raster_on_world_extremes_cutoff(map, title="RLSK Factor", quantiles=10)
# Out:
# Raster has 273,833 different values. Min: 0.51. Max: 1,478.14
# Using quantiles
# All positives route
